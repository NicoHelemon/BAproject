# %%
import numpy as np
import cv2
import os
import json
import utils
from matplotlib import pyplot as plt

# %%
target_directory = r'output\session_4\grabcut_verbose\\'

# %%
cat = cv2.imread(r'images\original_images\set_1\cat.jpg')

# %%
cat = utils.resize_target_height(cat, 600)

# %%
utils.pltShow(cat)

# %%
bbox = utils.boundingBox(cat)

# %%
catbbox =  utils.drawBbox(cat, bbox)

# %%
utils.pltShow(catbbox)

# %%
inMask = utils.bboxToMask(image, bbox, )

# %%
mask, _ = utils.grabCut(cat, bbox)

# %%
mask = utils.maskToGrayImage(mask)

# %%
utils.pltShow(mask, mode = 'gray')

# %%
utils.cv2Show(mask)
