# %%
from torchvision import transforms
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import timeit
import pandas as pd

import sys
sys.path.append('../../')
import utils.image as im
import utils.cam as cam
import utils.grabcut as gc
import utils.voc as voc
import utils.json as json
from utils.VOCSegmentation import VOCSegmentation

# %%
root_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\\'

json_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\\'

output_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\sessions\session2\\'

# %%
camnet = cam.Cam()

# %%
data_tbl = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Object')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 2))

# %%
annotations = json.open_json(json_path + "voc-object-annotations-clean")
N = len(annotations)
annotations = iter(annotations.items())

# %%
IoU = np.array([])
time = np.array([])

for i in range(N):
    start = timeit.default_timer()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_pil = img
    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    for j, annot in enumerate(annots):
        c, d, cbbox = annot
        
        img_cam = camnet.get_top(img_pil, c)
        img_cam = cam.cam_process(img_pil, img_cam)
        img_cam = im.bitwise_and(img_cam, im.cbbox_mask(img_cv2, cbbox))
        gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0)
        _, _, pred = gc.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
        pred    = im.bitwise_and(pred, im.cbbox_mask(img_cv2, cbbox))
        
        true = voc.true_mask(sgm, j+1, dilation = 0)
        
        IoU = np.append(IoU, voc.IoU_acc_undef(true, pred, sgm))
    stop = timeit.default_timer()
    time = np.append(time, stop - start)
    if i % 10 == 0:
        print(f'Image nb {i}')
        print(f'Time spent               = ' + voc.time_str(np.sum(time)))
        print(f'Estimated time remaining = ' + voc.time_str(np.mean(time) * (N - 1 - i)))
        print(f'Mean IoU                 =  {np.mean(IoU) :.3f}')
        print()
# Out:
# C:\Users\Nicol\Miniconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Image nb 0
# Time spent               = 1.018 sec
# Estimated time remaining = 49.429 min
# Mean IoU                 = 0.448
#
# Image nb 1
# Time spent               = 2.752 sec
# Estimated time remaining = 66.762 min
# Mean IoU                 = 0.396
#
# Image nb 2
# Time spent               = 3.273 sec
# Estimated time remaining = 52.921 min
# Mean IoU                 = 0.459
#
# Image nb 3
# Time spent               = 5.147 sec
# Estimated time remaining = 62.389 min
# Mean IoU                 = 0.488
#
# Image nb 4
# Time spent               = 6.286 sec
# Estimated time remaining = 60.932 min
# Mean IoU                 = 0.471
#
# Image nb 5
# Time spent               = 10.891 sec
# Estimated time remaining = 87.946 min
# Mean IoU                 = 0.517
#
# Image nb 6
# Time spent               = 12.470 sec
# Estimated time remaining = 86.282 min
# Mean IoU                 = 0.506
#
# Image nb 7
# Time spent               = 13.791 sec
# Estimated time remaining = 83.463 min
# Mean IoU                 = 0.543
#
# Image nb 8
# Time spent               = 15.652 sec
# Estimated time remaining = 84.175 min
# Mean IoU                 = 0.513
#
# Image nb 9
# Time spent               = 20.509 sec
# Estimated time remaining = 99.229 min
# Mean IoU                 = 0.475
#
# Image nb 10
# Time spent               = 26.750 sec
# Estimated time remaining = 117.621 min
# Mean IoU                 = 0.409
#
# Image nb 11
# Time spent               = 27.963 sec
# Estimated time remaining = 112.669 min
# Mean IoU                 = 0.426
#
# Image nb 12
# Time spent               = 28.954 sec
# Estimated time remaining = 107.651 min
# Mean IoU                 = 0.436
#
# Image nb 13
# Time spent               = 30.437 sec
# Estimated time remaining = 105.045 min
# Mean IoU                 = 0.453
#
# Image nb 14
# Time spent               = 30.856 sec
# Estimated time remaining = 99.358 min
# Mean IoU                 = 0.468
#
# Image nb 15
# Time spent               = 32.190 sec
# Estimated time remaining = 97.139 min
# Mean IoU                 = 0.477
#
# Image nb 16
# Time spent               = 33.190 sec
# Estimated time remaining = 94.233 min
# Mean IoU                 = 0.479
#
# Image nb 17
# Time spent               = 38.038 sec
# Estimated time remaining = 101.964 min
# Mean IoU                 = 0.461
#
# Image nb 18
# Time spent               = 39.036 sec
# Estimated time remaining = 99.097 min
# Mean IoU                 = 0.464
#
# Image nb 19
# Time spent               = 40.356 sec
# Estimated time remaining = 97.291 min
# Mean IoU                 = 0.453
#
# Image nb 20
# Time spent               = 43.321 sec
# Estimated time remaining = 99.432 min
# Mean IoU                 = 0.440
#
# Image nb 21
# Time spent               = 44.769 sec
# Estimated time remaining = 98.050 min
# Mean IoU                 = 0.461
#
# Image nb 22
# Time spent               = 47.120 sec
# Estimated time remaining = 98.679 min
# Mean IoU                 = 0.461
#
# Image nb 23
# Time spent               = 49.111 sec
# Estimated time remaining = 98.529 min
# Mean IoU                 = 0.461
#
# Image nb 24
# Time spent               = 50.161 sec
# Estimated time remaining = 96.577 min
# Mean IoU                 = 0.459
#
# Image nb 25
# Time spent               = 51.165 sec
# Estimated time remaining = 94.688 min
# Mean IoU                 = 0.470
#
# Image nb 26
# Time spent               = 54.131 sec
# Estimated time remaining = 96.433 min
# Mean IoU                 = 0.472
#
# Image nb 27
# Time spent               = 55.938 sec
# Estimated time remaining = 96.060 min
# Mean IoU                 = 0.468
#
# Image nb 28
# Time spent               = 59.161 sec
# Estimated time remaining = 98.058 min
# Mean IoU                 = 0.459
#
# Image nb 29
# Time spent               = 60.972 sec
# Estimated time remaining = 97.657 min
# Mean IoU                 = 0.433
#
# Image nb 30
# Time spent               = 61.800 sec
# Estimated time remaining = 95.756 min
# Mean IoU                 = 0.438
#
# Image nb 31
# Time spent               = 62.917 sec
# Estimated time remaining = 94.408 min
# Mean IoU                 = 0.442
#
# Image nb 32
# Time spent               = 66.584 sec
# Estimated time remaining = 96.849 min
# Mean IoU                 = 0.446
#
# Image nb 33
# Time spent               = 67.751 sec
# Estimated time remaining = 95.615 min
# Mean IoU                 = 0.448
#
# Image nb 34
# Time spent               = 69.095 sec
# Estimated time remaining = 94.692 min
# Mean IoU                 = 0.439
#
# Image nb 35
# Time spent               = 71.177 sec
# Estimated time remaining = 94.804 min
# Mean IoU                 = 0.446
#
# Image nb 36
# Time spent               = 72.102 sec
# Estimated time remaining = 93.408 min
# Mean IoU                 = 0.444
#
# Image nb 37
# Time spent               = 73.714 sec
# Estimated time remaining = 92.951 min
# Mean IoU                 = 0.444
#
# Image nb 38
# Time spent               = 77.342 sec
# Estimated time remaining = 94.991 min
# Mean IoU                 = 0.445
#
# Image nb 39
# Time spent               = 80.239 sec
# Estimated time remaining = 96.053 min
# Mean IoU                 = 0.425
#
# Image nb 40
# Time spent               = 81.686 sec
# Estimated time remaining = 95.367 min
# Mean IoU                 = 0.432
#
# Image nb 41
# Time spent               = 87.462 sec
# Estimated time remaining = 99.645 min
# Mean IoU                 = 0.421
#
# Image nb 42
# Time spent               = 88.618 sec
# Estimated time remaining = 98.579 min
# Mean IoU                 = 0.427
#
# Image nb 43
# Time spent               = 89.777 sec
# Estimated time remaining = 97.565 min
# Mean IoU                 = 0.432
#
# Image nb 44
# Time spent               = 90.295 sec
# Estimated time remaining = 95.913 min
# Mean IoU                 = 0.430
#
# Image nb 45
# Time spent               = 94.102 sec
# Estimated time remaining = 97.750 min
# Mean IoU                 = 0.407
#
# Image nb 46
# Time spent               = 96.168 sec
# Estimated time remaining = 97.737 min
# Mean IoU                 = 0.411
#
# Image nb 47
# Time spent               = 96.761 sec
# Estimated time remaining = 96.257 min
# Mean IoU                 = 0.415
#
# Image nb 48
# Time spent               = 101.818 sec
# Estimated time remaining = 99.186 min
# Mean IoU                 = 0.410
#
# Image nb 49
# Time spent               = 104.874 sec
# Estimated time remaining = 100.085 min
# Mean IoU                 = 0.412
#
# Image nb 50
# Time spent               = 106.527 sec
# Estimated time remaining = 99.635 min
# Mean IoU                 = 0.414
#
# Image nb 51
# Time spent               = 111.251 sec
# Estimated time remaining = 102.016 min
# Mean IoU                 = 0.400
#
# Image nb 52
# Time spent               = 113.316 sec
# Estimated time remaining = 101.913 min
# Mean IoU                 = 0.401
#
# Image nb 53
# Time spent               = 114.917 sec
# Estimated time remaining = 101.404 min
# Mean IoU                 = 0.398
#
# Image nb 54
# Time spent               = 116.333 sec
# Estimated time remaining = 100.751 min
# Mean IoU                 = 0.404
#
# Image nb 55
# Time spent               = 118.531 sec
# Estimated time remaining = 100.786 min
# Mean IoU                 = 0.403
#
# Image nb 56
# Time spent               = 119.497 sec
# Estimated time remaining = 99.791 min
# Mean IoU                 = 0.405
#
# Image nb 57
# Time spent               = 119.869 sec
# Estimated time remaining = 98.340 min
# Mean IoU                 = 0.404
#
# Image nb 58
# Time spent               = 121.847 sec
# Estimated time remaining = 98.235 min
# Mean IoU                 = 0.408
#
# Image nb 59
# Time spent               = 122.750 sec
# Estimated time remaining = 97.279 min
# Mean IoU                 = 0.415
#
# Image nb 60
# Time spent               = 125.433 sec
# Estimated time remaining = 97.742 min
# Mean IoU                 = 0.418
#
# Image nb 61
# Time spent               = 127.290 sec
# Estimated time remaining = 97.555 min
# Mean IoU                 = 0.423
#
# Image nb 62
# Time spent               = 128.432 sec
# Estimated time remaining = 96.833 min
# Mean IoU                 = 0.429
#
# Image nb 63
# Time spent               = 130.249 sec
# Estimated time remaining = 96.636 min
# Mean IoU                 = 0.435
#
# Image nb 64
# Time spent               = 133.425 sec
# Estimated time remaining = 97.435 min
# Mean IoU                 = 0.446
#
# Image nb 65
# Time spent               = 136.352 sec
# Estimated time remaining = 98.029 min
# Mean IoU                 = 0.441
#
# Image nb 66
# Time spent               = 138.491 sec
# Estimated time remaining = 98.046 min
# Mean IoU                 = 0.446
#
# Image nb 67
# Time spent               = 139.448 sec
# Estimated time remaining = 97.237 min
# Mean IoU                 = 0.447
# Image nb 68
# Time spent               = 141.581 sec
# Estimated time remaining = 97.260 min
# Mean IoU                 = 0.447
#
# Image nb 69
# Time spent               = 144.204 sec
# Estimated time remaining = 97.613 min
# Mean IoU                 = 0.451
#
# Image nb 70
# Time spent               = 144.910 sec
# Estimated time remaining = 96.675 min
# Mean IoU                 = 0.453
#
# Image nb 71
# Time spent               = 146.658 sec
# Estimated time remaining = 96.448 min
# Mean IoU                 = 0.458
#
# Image nb 72
# Time spent               = 151.367 sec
# Estimated time remaining = 98.147 min
# Mean IoU                 = 0.458
#
# Image nb 73
# Time spent               = 152.951 sec
# Estimated time remaining = 97.799 min
# Mean IoU                 = 0.459
#
# Image nb 74
# Time spent               = 153.356 sec
# Estimated time remaining = 96.716 min
# Mean IoU                 = 0.462
#
# Image nb 75
# Time spent               = 155.940 sec
# Estimated time remaining = 97.018 min
# Mean IoU                 = 0.466
#
# Image nb 76
# Time spent               = 161.130 sec
# Estimated time remaining = 98.910 min
# Mean IoU                 = 0.455
#
# Image nb 77
# Time spent               = 162.606 sec
# Estimated time remaining = 98.502 min
# Mean IoU                 = 0.455
#
# Image nb 78
# Time spent               = 165.460 sec
# Estimated time remaining = 98.927 min
# Mean IoU                 = 0.451
#
# Image nb 79
# Time spent               = 165.910 sec
# Estimated time remaining = 97.921 min
# Mean IoU                 = 0.451
#
# Image nb 80
# Time spent               = 166.359 sec
# Estimated time remaining = 96.940 min
# Mean IoU                 = 0.453
#
# Image nb 81
# Time spent               = 170.082 sec
# Estimated time remaining = 97.867 min
# Mean IoU                 = 0.449
#
# Image nb 82
# Time spent               = 173.644 sec
# Estimated time remaining = 98.677 min
# Mean IoU                 = 0.448
#
# Image nb 83
# Time spent               = 175.523 sec
# Estimated time remaining = 98.523 min
# Mean IoU                 = 0.449
#
# Image nb 84
# Time spent               = 176.704 sec
# Estimated time remaining = 97.984 min
# Mean IoU                 = 0.449
#
# Image nb 85
# Time spent               = 180.739 sec
# Estimated time remaining = 99.021 min
# Mean IoU                 = 0.454
#
# Image nb 86
# Time spent               = 184.852 sec
# Estimated time remaining = 100.075 min
# Mean IoU                 = 0.454
#
# Image nb 87
# Time spent               = 186.077 sec
# Estimated time remaining = 99.558 min
# Mean IoU                 = 0.456
#
# Image nb 88
# Time spent               = 186.802 sec
# Estimated time remaining = 98.788 min
# Mean IoU                 = 0.458
#
# Image nb 89
# Time spent               = 187.276 sec
# Estimated time remaining = 97.904 min
# Mean IoU                 = 0.458
#
# Image nb 90
# Time spent               = 190.696 sec
# Estimated time remaining = 98.561 min
# Mean IoU                 = 0.454
#
# Image nb 91
# Time spent               = 191.959 sec
# Estimated time remaining = 98.101 min
# Mean IoU                 = 0.455
#
# Image nb 92
# Time spent               = 194.431 sec
# Estimated time remaining = 98.261 min
# Mean IoU                 = 0.457
#
# Image nb 93
# Time spent               = 196.577 sec
# Estimated time remaining = 98.254 min
# Mean IoU                 = 0.458
#
# Image nb 94
# Time spent               = 197.106 sec
# Estimated time remaining = 97.447 min
# Mean IoU                 = 0.457
#
# Image nb 95
# Time spent               = 200.162 sec
# Estimated time remaining = 97.892 min
# Mean IoU                 = 0.446
#
# Image nb 96
# Time spent               = 201.685 sec
# Estimated time remaining = 97.585 min
# Mean IoU                 = 0.446
#
# Image nb 97
# Time spent               = 202.833 sec
# Estimated time remaining = 97.105 min
# Mean IoU                 = 0.448
#
# Image nb 98
# Time spent               = 205.833 sec
# Estimated time remaining = 97.511 min
# Mean IoU                 = 0.441
#
# Image nb 99
# Time spent               = 210.358 sec
# Estimated time remaining = 98.623 min
# Mean IoU                 = 0.439
#
# Image nb 100
# Time spent               = 211.539 sec
# Estimated time remaining = 98.159 min
# Mean IoU                 = 0.441
#
# Image nb 101
# Time spent               = 214.061 sec
# Estimated time remaining = 98.321 min
# Mean IoU                 = 0.439
#
# Image nb 102
# Time spent               = 214.980 sec
# Estimated time remaining = 97.750 min
# Mean IoU                 = 0.441
#
# Image nb 103
# Time spent               = 216.036 sec
# Estimated time remaining = 97.251 min
# Mean IoU                 = 0.442
#
# Image nb 104
# Time spent               = 220.927 sec
# Estimated time remaining = 98.470 min
# Mean IoU                 = 0.441
#
# Image nb 105
# Time spent               = 223.478 sec
# Estimated time remaining = 98.633 min
# Mean IoU                 = 0.444
#
# Image nb 106
# Time spent               = 224.160 sec
# Estimated time remaining = 97.974 min
# Mean IoU                 = 0.443
#
# Image nb 107
# Time spent               = 234.956 sec
# Estimated time remaining = 101.705 min
# Mean IoU                 = 0.450
#
# Image nb 108
# Time spent               = 235.744 sec
# Estimated time remaining = 101.075 min
# Mean IoU                 = 0.451
#
# Image nb 109
# Time spent               = 242.883 sec
# Estimated time remaining = 103.152 min
# Mean IoU                 = 0.450
#
# Image nb 110
# Time spent               = 245.345 sec
# Estimated time remaining = 103.222 min
# Mean IoU                 = 0.454
#
# Image nb 111
# Time spent               = 246.331 sec
# Estimated time remaining = 102.674 min
# Mean IoU                 = 0.455
#
# Image nb 112
# Time spent               = 248.480 sec
# Estimated time remaining = 102.617 min
# Mean IoU                 = 0.454
#
# Image nb 113
# Time spent               = 249.528 sec
# Estimated time remaining = 102.110 min
# Mean IoU                 = 0.455
#
# Image nb 114
# Time spent               = 253.706 sec
# Estimated time remaining = 102.880 min
# Mean IoU                 = 0.462
#
# Image nb 115
# Time spent               = 254.928 sec
# Estimated time remaining = 102.447 min
# Mean IoU                 = 0.463
#
# Image nb 116
# Time spent               = 256.924 sec
# Estimated time remaining = 102.330 min
# Mean IoU                 = 0.465
#
# Image nb 117
# Time spent               = 259.509 sec
# Estimated time remaining = 102.447 min
# Mean IoU                 = 0.465
#
# Image nb 118
# Time spent               = 260.899 sec
# Estimated time remaining = 102.094 min
# Mean IoU                 = 0.461
#
# Image nb 119
# Time spent               = 261.695 sec
# Estimated time remaining = 101.516 min
# Mean IoU                 = 0.459
#
# Image nb 120
# Time spent               = 262.226 sec
# Estimated time remaining = 100.845 min
# Mean IoU                 = 0.460
#
# Image nb 121
# Time spent               = 264.488 sec
# Estimated time remaining = 100.845 min
# Mean IoU                 = 0.461
#
# Image nb 122
# Time spent               = 268.247 sec
# Estimated time remaining = 101.411 min
# Mean IoU                 = 0.462
#
# Image nb 123
# Time spent               = 271.717 sec
# Estimated time remaining = 101.857 min
# Mean IoU                 = 0.459
#
# Image nb 124
# Time spent               = 274.991 sec
# Estimated time remaining = 102.223 min
# Mean IoU                 = 0.460
#
# Image nb 125
# Time spent               = 275.700 sec
# Estimated time remaining = 101.637 min
# Mean IoU                 = 0.462
#
# Image nb 126
# Time spent               = 277.866 sec
# Estimated time remaining = 101.592 min
# Mean IoU                 = 0.462
#
# Image nb 127
# Time spent               = 279.079 sec
# Estimated time remaining = 101.202 min
# Mean IoU                 = 0.462
#
# Image nb 128
# Time spent               = 279.541 sec
# Estimated time remaining = 100.548 min
# Mean IoU                 = 0.461
#
# Image nb 129
# Time spent               = 283.776 sec
# Estimated time remaining = 101.250 min
# Mean IoU                 = 0.460
#
# Image nb 130
# Time spent               = 285.214 sec
# Estimated time remaining = 100.950 min
# Mean IoU                 = 0.460
#
# Image nb 131
# Time spent               = 285.790 sec
# Estimated time remaining = 100.351 min
# Mean IoU                 = 0.460
#
# Image nb 132
# Time spent               = 287.352 sec
# Estimated time remaining = 100.105 min
# Mean IoU                 = 0.461
#
# Image nb 133
# Time spent               = 287.969 sec
# Estimated time remaining = 99.536 min
# Mean IoU                 = 0.462
#
# Image nb 134
# Time spent               = 288.472 sec
# Estimated time remaining = 98.935 min
# Mean IoU                 = 0.463
# Image nb 135
# Time spent               = 289.691 sec
# Estimated time remaining = 98.587 min
# Mean IoU                 = 0.463
#
# Image nb 136
# Time spent               = 291.923 sec
# Estimated time remaining = 98.586 min
# Mean IoU                 = 0.462
#
# Image nb 137
# Time spent               = 292.955 sec
# Estimated time remaining = 98.182 min
# Mean IoU                 = 0.464
#
# Image nb 138
# Time spent               = 293.820 sec
# Estimated time remaining = 97.729 min
# Mean IoU                 = 0.466
#
# Image nb 139
# Time spent               = 295.309 sec
# Estimated time remaining = 97.487 min
# Mean IoU                 = 0.465
#
# Image nb 140
# Time spent               = 298.325 sec
# Estimated time remaining = 97.749 min
# Mean IoU                 = 0.466
#
# Image nb 141
# Time spent               = 298.862 sec
# Estimated time remaining = 97.200 min
# Mean IoU                 = 0.466
#
# Image nb 142
# Time spent               = 299.867 sec
# Estimated time remaining = 96.810 min
# Mean IoU                 = 0.466
#
# Image nb 143
# Time spent               = 303.068 sec
# Estimated time remaining = 97.129 min
# Mean IoU                 = 0.463
#
# Image nb 144
# Time spent               = 305.481 sec
# Estimated time remaining = 97.192 min
# Mean IoU                 = 0.464
#
# Image nb 145
# Time spent               = 306.592 sec
# Estimated time remaining = 96.842 min
# Mean IoU                 = 0.465
#
# Image nb 146
# Time spent               = 308.724 sec
# Estimated time remaining = 96.818 min
# Mean IoU                 = 0.461
#
# Image nb 147
# Time spent               = 310.504 sec
# Estimated time remaining = 96.683 min
# Mean IoU                 = 0.458
#
# Image nb 148
# Time spent               = 311.180 sec
# Estimated time remaining = 96.208 min
# Mean IoU                 = 0.458
#
# Image nb 149
# Time spent               = 316.245 sec
# Estimated time remaining = 97.087 min
# Mean IoU                 = 0.453
#
# Image nb 150
# Time spent               = 318.123 sec
# Estimated time remaining = 96.982 min
# Mean IoU                 = 0.451
#
# Image nb 151
# Time spent               = 323.533 sec
# Estimated time remaining = 97.947 min
# Mean IoU                 = 0.451
#
# Image nb 152
# Time spent               = 325.165 sec
# Estimated time remaining = 97.762 min
# Mean IoU                 = 0.452
#
# Image nb 153
# Time spent               = 326.091 sec
# Estimated time remaining = 97.368 min
# Mean IoU                 = 0.450
#
# Image nb 154
# Time spent               = 328.381 sec
# Estimated time remaining = 97.384 min
# Mean IoU                 = 0.449
#
# Image nb 155
# Time spent               = 329.240 sec
# Estimated time remaining = 96.978 min
# Mean IoU                 = 0.451
#
# Image nb 156
# Time spent               = 331.441 sec
# Estimated time remaining = 96.969 min
# Mean IoU                 = 0.452
#
# Image nb 157
# Time spent               = 332.254 sec
# Estimated time remaining = 96.557 min
# Mean IoU                 = 0.453
#
# Image nb 158
# Time spent               = 333.346 sec
# Estimated time remaining = 96.230 min
# Mean IoU                 = 0.454
#
# Image nb 159
# Time spent               = 337.448 sec
# Estimated time remaining = 96.770 min
# Mean IoU                 = 0.454
#
# Image nb 160
# Time spent               = 339.281 sec
# Estimated time remaining = 96.656 min
# Mean IoU                 = 0.454
#
# Image nb 161
# Time spent               = 342.242 sec
# Estimated time remaining = 96.863 min
# Mean IoU                 = 0.454
#
# Image nb 162
# Time spent               = 343.974 sec
# Estimated time remaining = 96.721 min
# Mean IoU                 = 0.454
#
# Image nb 163
# Time spent               = 346.093 sec
# Estimated time remaining = 96.688 min
# Mean IoU                 = 0.455
#
# Image nb 164
# Time spent               = 351.705 sec
# Estimated time remaining = 97.625 min
# Mean IoU                 = 0.454
#
# Image nb 165
# Time spent               = 353.687 sec
# Estimated time remaining = 97.548 min
# Mean IoU                 = 0.454
#
# Image nb 166
# Time spent               = 354.893 sec
# Estimated time remaining = 97.259 min
# Mean IoU                 = 0.455
#
# Image nb 167
# Time spent               = 356.729 sec
# Estimated time remaining = 97.145 min
# Mean IoU                 = 0.455
#
# Image nb 168
# Time spent               = 358.182 sec
# Estimated time remaining = 96.928 min
# Mean IoU                 = 0.454
#
# Image nb 169
# Time spent               = 360.149 sec
# Estimated time remaining = 96.852 min
# Mean IoU                 = 0.453
#
# Image nb 170
# Time spent               = 362.308 sec
# Estimated time remaining = 96.827 min
# Mean IoU                 = 0.455
#
# Image nb 171
# Time spent               = 366.107 sec
# Estimated time remaining = 97.238 min
# Mean IoU                 = 0.451
#
# Image nb 172
# Time spent               = 368.344 sec
# Estimated time remaining = 97.232 min
# Mean IoU                 = 0.449
#
# Image nb 173
# Time spent               = 370.823 sec
# Estimated time remaining = 97.288 min
# Mean IoU                 = 0.454
#
# Image nb 174
# Time spent               = 374.204 sec
# Estimated time remaining = 97.578 min
# Mean IoU                 = 0.456
#
# Image nb 175
# Time spent               = 377.352 sec
# Estimated time remaining = 97.804 min
# Mean IoU                 = 0.457
#
# Image nb 176
# Time spent               = 382.735 sec
# Estimated time remaining = 98.603 min
# Mean IoU                 = 0.450
#
# Image nb 177
# Time spent               = 384.729 sec
# Estimated time remaining = 98.524 min
# Mean IoU                 = 0.451
#
# Image nb 178
# Time spent               = 387.061 sec
# Estimated time remaining = 98.531 min
# Mean IoU                 = 0.450
#
# Image nb 179
# Time spent               = 390.052 sec
# Estimated time remaining = 98.705 min
# Mean IoU                 = 0.449
#
# Image nb 180
# Time spent               = 393.254 sec
# Estimated time remaining = 98.929 min
# Mean IoU                 = 0.450
#
# Image nb 181
# Time spent               = 394.269 sec
# Estimated time remaining = 98.603 min
# Mean IoU                 = 0.448
#
# Image nb 182
# Time spent               = 395.724 sec
# Estimated time remaining = 98.390 min
# Mean IoU                 = 0.447
#
# Image nb 183
# Time spent               = 398.769 sec
# Estimated time remaining = 98.573 min
# Mean IoU                 = 0.448
#
# Image nb 184
# Time spent               = 401.041 sec
# Estimated time remaining = 98.562 min
# Mean IoU                 = 0.449
#
# Image nb 185
# Time spent               = 403.823 sec
# Estimated time remaining = 98.676 min
# Mean IoU                 = 0.451
#
# Image nb 186
# Time spent               = 404.864 sec
# Estimated time remaining = 98.365 min
# Mean IoU                 = 0.452
#
# Image nb 187
# Time spent               = 406.437 sec
# Estimated time remaining = 98.186 min
# Mean IoU                 = 0.454
#
# Image nb 188
# Time spent               = 406.872 sec
# Estimated time remaining = 97.735 min
# Mean IoU                 = 0.454
#
# Image nb 189
# Time spent               = 411.790 sec
# Estimated time remaining = 98.360 min
# Mean IoU                 = 0.452
#
# Image nb 190
# Time spent               = 415.350 sec
# Estimated time remaining = 98.655 min
# Mean IoU                 = 0.451
#
# Image nb 191
# Time spent               = 416.530 sec
# Estimated time remaining = 98.383 min
# Mean IoU                 = 0.452
#
# Image nb 192
# Time spent               = 416.970 sec
# Estimated time remaining = 97.941 min
# Mean IoU                 = 0.453
#
# Image nb 193
# Time spent               = 419.930 sec
# Estimated time remaining = 98.092 min
# Mean IoU                 = 0.451
#
# Image nb 194
# Time spent               = 423.317 sec
# Estimated time remaining = 98.340 min
# Mean IoU                 = 0.449
#
# Image nb 195
# Time spent               = 424.933 sec
# Estimated time remaining = 98.175 min
# Mean IoU                 = 0.449
#
# Image nb 196
# Time spent               = 425.863 sec
# Estimated time remaining = 97.855 min
# Mean IoU                 = 0.450
#
# Image nb 197
# Time spent               = 428.658 sec
# Estimated time remaining = 97.963 min
# Mean IoU                 = 0.452
#
# Image nb 198
# Time spent               = 429.106 sec
# Estimated time remaining = 97.537 min
# Mean IoU                 = 0.453
#
# Image nb 199
# Time spent               = 431.499 sec
# Estimated time remaining = 97.555 min
# Mean IoU                 = 0.454
#
# Image nb 200
# Time spent               = 432.963 sec
# Estimated time remaining = 97.363 min
# Mean IoU                 = 0.455
#
# Image nb 201
# Time spent               = 433.493 sec
# Estimated time remaining = 96.964 min
# Mean IoU                 = 0.456
# Image nb 202
# Time spent               = 435.269 sec
# Estimated time remaining = 96.845 min
# Mean IoU                 = 0.456
#
# Image nb 203
# Time spent               = 436.196 sec
# Estimated time remaining = 96.540 min
# Mean IoU                 = 0.456
#
# Image nb 204
# Time spent               = 439.782 sec
# Estimated time remaining = 96.824 min
# Mean IoU                 = 0.456
#
# Image nb 205
# Time spent               = 443.148 sec
# Estimated time remaining = 97.055 min
# Mean IoU                 = 0.456
#
# Image nb 206
# Time spent               = 447.183 sec
# Estimated time remaining = 97.430 min
# Mean IoU                 = 0.456
#
# Image nb 207
# Time spent               = 448.414 sec
# Estimated time remaining = 97.192 min
# Mean IoU                 = 0.457
#
# Image nb 208
# Time spent               = 451.068 sec
# Estimated time remaining = 97.264 min
# Mean IoU                 = 0.457
#
# Image nb 209
# Time spent               = 452.145 sec
# Estimated time remaining = 96.996 min
# Mean IoU                 = 0.456
#
# Image nb 210
# Time spent               = 455.624 sec
# Estimated time remaining = 97.243 min
# Mean IoU                 = 0.454
#
# Image nb 211
# Time spent               = 457.372 sec
# Estimated time remaining = 97.120 min
# Mean IoU                 = 0.455
#
# Image nb 212
# Time spent               = 461.825 sec
# Estimated time remaining = 97.569 min
# Mean IoU                 = 0.448
#
# Image nb 213
# Time spent               = 466.062 sec
# Estimated time remaining = 97.967 min
# Mean IoU                 = 0.446
#
# Image nb 214
# Time spent               = 468.356 sec
# Estimated time remaining = 97.955 min
# Mean IoU                 = 0.445
#
# Image nb 215
# Time spent               = 469.585 sec
# Estimated time remaining = 97.722 min
# Mean IoU                 = 0.446
#
# Image nb 216
# Time spent               = 470.559 sec
# Estimated time remaining = 97.437 min
# Mean IoU                 = 0.447
#
# Image nb 217
# Time spent               = 471.808 sec
# Estimated time remaining = 97.211 min
# Mean IoU                 = 0.447
#
# Image nb 218
# Time spent               = 475.696 sec
# Estimated time remaining = 97.529 min
# Mean IoU                 = 0.444
#
# Image nb 219
# Time spent               = 476.992 sec
# Estimated time remaining = 97.314 min
# Mean IoU                 = 0.445
#
# Image nb 220
# Time spent               = 479.706 sec
# Estimated time remaining = 97.388 min
# Mean IoU                 = 0.447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3e6e2286b93a> in <module>
#      20         img_cam = cam.cam_process(img_pil, img_cam)
#      21         img_cam = im.bitwise_and(img_cam, im.cbbox_mask(img_cv2, cbbox))
# ---> 22         gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0)
#      23         _, _, pred = gc.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
#      24
#
# ~\Documents\EPFL\BA7\Project\Code\voc\utils\cam.py in cam_to_gcmask(cam, a, b, c)
#     133     max_coord = np.unravel_index(cam.argmax(), cam.shape)
#     134
# --> 135     mask = np.vectorize(img1c_to_4bins)(cam, a, b, c).astype('uint8')
#     136     return anchoring_fgd(mask, max_coord)
#
# KeyboardInterrupt:

# %%
print(f'Mean IoU = {np.mean(IoU)}')

# %%
df = pd.read_csv(r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\voc-object-annotations-clean.csv')

# %%
df['mIoU'] = IoU

# %%
df.to_csv(output_dir + 'IoU.csv', index = False)
