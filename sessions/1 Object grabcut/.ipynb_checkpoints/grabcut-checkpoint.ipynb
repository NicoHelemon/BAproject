# %%
from torchvision import transforms
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import timeit
import pandas as pd

import sys
sys.path.append('../../')
import utils.image as im
import utils.cam as cam
import utils.grabcut as gc
import utils.voc as voc
import utils.json as json
from utils.VOCSegmentation import VOCSegmentation

# %%
root_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\\'

json_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\\'

output_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\sessions\session1\\'

# %%
data_tbl = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Object')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 2))

# %%
annotations = json.open_json(json_path + "voc-object-annotations-clean")
N = len(annotations)
annotations = iter(annotations.items())

# %%
IoU = np.array([])
time = np.array([])

for i in range(N):
    start = timeit.default_timer()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    for j, annot in enumerate(annots):
        _, _, cbbox = annot
        
        _, _, pred = gc.grabcut(img_cv2, im.corner_to_delta(cbbox), mode = 'RECT')
        
        true = voc.true_mask(sgm, j+1, dilation = 0)
        
        IoU = np.append(IoU, voc.IoU_acc_undef(true, pred, sgm))
        
    stop = timeit.default_timer()
    time = np.append(time, stop - start)
    if i % 10 == 0:
        print(f'Image nb {i}')
        print(f'Time spent               = ' + voc.time_str(np.sum(time)))
        print(f'Estimated time remaining = ' + voc.time_str(np.mean(time) * (N - 1 - i)))
        print(f'Mean IoU                 =  {np.mean(IoU) :.3f}')
        print()
# Out:
# Image nb 0
# Time spent               = 0.974 sec
# Estimated time remaining = 47.258 min
# Mean IoU                 = 0.445
#
# Image nb 1
# Time spent               = 2.280 sec
# Estimated time remaining = 55.320 min
# Mean IoU                 = 0.387
#
# Image nb 2
# Time spent               = 2.667 sec
# Estimated time remaining = 43.119 min
# Mean IoU                 = 0.450
#
# Image nb 3
# Time spent               = 4.027 sec
# Estimated time remaining = 48.814 min
# Mean IoU                 = 0.491
#
# Image nb 4
# Time spent               = 5.408 sec
# Estimated time remaining = 52.426 min
# Mean IoU                 = 0.476
#
# Image nb 5
# Time spent               = 6.585 sec
# Estimated time remaining = 53.174 min
# Mean IoU                 = 0.528
#
# Image nb 6
# Time spent               = 7.739 sec
# Estimated time remaining = 53.545 min
# Mean IoU                 = 0.522
#
# Image nb 7
# Time spent               = 8.531 sec
# Estimated time remaining = 51.633 min
# Mean IoU                 = 0.557
#
# Image nb 8
# Time spent               = 10.196 sec
# Estimated time remaining = 54.832 min
# Mean IoU                 = 0.561
#
# Image nb 9
# Time spent               = 16.036 sec
# Estimated time remaining = 77.589 min
# Mean IoU                 = 0.509
#
# Image nb 10
# Time spent               = 20.406 sec
# Estimated time remaining = 89.724 min
# Mean IoU                 = 0.442
#
# Image nb 11
# Time spent               = 21.573 sec
# Estimated time remaining = 86.920 min
# Mean IoU                 = 0.456
#
# Image nb 12
# Time spent               = 22.541 sec
# Estimated time remaining = 83.807 min
# Mean IoU                 = 0.467
#
# Image nb 13
# Time spent               = 23.750 sec
# Estimated time remaining = 81.966 min
# Mean IoU                 = 0.482
#
# Image nb 14
# Time spent               = 24.008 sec
# Estimated time remaining = 77.305 min
# Mean IoU                 = 0.496
#
# Image nb 15
# Time spent               = 25.060 sec
# Estimated time remaining = 75.624 min
# Mean IoU                 = 0.519
#
# Image nb 16
# Time spent               = 25.823 sec
# Estimated time remaining = 73.316 min
# Mean IoU                 = 0.519
#
# Image nb 17
# Time spent               = 29.763 sec
# Estimated time remaining = 79.783 min
# Mean IoU                 = 0.526
#
# Image nb 18
# Time spent               = 30.710 sec
# Estimated time remaining = 77.960 min
# Mean IoU                 = 0.529
#
# Image nb 19
# Time spent               = 32.139 sec
# Estimated time remaining = 77.481 min
# Mean IoU                 = 0.526
#
# Image nb 20
# Time spent               = 34.338 sec
# Estimated time remaining = 78.813 min
# Mean IoU                 = 0.512
#
# Image nb 21
# Time spent               = 36.349 sec
# Estimated time remaining = 79.610 min
# Mean IoU                 = 0.526
#
# Image nb 22
# Time spent               = 38.142 sec
# Estimated time remaining = 79.878 min
# Mean IoU                 = 0.519
#
# Image nb 23
# Time spent               = 40.465 sec
# Estimated time remaining = 81.184 min
# Mean IoU                 = 0.520
#
# Image nb 24
# Time spent               = 41.193 sec
# Estimated time remaining = 79.310 min
# Mean IoU                 = 0.516
#
# Image nb 25
# Time spent               = 41.801 sec
# Estimated time remaining = 77.358 min
# Mean IoU                 = 0.524
#
# Image nb 26
# Time spent               = 43.637 sec
# Estimated time remaining = 77.738 min
# Mean IoU                 = 0.539
#
# Image nb 27
# Time spent               = 46.213 sec
# Estimated time remaining = 79.360 min
# Mean IoU                 = 0.540
#
# Image nb 28
# Time spent               = 48.631 sec
# Estimated time remaining = 80.604 min
# Mean IoU                 = 0.526
#
# Image nb 29
# Time spent               = 49.794 sec
# Estimated time remaining = 79.754 min
# Mean IoU                 = 0.497
#
# Image nb 30
# Time spent               = 50.746 sec
# Estimated time remaining = 78.629 min
# Mean IoU                 = 0.499
#
# Image nb 31
# Time spent               = 51.470 sec
# Estimated time remaining = 77.232 min
# Mean IoU                 = 0.502
#
# Image nb 32
# Time spent               = 52.553 sec
# Estimated time remaining = 76.441 min
# Mean IoU                 = 0.507
#
# Image nb 33
# Time spent               = 53.374 sec
# Estimated time remaining = 75.325 min
# Mean IoU                 = 0.508
#
# Image nb 34
# Time spent               = 54.473 sec
# Estimated time remaining = 74.654 min
# Mean IoU                 = 0.497
#
# Image nb 35
# Time spent               = 56.010 sec
# Estimated time remaining = 74.603 min
# Mean IoU                 = 0.493
#
# Image nb 36
# Time spent               = 56.646 sec
# Estimated time remaining = 73.385 min
# Mean IoU                 = 0.490
#
# Image nb 37
# Time spent               = 57.877 sec
# Estimated time remaining = 72.981 min
# Mean IoU                 = 0.490
#
# Image nb 38
# Time spent               = 60.819 sec
# Estimated time remaining = 74.699 min
# Mean IoU                 = 0.489
#
# Image nb 39
# Time spent               = 62.605 sec
# Estimated time remaining = 74.944 min
# Mean IoU                 = 0.468
#
# Image nb 40
# Time spent               = 63.513 sec
# Estimated time remaining = 74.151 min
# Mean IoU                 = 0.473
#
# Image nb 41
# Time spent               = 66.017 sec
# Estimated time remaining = 75.213 min
# Mean IoU                 = 0.464
#
# Image nb 42
# Time spent               = 67.076 sec
# Estimated time remaining = 74.616 min
# Mean IoU                 = 0.468
#
# Image nb 43
# Time spent               = 67.831 sec
# Estimated time remaining = 73.715 min
# Mean IoU                 = 0.473
#
# Image nb 44
# Time spent               = 68.208 sec
# Estimated time remaining = 72.452 min
# Mean IoU                 = 0.470
#
# Image nb 45
# Time spent               = 70.581 sec
# Estimated time remaining = 73.317 min
# Mean IoU                 = 0.444
#
# Image nb 46
# Time spent               = 72.040 sec
# Estimated time remaining = 73.215 min
# Mean IoU                 = 0.449
#
# Image nb 47
# Time spent               = 72.343 sec
# Estimated time remaining = 71.966 min
# Mean IoU                 = 0.452
#
# Image nb 48
# Time spent               = 76.251 sec
# Estimated time remaining = 74.280 min
# Mean IoU                 = 0.454
#
# Image nb 49
# Time spent               = 78.430 sec
# Estimated time remaining = 74.848 min
# Mean IoU                 = 0.456
#
# Image nb 50
# Time spent               = 79.960 sec
# Estimated time remaining = 74.786 min
# Mean IoU                 = 0.457
#
# Image nb 51
# Time spent               = 83.484 sec
# Estimated time remaining = 76.554 min
# Mean IoU                 = 0.444
#
# Image nb 52
# Time spent               = 85.496 sec
# Estimated time remaining = 76.893 min
# Mean IoU                 = 0.446
#
# Image nb 53
# Time spent               = 86.620 sec
# Estimated time remaining = 76.434 min
# Mean IoU                 = 0.442
#
# Image nb 54
# Time spent               = 87.438 sec
# Estimated time remaining = 75.727 min
# Mean IoU                 = 0.447
#
# Image nb 55
# Time spent               = 89.241 sec
# Estimated time remaining = 75.881 min
# Mean IoU                 = 0.445
#
# Image nb 56
# Time spent               = 90.042 sec
# Estimated time remaining = 75.193 min
# Mean IoU                 = 0.446
#
# Image nb 57
# Time spent               = 90.302 sec
# Estimated time remaining = 74.084 min
# Mean IoU                 = 0.446
#
# Image nb 58
# Time spent               = 91.576 sec
# Estimated time remaining = 73.830 min
# Mean IoU                 = 0.450
#
# Image nb 59
# Time spent               = 92.113 sec
# Estimated time remaining = 73.000 min
# Mean IoU                 = 0.456
#
# Image nb 60
# Time spent               = 93.943 sec
# Estimated time remaining = 73.204 min
# Mean IoU                 = 0.458
#
# Image nb 61
# Time spent               = 95.395 sec
# Estimated time remaining = 73.110 min
# Mean IoU                 = 0.461
#
# Image nb 62
# Time spent               = 96.418 sec
# Estimated time remaining = 72.696 min
# Mean IoU                 = 0.467
#
# Image nb 63
# Time spent               = 97.351 sec
# Estimated time remaining = 72.228 min
# Mean IoU                 = 0.471
#
# Image nb 64
# Time spent               = 99.424 sec
# Estimated time remaining = 72.605 min
# Mean IoU                 = 0.484
#
# Image nb 65
# Time spent               = 101.382 sec
# Estimated time remaining = 72.887 min
# Mean IoU                 = 0.478
#
# Image nb 66
# Time spent               = 102.882 sec
# Estimated time remaining = 72.837 min
# Mean IoU                 = 0.483
#
# Image nb 67
# Time spent               = 103.450 sec
# Estimated time remaining = 72.136 min
# Mean IoU                 = 0.483
# Image nb 68
# Time spent               = 105.043 sec
# Estimated time remaining = 72.160 min
# Mean IoU                 = 0.483
#
# Image nb 69
# Time spent               = 106.655 sec
# Estimated time remaining = 72.195 min
# Mean IoU                 = 0.486
#
# Image nb 70
# Time spent               = 107.169 sec
# Estimated time remaining = 71.497 min
# Mean IoU                 = 0.488
#
# Image nb 71
# Time spent               = 108.440 sec
# Estimated time remaining = 71.314 min
# Mean IoU                 = 0.492
#
# Image nb 72
# Time spent               = 113.038 sec
# Estimated time remaining = 73.294 min
# Mean IoU                 = 0.492
#
# Image nb 73
# Time spent               = 114.445 sec
# Estimated time remaining = 73.178 min
# Mean IoU                 = 0.495
#
# Image nb 74
# Time spent               = 114.766 sec
# Estimated time remaining = 72.379 min
# Mean IoU                 = 0.498
#
# Image nb 75
# Time spent               = 117.398 sec
# Estimated time remaining = 73.039 min
# Mean IoU                 = 0.501
#
# Image nb 76
# Time spent               = 120.752 sec
# Estimated time remaining = 74.124 min
# Mean IoU                 = 0.488
#
# Image nb 77
# Time spent               = 122.036 sec
# Estimated time remaining = 73.926 min
# Mean IoU                 = 0.489
#
# Image nb 78
# Time spent               = 123.748 sec
# Estimated time remaining = 73.988 min
# Mean IoU                 = 0.487
#
# Image nb 79
# Time spent               = 124.089 sec
# Estimated time remaining = 73.239 min
# Mean IoU                 = 0.487
#
# Image nb 80
# Time spent               = 124.355 sec
# Estimated time remaining = 72.463 min
# Mean IoU                 = 0.489
#
# Image nb 81
# Time spent               = 126.949 sec
# Estimated time remaining = 73.047 min
# Mean IoU                 = 0.486
#
# Image nb 82
# Time spent               = 129.718 sec
# Estimated time remaining = 73.715 min
# Mean IoU                 = 0.485
#
# Image nb 83
# Time spent               = 130.989 sec
# Estimated time remaining = 73.526 min
# Mean IoU                 = 0.485
#
# Image nb 84
# Time spent               = 131.722 sec
# Estimated time remaining = 73.041 min
# Mean IoU                 = 0.485
#
# Image nb 85
# Time spent               = 134.462 sec
# Estimated time remaining = 73.667 min
# Mean IoU                 = 0.489
#
# Image nb 86
# Time spent               = 135.966 sec
# Estimated time remaining = 73.609 min
# Mean IoU                 = 0.489
#
# Image nb 87
# Time spent               = 136.772 sec
# Estimated time remaining = 73.178 min
# Mean IoU                 = 0.491
#
# Image nb 88
# Time spent               = 137.135 sec
# Estimated time remaining = 72.522 min
# Mean IoU                 = 0.493
#
# Image nb 89
# Time spent               = 137.454 sec
# Estimated time remaining = 71.858 min
# Mean IoU                 = 0.492
#
# Image nb 90
# Time spent               = 139.986 sec
# Estimated time remaining = 72.352 min
# Mean IoU                 = 0.486
#
# Image nb 91
# Time spent               = 143.136 sec
# Estimated time remaining = 73.150 min
# Mean IoU                 = 0.487
#
# Image nb 92
# Time spent               = 144.788 sec
# Estimated time remaining = 73.173 min
# Mean IoU                 = 0.488
#
# Image nb 93
# Time spent               = 146.390 sec
# Estimated time remaining = 73.169 min
# Mean IoU                 = 0.488
#
# Image nb 94
# Time spent               = 146.771 sec
# Estimated time remaining = 72.562 min
# Mean IoU                 = 0.486
#
# Image nb 95
# Time spent               = 149.252 sec
# Estimated time remaining = 72.993 min
# Mean IoU                 = 0.475
#
# Image nb 96
# Time spent               = 150.617 sec
# Estimated time remaining = 72.876 min
# Mean IoU                 = 0.475
#
# Image nb 97
# Time spent               = 151.585 sec
# Estimated time remaining = 72.570 min
# Mean IoU                 = 0.478
#
# Image nb 98
# Time spent               = 154.045 sec
# Estimated time remaining = 72.977 min
# Mean IoU                 = 0.472
#
# Image nb 99
# Time spent               = 156.902 sec
# Estimated time remaining = 73.561 min
# Mean IoU                 = 0.474
#
# Image nb 100
# Time spent               = 158.018 sec
# Estimated time remaining = 73.325 min
# Mean IoU                 = 0.476
#
# Image nb 101
# Time spent               = 160.745 sec
# Estimated time remaining = 73.833 min
# Mean IoU                 = 0.475
#
# Image nb 102
# Time spent               = 161.652 sec
# Estimated time remaining = 73.502 min
# Mean IoU                 = 0.475
#
# Image nb 103
# Time spent               = 162.203 sec
# Estimated time remaining = 73.017 min
# Mean IoU                 = 0.477
#
# Image nb 104
# Time spent               = 165.145 sec
# Estimated time remaining = 73.607 min
# Mean IoU                 = 0.476
#
# Image nb 105
# Time spent               = 167.517 sec
# Estimated time remaining = 73.934 min
# Mean IoU                 = 0.478
#
# Image nb 106
# Time spent               = 167.864 sec
# Estimated time remaining = 73.369 min
# Mean IoU                 = 0.480
#
# Image nb 107
# Time spent               = 175.679 sec
# Estimated time remaining = 76.046 min
# Mean IoU                 = 0.486
#
# Image nb 108
# Time spent               = 176.186 sec
# Estimated time remaining = 75.539 min
# Mean IoU                 = 0.487
#
# Image nb 109
# Time spent               = 181.143 sec
# Estimated time remaining = 76.931 min
# Mean IoU                 = 0.486
#
# Image nb 110
# Time spent               = 182.928 sec
# Estimated time remaining = 76.962 min
# Mean IoU                 = 0.489
#
# Image nb 111
# Time spent               = 183.561 sec
# Estimated time remaining = 76.511 min
# Mean IoU                 = 0.491
#
# Image nb 112
# Time spent               = 185.241 sec
# Estimated time remaining = 76.501 min
# Mean IoU                 = 0.492
#
# Image nb 113
# Time spent               = 186.755 sec
# Estimated time remaining = 76.422 min
# Mean IoU                 = 0.492
#
# Image nb 114
# Time spent               = 190.899 sec
# Estimated time remaining = 77.411 min
# Mean IoU                 = 0.500
#
# Image nb 115
# Time spent               = 191.885 sec
# Estimated time remaining = 77.112 min
# Mean IoU                 = 0.500
#
# Image nb 116
# Time spent               = 193.454 sec
# Estimated time remaining = 77.051 min
# Mean IoU                 = 0.502
#
# Image nb 117
# Time spent               = 195.258 sec
# Estimated time remaining = 77.083 min
# Mean IoU                 = 0.503
#
# Image nb 118
# Time spent               = 196.203 sec
# Estimated time remaining = 76.777 min
# Mean IoU                 = 0.499
#
# Image nb 119
# Time spent               = 196.743 sec
# Estimated time remaining = 76.320 min
# Mean IoU                 = 0.496
#
# Image nb 120
# Time spent               = 197.191 sec
# Estimated time remaining = 75.834 min
# Mean IoU                 = 0.497
#
# Image nb 121
# Time spent               = 198.839 sec
# Estimated time remaining = 75.814 min
# Mean IoU                 = 0.498
#
# Image nb 122
# Time spent               = 202.169 sec
# Estimated time remaining = 76.430 min
# Mean IoU                 = 0.498
#
# Image nb 123
# Time spent               = 205.623 sec
# Estimated time remaining = 77.081 min
# Mean IoU                 = 0.494
#
# Image nb 124
# Time spent               = 206.461 sec
# Estimated time remaining = 76.748 min
# Mean IoU                 = 0.496
#
# Image nb 125
# Time spent               = 207.921 sec
# Estimated time remaining = 76.650 min
# Mean IoU                 = 0.497
#
# Image nb 126
# Time spent               = 209.173 sec
# Estimated time remaining = 76.477 min
# Mean IoU                 = 0.497
#
# Image nb 127
# Time spent               = 209.967 sec
# Estimated time remaining = 76.140 min
# Mean IoU                 = 0.498
#
# Image nb 128
# Time spent               = 210.258 sec
# Estimated time remaining = 75.628 min
# Mean IoU                 = 0.499
#
# Image nb 129
# Time spent               = 212.758 sec
# Estimated time remaining = 75.911 min
# Mean IoU                 = 0.498
#
# Image nb 130
# Time spent               = 215.504 sec
# Estimated time remaining = 76.276 min
# Mean IoU                 = 0.499
#
# Image nb 131
# Time spent               = 215.848 sec
# Estimated time remaining = 75.792 min
# Mean IoU                 = 0.500
#
# Image nb 132
# Time spent               = 216.994 sec
# Estimated time remaining = 75.594 min
# Mean IoU                 = 0.500
#
# Image nb 133
# Time spent               = 217.666 sec
# Estimated time remaining = 75.236 min
# Mean IoU                 = 0.499
#
# Image nb 134
# Time spent               = 218.180 sec
# Estimated time remaining = 74.828 min
# Mean IoU                 = 0.500
# Image nb 135
# Time spent               = 219.388 sec
# Estimated time remaining = 74.662 min
# Mean IoU                 = 0.501
#
# Image nb 136
# Time spent               = 222.214 sec
# Estimated time remaining = 75.045 min
# Mean IoU                 = 0.501
#
# Image nb 137
# Time spent               = 223.087 sec
# Estimated time remaining = 74.766 min
# Mean IoU                 = 0.503
#
# Image nb 138
# Time spent               = 223.977 sec
# Estimated time remaining = 74.498 min
# Mean IoU                 = 0.504
#
# Image nb 139
# Time spent               = 225.701 sec
# Estimated time remaining = 74.508 min
# Mean IoU                 = 0.505
#
# Image nb 140
# Time spent               = 227.584 sec
# Estimated time remaining = 74.570 min
# Mean IoU                 = 0.506
#
# Image nb 141
# Time spent               = 227.912 sec
# Estimated time remaining = 74.125 min
# Mean IoU                 = 0.506
#
# Image nb 142
# Time spent               = 228.518 sec
# Estimated time remaining = 73.776 min
# Mean IoU                 = 0.506
#
# Image nb 143
# Time spent               = 230.655 sec
# Estimated time remaining = 73.922 min
# Mean IoU                 = 0.504
#
# Image nb 144
# Time spent               = 232.578 sec
# Estimated time remaining = 73.997 min
# Mean IoU                 = 0.505
#
# Image nb 145
# Time spent               = 233.392 sec
# Estimated time remaining = 73.721 min
# Mean IoU                 = 0.506
#
# Image nb 146
# Time spent               = 235.016 sec
# Estimated time remaining = 73.702 min
# Mean IoU                 = 0.503
#
# Image nb 147
# Time spent               = 236.217 sec
# Estimated time remaining = 73.552 min
# Mean IoU                 = 0.502
#
# Image nb 148
# Time spent               = 237.147 sec
# Estimated time remaining = 73.319 min
# Mean IoU                 = 0.502
#
# Image nb 149
# Time spent               = 243.289 sec
# Estimated time remaining = 74.690 min
# Mean IoU                 = 0.497
#
# Image nb 150
# Time spent               = 244.593 sec
# Estimated time remaining = 74.566 min
# Mean IoU                 = 0.496
#
# Image nb 151
# Time spent               = 245.329 sec
# Estimated time remaining = 74.271 min
# Mean IoU                 = 0.497
#
# Image nb 152
# Time spent               = 246.434 sec
# Estimated time remaining = 74.091 min
# Mean IoU                 = 0.497
#
# Image nb 153
# Time spent               = 247.087 sec
# Estimated time remaining = 73.778 min
# Mean IoU                 = 0.495
#
# Image nb 154
# Time spent               = 248.862 sec
# Estimated time remaining = 73.802 min
# Mean IoU                 = 0.494
#
# Image nb 155
# Time spent               = 249.430 sec
# Estimated time remaining = 73.470 min
# Mean IoU                 = 0.496
#
# Image nb 156
# Time spent               = 250.508 sec
# Estimated time remaining = 73.291 min
# Mean IoU                 = 0.497
#
# Image nb 157
# Time spent               = 251.313 sec
# Estimated time remaining = 73.035 min
# Mean IoU                 = 0.497
#
# Image nb 158
# Time spent               = 253.618 sec
# Estimated time remaining = 73.214 min
# Mean IoU                 = 0.498
#
# Image nb 159
# Time spent               = 257.665 sec
# Estimated time remaining = 73.891 min
# Mean IoU                 = 0.498
#
# Image nb 160
# Time spent               = 259.788 sec
# Estimated time remaining = 74.010 min
# Mean IoU                 = 0.499
#
# Image nb 161
# Time spent               = 262.842 sec
# Estimated time remaining = 74.391 min
# Mean IoU                 = 0.500
#
# Image nb 162
# Time spent               = 264.641 sec
# Estimated time remaining = 74.413 min
# Mean IoU                 = 0.500
#
# Image nb 163
# Time spent               = 266.187 sec
# Estimated time remaining = 74.365 min
# Mean IoU                 = 0.500
#
# Image nb 164
# Time spent               = 269.835 sec
# Estimated time remaining = 74.900 min
# Mean IoU                 = 0.499
#
# Image nb 165
# Time spent               = 271.374 sec
# Estimated time remaining = 74.846 min
# Mean IoU                 = 0.499
#
# Image nb 166
# Time spent               = 271.981 sec
# Estimated time remaining = 74.537 min
# Mean IoU                 = 0.500
#
# Image nb 167
# Time spent               = 273.409 sec
# Estimated time remaining = 74.455 min
# Mean IoU                 = 0.501
#
# Image nb 168
# Time spent               = 274.558 sec
# Estimated time remaining = 74.299 min
# Mean IoU                 = 0.499
#
# Image nb 169
# Time spent               = 276.007 sec
# Estimated time remaining = 74.224 min
# Mean IoU                 = 0.499
#
# Image nb 170
# Time spent               = 277.779 sec
# Estimated time remaining = 74.237 min
# Mean IoU                 = 0.500
#
# Image nb 171
# Time spent               = 280.781 sec
# Estimated time remaining = 74.576 min
# Mean IoU                 = 0.495
#
# Image nb 172
# Time spent               = 282.329 sec
# Estimated time remaining = 74.526 min
# Mean IoU                 = 0.493
#
# Image nb 173
# Time spent               = 284.076 sec
# Estimated time remaining = 74.529 min
# Mean IoU                 = 0.498
#
# Image nb 174
# Time spent               = 287.687 sec
# Estimated time remaining = 75.018 min
# Mean IoU                 = 0.499
#
# Image nb 175
# Time spent               = 289.903 sec
# Estimated time remaining = 75.139 min
# Mean IoU                 = 0.500
#
# Image nb 176
# Time spent               = 293.386 sec
# Estimated time remaining = 75.584 min
# Mean IoU                 = 0.493
#
# Image nb 177
# Time spent               = 294.948 sec
# Estimated time remaining = 75.532 min
# Mean IoU                 = 0.494
#
# Image nb 178
# Time spent               = 296.475 sec
# Estimated time remaining = 75.471 min
# Mean IoU                 = 0.494
#
# Image nb 179
# Time spent               = 298.542 sec
# Estimated time remaining = 75.548 min
# Mean IoU                 = 0.495
#
# Image nb 180
# Time spent               = 301.360 sec
# Estimated time remaining = 75.812 min
# Mean IoU                 = 0.496
#
# Image nb 181
# Time spent               = 302.120 sec
# Estimated time remaining = 75.558 min
# Mean IoU                 = 0.494
#
# Image nb 182
# Time spent               = 303.695 sec
# Estimated time remaining = 75.509 min
# Mean IoU                 = 0.493
#
# Image nb 183
# Time spent               = 305.417 sec
# Estimated time remaining = 75.497 min
# Mean IoU                 = 0.494
#
# Image nb 184
# Time spent               = 307.353 sec
# Estimated time remaining = 75.537 min
# Mean IoU                 = 0.494
#
# Image nb 185
# Time spent               = 309.675 sec
# Estimated time remaining = 75.671 min
# Mean IoU                 = 0.497
#
# Image nb 186
# Time spent               = 310.582 sec
# Estimated time remaining = 75.459 min
# Mean IoU                 = 0.498
#
# Image nb 187
# Time spent               = 311.913 sec
# Estimated time remaining = 75.351 min
# Mean IoU                 = 0.498
#
# Image nb 188
# Time spent               = 312.233 sec
# Estimated time remaining = 75.002 min
# Mean IoU                 = 0.499
#
# Image nb 189
# Time spent               = 315.754 sec
# Estimated time remaining = 75.421 min
# Mean IoU                 = 0.498
#
# Image nb 190
# Time spent               = 318.403 sec
# Estimated time remaining = 75.628 min
# Mean IoU                 = 0.497
#
# Image nb 191
# Time spent               = 319.167 sec
# Estimated time remaining = 75.387 min
# Mean IoU                 = 0.496
#
# Image nb 192
# Time spent               = 319.450 sec
# Estimated time remaining = 75.035 min
# Mean IoU                 = 0.497
#
# Image nb 193
# Time spent               = 322.718 sec
# Estimated time remaining = 75.384 min
# Mean IoU                 = 0.496
#
# Image nb 194
# Time spent               = 326.085 sec
# Estimated time remaining = 75.752 min
# Mean IoU                 = 0.495
#
# Image nb 195
# Time spent               = 327.538 sec
# Estimated time remaining = 75.673 min
# Mean IoU                 = 0.496
#
# Image nb 196
# Time spent               = 328.234 sec
# Estimated time remaining = 75.422 min
# Mean IoU                 = 0.496
#
# Image nb 197
# Time spent               = 330.067 sec
# Estimated time remaining = 75.432 min
# Mean IoU                 = 0.500
#
# Image nb 198
# Time spent               = 330.378 sec
# Estimated time remaining = 75.096 min
# Mean IoU                 = 0.500
#
# Image nb 199
# Time spent               = 331.976 sec
# Estimated time remaining = 75.054 min
# Mean IoU                 = 0.502
#
# Image nb 200
# Time spent               = 333.062 sec
# Estimated time remaining = 74.897 min
# Mean IoU                 = 0.503
#
# Image nb 201
# Time spent               = 333.570 sec
# Estimated time remaining = 74.613 min
# Mean IoU                 = 0.504
# Image nb 202
# Time spent               = 335.417 sec
# Estimated time remaining = 74.629 min
# Mean IoU                 = 0.505
#
# Image nb 203
# Time spent               = 336.984 sec
# Estimated time remaining = 74.583 min
# Mean IoU                 = 0.504
#
# Image nb 204
# Time spent               = 340.820 sec
# Estimated time remaining = 75.036 min
# Mean IoU                 = 0.504
#
# Image nb 205
# Time spent               = 344.048 sec
# Estimated time remaining = 75.351 min
# Mean IoU                 = 0.505
#
# Image nb 206
# Time spent               = 350.144 sec
# Estimated time remaining = 76.287 min
# Mean IoU                 = 0.502
#
# Image nb 207
# Time spent               = 352.301 sec
# Estimated time remaining = 76.360 min
# Mean IoU                 = 0.503
#
# Image nb 208
# Time spent               = 355.006 sec
# Estimated time remaining = 76.550 min
# Mean IoU                 = 0.503
#
# Image nb 209
# Time spent               = 355.797 sec
# Estimated time remaining = 76.327 min
# Mean IoU                 = 0.503
#
# Image nb 210
# Time spent               = 361.536 sec
# Estimated time remaining = 77.162 min
# Mean IoU                 = 0.503
#
# Image nb 211
# Time spent               = 362.925 sec
# Estimated time remaining = 77.064 min
# Mean IoU                 = 0.503
#
# Image nb 212
# Time spent               = 365.993 sec
# Estimated time remaining = 77.322 min
# Mean IoU                 = 0.496
#
# Image nb 213
# Time spent               = 369.047 sec
# Estimated time remaining = 77.575 min
# Mean IoU                 = 0.494
#
# Image nb 214
# Time spent               = 370.050 sec
# Estimated time remaining = 77.395 min
# Mean IoU                 = 0.494
#
# Image nb 215
# Time spent               = 371.228 sec
# Estimated time remaining = 77.253 min
# Mean IoU                 = 0.495
#
# Image nb 216
# Time spent               = 372.096 sec
# Estimated time remaining = 77.048 min
# Mean IoU                 = 0.495
#
# Image nb 217
# Time spent               = 373.585 sec
# Estimated time remaining = 76.973 min
# Mean IoU                 = 0.496
#
# Image nb 218
# Time spent               = 376.183 sec
# Estimated time remaining = 77.126 min
# Mean IoU                 = 0.492
#
# Image nb 219
# Time spent               = 377.298 sec
# Estimated time remaining = 76.975 min
# Mean IoU                 = 0.494
#
# Image nb 220
# Time spent               = 378.973 sec
# Estimated time remaining = 76.938 min
# Mean IoU                 = 0.495
#
# Image nb 221
# Time spent               = 380.084 sec
# Estimated time remaining = 76.787 min
# Mean IoU                 = 0.497
#
# Image nb 222
# Time spent               = 381.882 sec
# Estimated time remaining = 76.776 min
# Mean IoU                 = 0.497
#
# Image nb 223
# Time spent               = 383.896 sec
# Estimated time remaining = 76.808 min
# Mean IoU                 = 0.496
#
# Image nb 224
# Time spent               = 384.745 sec
# Estimated time remaining = 76.607 min
# Mean IoU                 = 0.496
#
# Image nb 225
# Time spent               = 385.297 sec
# Estimated time remaining = 76.349 min
# Mean IoU                 = 0.497
#
# Image nb 226
# Time spent               = 387.729 sec
# Estimated time remaining = 76.464 min
# Mean IoU                 = 0.497
#
# Image nb 227
# Time spent               = 389.834 sec
# Estimated time remaining = 76.513 min
# Mean IoU                 = 0.497
#
# Image nb 228
# Time spent               = 392.947 sec
# Estimated time remaining = 76.759 min
# Mean IoU                 = 0.497
#
# Image nb 229
# Time spent               = 393.618 sec
# Estimated time remaining = 76.527 min
# Mean IoU                 = 0.497
#
# Image nb 230
# Time spent               = 394.971 sec
# Estimated time remaining = 76.429 min
# Mean IoU                 = 0.497
#
# Image nb 231
# Time spent               = 395.971 sec
# Estimated time remaining = 76.264 min
# Mean IoU                 = 0.497
#
# Image nb 232
# Time spent               = 396.932 sec
# Estimated time remaining = 76.093 min
# Mean IoU                 = 0.498
#
# Image nb 233
# Time spent               = 397.850 sec
# Estimated time remaining = 75.915 min
# Mean IoU                 = 0.499
#
# Image nb 234
# Time spent               = 399.314 sec
# Estimated time remaining = 75.841 min
# Mean IoU                 = 0.500
#
# Image nb 235
# Time spent               = 399.990 sec
# Estimated time remaining = 75.620 min
# Mean IoU                 = 0.498
#
# Image nb 236
# Time spent               = 401.280 sec
# Estimated time remaining = 75.515 min
# Mean IoU                 = 0.497
#
# Image nb 237
# Time spent               = 401.769 sec
# Estimated time remaining = 75.261 min
# Mean IoU                 = 0.498
#
# Image nb 238
# Time spent               = 402.426 sec
# Estimated time remaining = 75.041 min
# Mean IoU                 = 0.496
#
# Image nb 239
# Time spent               = 405.276 sec
# Estimated time remaining = 75.229 min
# Mean IoU                 = 0.492
#
# Image nb 240
# Time spent               = 405.702 sec
# Estimated time remaining = 74.968 min
# Mean IoU                 = 0.492
#
# Image nb 241
# Time spent               = 406.720 sec
# Estimated time remaining = 74.817 min
# Mean IoU                 = 0.493
#
# Image nb 242
# Time spent               = 407.203 sec
# Estimated time remaining = 74.570 min
# Mean IoU                 = 0.494
#
# Image nb 243
# Time spent               = 413.711 sec
# Estimated time remaining = 75.423 min
# Mean IoU                 = 0.493
#
# Image nb 244
# Time spent               = 413.957 sec
# Estimated time remaining = 75.132 min
# Mean IoU                 = 0.494
#
# Image nb 245
# Time spent               = 416.698 sec
# Estimated time remaining = 75.294 min
# Mean IoU                 = 0.495
#
# Image nb 246
# Time spent               = 418.114 sec
# Estimated time remaining = 75.215 min
# Mean IoU                 = 0.494
#
# Image nb 247
# Time spent               = 420.471 sec
# Estimated time remaining = 75.306 min
# Mean IoU                 = 0.494
#
# Image nb 248
# Time spent               = 420.803 sec
# Estimated time remaining = 75.035 min
# Mean IoU                 = 0.495
#
# Image nb 249
# Time spent               = 421.719 sec
# Estimated time remaining = 74.869 min
# Mean IoU                 = 0.495
#
# Image nb 250
# Time spent               = 422.052 sec
# Estimated time remaining = 74.602 min
# Mean IoU                 = 0.496
#
# Image nb 251
# Time spent               = 422.346 sec
# Estimated time remaining = 74.330 min
# Mean IoU                 = 0.496
#
# Image nb 252
# Time spent               = 425.903 sec
# Estimated time remaining = 74.631 min
# Mean IoU                 = 0.494
#
# Image nb 253
# Time spent               = 426.544 sec
# Estimated time remaining = 74.421 min
# Mean IoU                 = 0.494
#
# Image nb 254
# Time spent               = 427.512 sec
# Estimated time remaining = 74.270 min
# Mean IoU                 = 0.495
#
# Image nb 255
# Time spent               = 428.719 sec
# Estimated time remaining = 74.161 min
# Mean IoU                 = 0.495
#
# Image nb 256
# Time spent               = 429.392 sec
# Estimated time remaining = 73.960 min
# Mean IoU                 = 0.496
#
# Image nb 257
# Time spent               = 431.686 sec
# Estimated time remaining = 74.039 min
# Mean IoU                 = 0.496
#
# Image nb 258
# Time spent               = 432.128 sec
# Estimated time remaining = 73.801 min
# Mean IoU                 = 0.496
#
# Image nb 259
# Time spent               = 435.124 sec
# Estimated time remaining = 73.999 min
# Mean IoU                 = 0.497
#
# Image nb 260
# Time spent               = 435.422 sec
# Estimated time remaining = 73.738 min
# Mean IoU                 = 0.498
#
# Image nb 261
# Time spent               = 436.846 sec
# Estimated time remaining = 73.669 min
# Mean IoU                 = 0.499
#
# Image nb 262
# Time spent               = 439.007 sec
# Estimated time remaining = 73.724 min
# Mean IoU                 = 0.497
#
# Image nb 263
# Time spent               = 441.336 sec
# Estimated time remaining = 73.807 min
# Mean IoU                 = 0.498
#
# Image nb 264
# Time spent               = 442.359 sec
# Estimated time remaining = 73.671 min
# Mean IoU                 = 0.498
#
# Image nb 265
# Time spent               = 442.868 sec
# Estimated time remaining = 73.451 min
# Mean IoU                 = 0.499
#
# Image nb 266
# Time spent               = 445.974 sec
# Estimated time remaining = 73.661 min
# Mean IoU                 = 0.495
#
# Image nb 267
# Time spent               = 446.628 sec
# Estimated time remaining = 73.466 min
# Mean IoU                 = 0.495
#
# Image nb 268
# Time spent               = 446.949 sec
# Estimated time remaining = 73.218 min
# Mean IoU                 = 0.495
# Image nb 269
# Time spent               = 448.292 sec
# Estimated time remaining = 73.138 min
# Mean IoU                 = 0.495
#
# Image nb 270
# Time spent               = 448.784 sec
# Estimated time remaining = 72.920 min
# Mean IoU                 = 0.495
#
# Image nb 271
# Time spent               = 451.075 sec
# Estimated time remaining = 72.996 min
# Mean IoU                 = 0.494
#
# Image nb 272
# Time spent               = 453.411 sec
# Estimated time remaining = 73.077 min
# Mean IoU                 = 0.493
#
# Image nb 273
# Time spent               = 456.438 sec
# Estimated time remaining = 73.269 min
# Mean IoU                 = 0.494
#
# Image nb 274
# Time spent               = 460.252 sec
# Estimated time remaining = 73.585 min
# Mean IoU                 = 0.495
#
# Image nb 275
# Time spent               = 460.595 sec
# Estimated time remaining = 73.345 min
# Mean IoU                 = 0.495
#
# Image nb 276
# Time spent               = 467.417 sec
# Estimated time remaining = 74.134 min
# Mean IoU                 = 0.494
#
# Image nb 277
# Time spent               = 470.111 sec
# Estimated time remaining = 74.265 min
# Mean IoU                 = 0.493
#
# Image nb 278
# Time spent               = 475.294 sec
# Estimated time remaining = 74.786 min
# Mean IoU                 = 0.492
#
# Image nb 279
# Time spent               = 478.572 sec
# Estimated time remaining = 75.005 min
# Mean IoU                 = 0.492
#
# Image nb 280
# Time spent               = 481.573 sec
# Estimated time remaining = 75.178 min
# Mean IoU                 = 0.490
#
# Image nb 281
# Time spent               = 482.164 sec
# Estimated time remaining = 74.975 min
# Mean IoU                 = 0.491
#
# Image nb 282
# Time spent               = 486.577 sec
# Estimated time remaining = 75.365 min
# Mean IoU                 = 0.489
#
# Image nb 283
# Time spent               = 488.973 sec
# Estimated time remaining = 75.441 min
# Mean IoU                 = 0.490
#
# Image nb 284
# Time spent               = 489.911 sec
# Estimated time remaining = 75.292 min
# Mean IoU                 = 0.491
#
# Image nb 285
# Time spent               = 491.839 sec
# Estimated time remaining = 75.295 min
# Mean IoU                 = 0.491
#
# Image nb 286
# Time spent               = 493.084 sec
# Estimated time remaining = 75.194 min
# Mean IoU                 = 0.492
#
# Image nb 287
# Time spent               = 496.682 sec
# Estimated time remaining = 75.451 min
# Mean IoU                 = 0.489
#
# Image nb 288
# Time spent               = 497.905 sec
# Estimated time remaining = 75.346 min
# Mean IoU                 = 0.489
#
# Image nb 289
# Time spent               = 499.290 sec
# Estimated time remaining = 75.267 min
# Mean IoU                 = 0.491
#
# Image nb 290
# Time spent               = 500.184 sec
# Estimated time remaining = 75.114 min
# Mean IoU                 = 0.491
#
# Image nb 291
# Time spent               = 501.319 sec
# Estimated time remaining = 74.997 min
# Mean IoU                 = 0.491
#
# Image nb 292
# Time spent               = 502.458 sec
# Estimated time remaining = 74.883 min
# Mean IoU                 = 0.490
#
# Image nb 293
# Time spent               = 503.010 sec
# Estimated time remaining = 74.682 min
# Mean IoU                 = 0.491
#
# Image nb 294
# Time spent               = 503.669 sec
# Estimated time remaining = 74.497 min
# Mean IoU                 = 0.491
#
# Image nb 295
# Time spent               = 504.434 sec
# Estimated time remaining = 74.330 min
# Mean IoU                 = 0.491
#
# Image nb 296
# Time spent               = 510.417 sec
# Estimated time remaining = 74.930 min
# Mean IoU                 = 0.487
#
# Image nb 297
# Time spent               = 512.049 sec
# Estimated time remaining = 74.889 min
# Mean IoU                 = 0.486
#
# Image nb 298
# Time spent               = 513.575 sec
# Estimated time remaining = 74.832 min
# Mean IoU                 = 0.487
#
# Image nb 299
# Time spent               = 516.745 sec
# Estimated time remaining = 75.014 min
# Mean IoU                 = 0.485
#
# Image nb 300
# Time spent               = 519.109 sec
# Estimated time remaining = 75.078 min
# Mean IoU                 = 0.481
#
# Image nb 301
# Time spent               = 519.692 sec
# Estimated time remaining = 74.885 min
# Mean IoU                 = 0.481
#
# Image nb 302
# Time spent               = 520.276 sec
# Estimated time remaining = 74.693 min
# Mean IoU                 = 0.483
#
# Image nb 303
# Time spent               = 521.675 sec
# Estimated time remaining = 74.619 min
# Mean IoU                 = 0.483
#
# Image nb 304
# Time spent               = 523.150 sec
# Estimated time remaining = 74.556 min
# Mean IoU                 = 0.484
#
# Image nb 305
# Time spent               = 526.586 sec
# Estimated time remaining = 74.772 min
# Mean IoU                 = 0.484
#
# Image nb 306
# Time spent               = 528.061 sec
# Estimated time remaining = 74.708 min
# Mean IoU                 = 0.484
#
# Image nb 307
# Time spent               = 529.240 sec
# Estimated time remaining = 74.603 min
# Mean IoU                 = 0.484
#
# Image nb 308
# Time spent               = 529.551 sec
# Estimated time remaining = 74.377 min
# Mean IoU                 = 0.485
#
# Image nb 309
# Time spent               = 535.347 sec
# Estimated time remaining = 74.920 min
# Mean IoU                 = 0.485
#
# Image nb 310
# Time spent               = 536.390 sec
# Estimated time remaining = 74.796 min
# Mean IoU                 = 0.485
#
# Image nb 311
# Time spent               = 536.610 sec
# Estimated time remaining = 74.558 min
# Mean IoU                 = 0.486
#
# Image nb 312
# Time spent               = 537.255 sec
# Estimated time remaining = 74.380 min
# Mean IoU                 = 0.484
#
# Image nb 313
# Time spent               = 537.998 sec
# Estimated time remaining = 74.217 min
# Mean IoU                 = 0.485
#
# Image nb 314
# Time spent               = 540.671 sec
# Estimated time remaining = 74.321 min
# Mean IoU                 = 0.481
#
# Image nb 315
# Time spent               = 544.059 sec
# Estimated time remaining = 74.521 min
# Mean IoU                 = 0.482
#
# Image nb 316
# Time spent               = 545.058 sec
# Estimated time remaining = 74.394 min
# Mean IoU                 = 0.481
#
# Image nb 317
# Time spent               = 546.469 sec
# Estimated time remaining = 74.323 min
# Mean IoU                 = 0.482
#
# Image nb 318
# Time spent               = 548.302 sec
# Estimated time remaining = 74.310 min
# Mean IoU                 = 0.482
#
# Image nb 319
# Time spent               = 549.590 sec
# Estimated time remaining = 74.223 min
# Mean IoU                 = 0.483
#
# Image nb 320
# Time spent               = 551.061 sec
# Estimated time remaining = 74.162 min
# Mean IoU                 = 0.483
#
# Image nb 321
# Time spent               = 552.914 sec
# Estimated time remaining = 74.151 min
# Mean IoU                 = 0.483
#
# Image nb 322
# Time spent               = 559.036 sec
# Estimated time remaining = 74.711 min
# Mean IoU                 = 0.476
#
# Image nb 323
# Time spent               = 559.323 sec
# Estimated time remaining = 74.490 min
# Mean IoU                 = 0.477
#
# Image nb 324
# Time spent               = 560.240 sec
# Estimated time remaining = 74.354 min
# Mean IoU                 = 0.475
#
# Image nb 325
# Time spent               = 561.538 sec
# Estimated time remaining = 74.269 min
# Mean IoU                 = 0.475
#
# Image nb 326
# Time spent               = 562.401 sec
# Estimated time remaining = 74.127 min
# Mean IoU                 = 0.475
#
# Image nb 327
# Time spent               = 563.578 sec
# Estimated time remaining = 74.027 min
# Mean IoU                 = 0.476
#
# Image nb 328
# Time spent               = 567.186 sec
# Estimated time remaining = 74.246 min
# Mean IoU                 = 0.476
#
# Image nb 329
# Time spent               = 569.627 sec
# Estimated time remaining = 74.310 min
# Mean IoU                 = 0.475
#
# Image nb 330
# Time spent               = 572.019 sec
# Estimated time remaining = 74.368 min
# Mean IoU                 = 0.475
#
# Image nb 331
# Time spent               = 573.535 sec
# Estimated time remaining = 74.312 min
# Mean IoU                 = 0.477
#
# Image nb 332
# Time spent               = 575.384 sec
# Estimated time remaining = 74.299 min
# Mean IoU                 = 0.478
#
# Image nb 333
# Time spent               = 577.021 sec
# Estimated time remaining = 74.258 min
# Mean IoU                 = 0.477
#
# Image nb 334
# Time spent               = 579.080 sec
# Estimated time remaining = 74.272 min
# Mean IoU                 = 0.478
#
# Image nb 335
# Time spent               = 580.705 sec
# Estimated time remaining = 74.230 min
# Mean IoU                 = 0.478
# Image nb 336
# Time spent               = 582.386 sec
# Estimated time remaining = 74.195 min
# Mean IoU                 = 0.478
#
# Image nb 337
# Time spent               = 584.096 sec
# Estimated time remaining = 74.164 min
# Mean IoU                 = 0.477
#
# Image nb 338
# Time spent               = 584.773 sec
# Estimated time remaining = 74.002 min
# Mean IoU                 = 0.477
#
# Image nb 339
# Time spent               = 585.632 sec
# Estimated time remaining = 73.864 min
# Mean IoU                 = 0.478
#
# Image nb 340
# Time spent               = 586.884 sec
# Estimated time remaining = 73.776 min
# Mean IoU                 = 0.478
#
# Image nb 341
# Time spent               = 588.146 sec
# Estimated time remaining = 73.690 min
# Mean IoU                 = 0.478
#
# Image nb 342
# Time spent               = 589.719 sec
# Estimated time remaining = 73.643 min
# Mean IoU                 = 0.478
#
# Image nb 343
# Time spent               = 594.134 sec
# Estimated time remaining = 73.950 min
# Mean IoU                 = 0.478
#
# Image nb 344
# Time spent               = 595.959 sec
# Estimated time remaining = 73.933 min
# Mean IoU                 = 0.478
#
# Image nb 345
# Time spent               = 601.951 sec
# Estimated time remaining = 74.432 min
# Mean IoU                 = 0.472
#
# Image nb 346
# Time spent               = 604.238 sec
# Estimated time remaining = 74.470 min
# Mean IoU                 = 0.472
#
# Image nb 347
# Time spent               = 605.454 sec
# Estimated time remaining = 74.377 min
# Mean IoU                 = 0.471
#
# Image nb 348
# Time spent               = 607.748 sec
# Estimated time remaining = 74.416 min
# Mean IoU                 = 0.471
#
# Image nb 349
# Time spent               = 609.624 sec
# Estimated time remaining = 74.403 min
# Mean IoU                 = 0.472
#
# Image nb 350
# Time spent               = 614.274 sec
# Estimated time remaining = 74.728 min
# Mean IoU                 = 0.469
#
# Image nb 351
# Time spent               = 615.844 sec
# Estimated time remaining = 74.677 min
# Mean IoU                 = 0.470
#
# Image nb 352
# Time spent               = 616.578 sec
# Estimated time remaining = 74.525 min
# Mean IoU                 = 0.470
#
# Image nb 353
# Time spent               = 617.607 sec
# Estimated time remaining = 74.409 min
# Mean IoU                 = 0.471
#
# Image nb 354
# Time spent               = 618.967 sec
# Estimated time remaining = 74.334 min
# Mean IoU                 = 0.471
#
# Image nb 355
# Time spent               = 620.324 sec
# Estimated time remaining = 74.259 min
# Mean IoU                 = 0.471
#
# Image nb 356
# Time spent               = 622.507 sec
# Estimated time remaining = 74.282 min
# Mean IoU                 = 0.471
#
# Image nb 357
# Time spent               = 623.808 sec
# Estimated time remaining = 74.201 min
# Mean IoU                 = 0.472
#
# Image nb 358
# Time spent               = 625.625 sec
# Estimated time remaining = 74.180 min
# Mean IoU                 = 0.472
#
# Image nb 359
# Time spent               = 626.481 sec
# Estimated time remaining = 74.047 min
# Mean IoU                 = 0.472
#
# Image nb 360
# Time spent               = 627.671 sec
# Estimated time remaining = 73.953 min
# Mean IoU                 = 0.471
#
# Image nb 361
# Time spent               = 628.342 sec
# Estimated time remaining = 73.798 min
# Mean IoU                 = 0.472
#
# Image nb 362
# Time spent               = 632.017 sec
# Estimated time remaining = 73.997 min
# Mean IoU                 = 0.471
#
# Image nb 363
# Time spent               = 633.427 sec
# Estimated time remaining = 73.929 min
# Mean IoU                 = 0.472
#
# Image nb 364
# Time spent               = 634.201 sec
# Estimated time remaining = 73.787 min
# Mean IoU                 = 0.472
#
# Image nb 365
# Time spent               = 637.033 sec
# Estimated time remaining = 73.885 min
# Mean IoU                 = 0.472
#
# Image nb 366
# Time spent               = 637.408 sec
# Estimated time remaining = 73.699 min
# Mean IoU                 = 0.472
#
# Image nb 367
# Time spent               = 638.495 sec
# Estimated time remaining = 73.595 min
# Mean IoU                 = 0.473
#
# Image nb 368
# Time spent               = 639.004 sec
# Estimated time remaining = 73.425 min
# Mean IoU                 = 0.473
#
# Image nb 369
# Time spent               = 639.733 sec
# Estimated time remaining = 73.281 min
# Mean IoU                 = 0.474
#
# Image nb 370
# Time spent               = 640.638 sec
# Estimated time remaining = 73.158 min
# Mean IoU                 = 0.474
#
# Image nb 371
# Time spent               = 640.962 sec
# Estimated time remaining = 72.970 min
# Mean IoU                 = 0.474
#
# Image nb 372
# Time spent               = 643.339 sec
# Estimated time remaining = 73.015 min
# Mean IoU                 = 0.473
#
# Image nb 373
# Time spent               = 644.106 sec
# Estimated time remaining = 72.878 min
# Mean IoU                 = 0.474
#
# Image nb 374
# Time spent               = 647.313 sec
# Estimated time remaining = 73.017 min
# Mean IoU                 = 0.474
#
# Image nb 375
# Time spent               = 648.355 sec
# Estimated time remaining = 72.911 min
# Mean IoU                 = 0.473
#
# Image nb 376
# Time spent               = 649.871 sec
# Estimated time remaining = 72.859 min
# Mean IoU                 = 0.471
#
# Image nb 377
# Time spent               = 650.684 sec
# Estimated time remaining = 72.729 min
# Mean IoU                 = 0.472
#
# Image nb 378
# Time spent               = 651.835 sec
# Estimated time remaining = 72.636 min
# Mean IoU                 = 0.472
#
# Image nb 379
# Time spent               = 653.139 sec
# Estimated time remaining = 72.561 min
# Mean IoU                 = 0.472
#
# Image nb 380
# Time spent               = 655.169 sec
# Estimated time remaining = 72.567 min
# Mean IoU                 = 0.472
#
# Image nb 381
# Time spent               = 656.234 sec
# Estimated time remaining = 72.466 min
# Mean IoU                 = 0.473
#
# Image nb 382
# Time spent               = 657.168 sec
# Estimated time remaining = 72.351 min
# Mean IoU                 = 0.473
#
# Image nb 383
# Time spent               = 657.475 sec
# Estimated time remaining = 72.168 min
# Mean IoU                 = 0.473
#
# Image nb 384
# Time spent               = 660.050 sec
# Estimated time remaining = 72.234 min
# Mean IoU                 = 0.473
#
# Image nb 385
# Time spent               = 664.142 sec
# Estimated time remaining = 72.465 min
# Mean IoU                 = 0.472
#
# Image nb 386
# Time spent               = 664.875 sec
# Estimated time remaining = 72.329 min
# Mean IoU                 = 0.473
#
# Image nb 387
# Time spent               = 665.624 sec
# Estimated time remaining = 72.195 min
# Mean IoU                 = 0.473
#
# Image nb 388
# Time spent               = 668.959 sec
# ...
#
# Image nb 2785
# Time spent               = 3482.642 sec
# Estimated time remaining = 2.646 min
# Mean IoU                 = 0.527
#
# Image nb 2786
# Time spent               = 3483.299 sec
# Estimated time remaining = 2.625 min
# Mean IoU                 = 0.527
#
# Image nb 2787
# Time spent               = 3484.146 sec
# Estimated time remaining = 2.604 min
# Mean IoU                 = 0.527
#
# Image nb 2788
# Time spent               = 3484.913 sec
# Estimated time remaining = 2.582 min
# Mean IoU                 = 0.527
#
# Image nb 2789
# Time spent               = 3489.248 sec
# Estimated time remaining = 2.564 min
# Mean IoU                 = 0.527
#
# Image nb 2790
# Time spent               = 3489.655 sec
# Estimated time remaining = 2.542 min
# Mean IoU                 = 0.527
#
# Image nb 2791
# Time spent               = 3490.134 sec
# Estimated time remaining = 2.521 min
# Mean IoU                 = 0.527
#
# Image nb 2792
# Time spent               = 3491.342 sec
# Estimated time remaining = 2.500 min
# Mean IoU                 = 0.527
#
# Image nb 2793
# Time spent               = 3491.824 sec
# Estimated time remaining = 2.479 min
# Mean IoU                 = 0.527
#
# Image nb 2794
# Time spent               = 3494.607 sec
# Estimated time remaining = 2.459 min
# Mean IoU                 = 0.527
#
# Image nb 2795
# Time spent               = 3495.177 sec
# Estimated time remaining = 2.438 min
# Mean IoU                 = 0.527
#
# Image nb 2796
# Time spent               = 3495.957 sec
# Estimated time remaining = 2.416 min
# Mean IoU                 = 0.527
#
# Image nb 2797
# Time spent               = 3496.183 sec
# Estimated time remaining = 2.395 min
# Mean IoU                 = 0.526
#
# Image nb 2798
# Time spent               = 3497.969 sec
# Estimated time remaining = 2.374 min
# Mean IoU                 = 0.526
#
# Image nb 2799
# Time spent               = 3498.378 sec
# Estimated time remaining = 2.353 min
# Mean IoU                 = 0.526
#
# Image nb 2800
# Time spent               = 3498.592 sec
# Estimated time remaining = 2.332 min
# Mean IoU                 = 0.526
#
# Image nb 2801
# Time spent               = 3499.644 sec
# Estimated time remaining = 2.311 min
# Mean IoU                 = 0.526
#
# Image nb 2802
# Time spent               = 3500.084 sec
# Estimated time remaining = 2.289 min
# Mean IoU                 = 0.526
#
# Image nb 2803
# Time spent               = 3501.197 sec
# Estimated time remaining = 2.268 min
# Mean IoU                 = 0.526
#
# Image nb 2804
# Time spent               = 3501.526 sec
# Estimated time remaining = 2.247 min
# Mean IoU                 = 0.526
#
# Image nb 2805
# Time spent               = 3502.945 sec
# Estimated time remaining = 2.226 min
# Mean IoU                 = 0.526
#
# Image nb 2806
# Time spent               = 3503.501 sec
# Estimated time remaining = 2.205 min
# Mean IoU                 = 0.526
#
# Image nb 2807
# Time spent               = 3504.475 sec
# Estimated time remaining = 2.184 min
# Mean IoU                 = 0.526
#
# Image nb 2808
# Time spent               = 3504.984 sec
# Estimated time remaining = 2.163 min
# Mean IoU                 = 0.526
#
# Image nb 2809
# Time spent               = 3506.350 sec
# Estimated time remaining = 2.142 min
# Mean IoU                 = 0.526
#
# Image nb 2810
# Time spent               = 3507.987 sec
# Estimated time remaining = 2.122 min
# Mean IoU                 = 0.526
#
# Image nb 2811
# Time spent               = 3510.986 sec
# Estimated time remaining = 2.102 min
# Mean IoU                 = 0.526
#
# Image nb 2812
# Time spent               = 3513.049 sec
# Estimated time remaining = 2.081 min
# Mean IoU                 = 0.526
#
# Image nb 2813
# Time spent               = 3514.080 sec
# Estimated time remaining = 2.060 min
# Mean IoU                 = 0.526
#
# Image nb 2814
# Time spent               = 3515.890 sec
# Estimated time remaining = 2.040 min
# Mean IoU                 = 0.526
#
# Image nb 2815
# Time spent               = 3516.750 sec
# Estimated time remaining = 2.019 min
# Mean IoU                 = 0.526
#
# Image nb 2816
# Time spent               = 3520.485 sec
# Estimated time remaining = 2.000 min
# Mean IoU                 = 0.526
#
# Image nb 2817
# Time spent               = 3520.910 sec
# Estimated time remaining = 1.978 min
# Mean IoU                 = 0.526
#
# Image nb 2818
# Time spent               = 3521.244 sec
# Estimated time remaining = 1.957 min
# Mean IoU                 = 0.526
#
# Image nb 2819
# Time spent               = 3522.859 sec
# Estimated time remaining = 1.936 min
# Mean IoU                 = 0.526
#
# Image nb 2820
# Time spent               = 3524.079 sec
# Estimated time remaining = 1.915 min
# Mean IoU                 = 0.526
#
# Image nb 2821
# Time spent               = 3524.759 sec
# Estimated time remaining = 1.894 min
# Mean IoU                 = 0.526
#
# Image nb 2822
# Time spent               = 3526.046 sec
# Estimated time remaining = 1.874 min
# Mean IoU                 = 0.526
#
# Image nb 2823
# Time spent               = 3526.493 sec
# Estimated time remaining = 1.852 min
# Mean IoU                 = 0.526
#
# Image nb 2824
# Time spent               = 3527.239 sec
# Estimated time remaining = 1.831 min
# Mean IoU                 = 0.526
#
# Image nb 2825
# Time spent               = 3529.135 sec
# Estimated time remaining = 1.811 min
# Mean IoU                 = 0.526
#
# Image nb 2826
# Time spent               = 3529.610 sec
# Estimated time remaining = 1.790 min
# Mean IoU                 = 0.526
#
# Image nb 2827
# Time spent               = 3531.538 sec
# Estimated time remaining = 1.769 min
# Mean IoU                 = 0.526
#
# Image nb 2828
# Time spent               = 3532.480 sec
# Estimated time remaining = 1.748 min
# Mean IoU                 = 0.526
#
# Image nb 2829
# Time spent               = 3533.704 sec
# Estimated time remaining = 1.727 min
# Mean IoU                 = 0.526
#
# Image nb 2830
# Time spent               = 3535.506 sec
# Estimated time remaining = 1.707 min
# Mean IoU                 = 0.526
#
# Image nb 2831
# Time spent               = 3535.831 sec
# Estimated time remaining = 1.686 min
# Mean IoU                 = 0.526
#
# Image nb 2832
# Time spent               = 3537.682 sec
# Estimated time remaining = 1.665 min
# Mean IoU                 = 0.526
#
# Image nb 2833
# Time spent               = 3539.625 sec
# Estimated time remaining = 1.644 min
# Mean IoU                 = 0.526
#
# Image nb 2834
# Time spent               = 3540.142 sec
# Estimated time remaining = 1.623 min
# Mean IoU                 = 0.526
#
# Image nb 2835
# Time spent               = 3541.068 sec
# Estimated time remaining = 1.602 min
# Mean IoU                 = 0.526
#
# Image nb 2836
# Time spent               = 3541.976 sec
# Estimated time remaining = 1.581 min
# Mean IoU                 = 0.526
#
# Image nb 2837
# Time spent               = 3542.288 sec
# Estimated time remaining = 1.560 min
# Mean IoU                 = 0.526
#
# Image nb 2838
# Time spent               = 3543.716 sec
# Estimated time remaining = 1.539 min
# Mean IoU                 = 0.526
#
# Image nb 2839
# Time spent               = 3545.838 sec
# Estimated time remaining = 1.519 min
# Mean IoU                 = 0.526
#
# Image nb 2840
# Time spent               = 3546.755 sec
# Estimated time remaining = 1.498 min
# Mean IoU                 = 0.526
#
# Image nb 2841
# Time spent               = 3548.138 sec
# Estimated time remaining = 1.477 min
# Mean IoU                 = 0.526
#
# Image nb 2842
# Time spent               = 3550.841 sec
# Estimated time remaining = 1.457 min
# Mean IoU                 = 0.526
#
# Image nb 2843
# Time spent               = 3553.010 sec
# Estimated time remaining = 1.437 min
# Mean IoU                 = 0.525
#
# Image nb 2844
# Time spent               = 3553.874 sec
# Estimated time remaining = 1.416 min
# Mean IoU                 = 0.525
#
# Image nb 2845
# Time spent               = 3554.678 sec
# Estimated time remaining = 1.395 min
# Mean IoU                 = 0.525
#
# Image nb 2846
# Time spent               = 3557.145 sec
# Estimated time remaining = 1.374 min
# Mean IoU                 = 0.525
#
# Image nb 2847
# Time spent               = 3558.761 sec
# Estimated time remaining = 1.354 min
# Mean IoU                 = 0.525
# Image nb 2848
# Time spent               = 3559.150 sec
# Estimated time remaining = 1.333 min
# Mean IoU                 = 0.525
#
# Image nb 2849
# Time spent               = 3560.422 sec
# Estimated time remaining = 1.312 min
# Mean IoU                 = 0.525
#
# Image nb 2850
# Time spent               = 3561.847 sec
# Estimated time remaining = 1.291 min
# Mean IoU                 = 0.525
#
# Image nb 2851
# Time spent               = 3562.103 sec
# Estimated time remaining = 1.270 min
# Mean IoU                 = 0.525
#
# Image nb 2852
# Time spent               = 3562.691 sec
# Estimated time remaining = 1.249 min
# Mean IoU                 = 0.525
#
# Image nb 2853
# Time spent               = 3563.567 sec
# Estimated time remaining = 1.228 min
# Mean IoU                 = 0.525
#
# Image nb 2854
# Time spent               = 3567.249 sec
# Estimated time remaining = 1.208 min
# Mean IoU                 = 0.524
#
# Image nb 2855
# Time spent               = 3569.290 sec
# Estimated time remaining = 1.187 min
# Mean IoU                 = 0.524
#
# Image nb 2856
# Time spent               = 3570.896 sec
# Estimated time remaining = 1.167 min
# Mean IoU                 = 0.524
#
# Image nb 2857
# Time spent               = 3572.006 sec
# Estimated time remaining = 1.146 min
# Mean IoU                 = 0.524
#
# Image nb 2858
# Time spent               = 3572.382 sec
# Estimated time remaining = 1.125 min
# Mean IoU                 = 0.524
#
# Image nb 2859
# Time spent               = 3572.780 sec
# Estimated time remaining = 1.103 min
# Mean IoU                 = 0.524
#
# Image nb 2860
# Time spent               = 3573.255 sec
# Estimated time remaining = 1.082 min
# Mean IoU                 = 0.524
#
# Image nb 2861
# Time spent               = 3573.507 sec
# Estimated time remaining = 1.061 min
# Mean IoU                 = 0.524
#
# Image nb 2862
# Time spent               = 3573.676 sec
# Estimated time remaining = 1.040 min
# Mean IoU                 = 0.524
#
# Image nb 2863
# Time spent               = 3573.912 sec
# Estimated time remaining = 1.019 min
# Mean IoU                 = 0.524
#
# Image nb 2864
# Time spent               = 3575.975 sec
# Estimated time remaining = 0.999 min
# Mean IoU                 = 0.524
#
# Image nb 2865
# Time spent               = 3576.314 sec
# Estimated time remaining = 0.977 min
# Mean IoU                 = 0.525
#
# Image nb 2866
# Time spent               = 3576.647 sec
# Estimated time remaining = 0.956 min
# Mean IoU                 = 0.525
#
# Image nb 2867
# Time spent               = 3577.290 sec
# Estimated time remaining = 0.935 min
# Mean IoU                 = 0.525
#
# Image nb 2868
# Time spent               = 3577.599 sec
# Estimated time remaining = 0.914 min
# Mean IoU                 = 0.525
#
# Image nb 2869
# Time spent               = 3578.478 sec
# Estimated time remaining = 0.894 min
# Mean IoU                 = 0.525
#
# Image nb 2870
# Time spent               = 3579.710 sec
# Estimated time remaining = 0.873 min
# Mean IoU                 = 0.525
#
# Image nb 2871
# Time spent               = 3580.169 sec
# Estimated time remaining = 0.852 min
# Mean IoU                 = 0.525
#
# Image nb 2872
# Time spent               = 3580.914 sec
# Estimated time remaining = 0.831 min
# Mean IoU                 = 0.525
#
# Image nb 2873
# Time spent               = 3589.506 sec
# Estimated time remaining = 0.812 min
# Mean IoU                 = 0.523
#
# Image nb 2874
# Time spent               = 3589.846 sec
# Estimated time remaining = 0.791 min
# Mean IoU                 = 0.523
#
# Image nb 2875
# Time spent               = 3590.935 sec
# Estimated time remaining = 0.770 min
# Mean IoU                 = 0.523
#
# Image nb 2876
# Time spent               = 3591.488 sec
# Estimated time remaining = 0.749 min
# Mean IoU                 = 0.523
#
# Image nb 2877
# Time spent               = 3592.483 sec
# Estimated time remaining = 0.728 min
# Mean IoU                 = 0.523
#
# Image nb 2878
# Time spent               = 3592.723 sec
# Estimated time remaining = 0.707 min
# Mean IoU                 = 0.523
#
# Image nb 2879
# Time spent               = 3593.641 sec
# Estimated time remaining = 0.686 min
# Mean IoU                 = 0.523
#
# Image nb 2880
# Time spent               = 3595.439 sec
# Estimated time remaining = 0.666 min
# Mean IoU                 = 0.523
#
# Image nb 2881
# Time spent               = 3597.880 sec
# Estimated time remaining = 0.645 min
# Mean IoU                 = 0.523
#
# Image nb 2882
# Time spent               = 3598.091 sec
# Estimated time remaining = 0.624 min
# Mean IoU                 = 0.523
#
# Image nb 2883
# Time spent               = 3598.544 sec
# Estimated time remaining = 0.603 min
# Mean IoU                 = 0.523
#
# Image nb 2884
# Time spent               = 3599.334 sec
# Estimated time remaining = 0.582 min
# Mean IoU                 = 0.523
#
# Image nb 2885
# Time spent               = 3599.848 sec
# Estimated time remaining = 0.561 min
# Mean IoU                 = 0.523
#
# Image nb 2886
# Time spent               = 3601.219 sec
# Estimated time remaining = 0.541 min
# Mean IoU                 = 0.523
#
# Image nb 2887
# Time spent               = 3602.076 sec
# Estimated time remaining = 0.520 min
# Mean IoU                 = 0.523
#
# Image nb 2888
# Time spent               = 3602.588 sec
# Estimated time remaining = 0.499 min
# Mean IoU                 = 0.523
#
# Image nb 2889
# Time spent               = 3604.217 sec
# Estimated time remaining = 0.478 min
# Mean IoU                 = 0.523
#
# Image nb 2890
# Time spent               = 3605.246 sec
# Estimated time remaining = 0.457 min
# Mean IoU                 = 0.523
#
# Image nb 2891
# Time spent               = 3609.023 sec
# Estimated time remaining = 0.437 min
# Mean IoU                 = 0.523
#
# Image nb 2892
# Time spent               = 3614.200 sec
# Estimated time remaining = 0.416 min
# Mean IoU                 = 0.523
#
# Image nb 2893
# Time spent               = 3615.770 sec
# Estimated time remaining = 0.396 min
# Mean IoU                 = 0.522
#
# Image nb 2894
# Time spent               = 3617.243 sec
# Estimated time remaining = 0.375 min
# Mean IoU                 = 0.522
#
# Image nb 2895
# Time spent               = 3618.309 sec
# Estimated time remaining = 0.354 min
# Mean IoU                 = 0.522
#
# Image nb 2896
# Time spent               = 3620.649 sec
# Estimated time remaining = 0.333 min
# Mean IoU                 = 0.521
#
# Image nb 2897
# Time spent               = 3621.435 sec
# Estimated time remaining = 0.312 min
# Mean IoU                 = 0.521
#
# Image nb 2898
# Time spent               = 3622.266 sec
# Estimated time remaining = 0.292 min
# Mean IoU                 = 0.521
#
# Image nb 2899
# Time spent               = 3622.550 sec
# Estimated time remaining = 0.271 min
# Mean IoU                 = 0.521
#
# Image nb 2900
# Time spent               = 3623.930 sec
# Estimated time remaining = 0.250 min
# Mean IoU                 = 0.521
#
# Image nb 2901
# Time spent               = 3624.495 sec
# Estimated time remaining = 0.229 min
# Mean IoU                 = 0.521
#
# Image nb 2902
# Time spent               = 3625.140 sec
# Estimated time remaining = 0.208 min
# Mean IoU                 = 0.521
#
# Image nb 2903
# Time spent               = 3627.187 sec
# Estimated time remaining = 0.187 min
# Mean IoU                 = 0.521
#
# Image nb 2904
# Time spent               = 3627.655 sec
# Estimated time remaining = 0.167 min
# Mean IoU                 = 0.521
#
# Image nb 2905
# Time spent               = 3628.858 sec
# Estimated time remaining = 0.146 min
# Mean IoU                 = 0.521
#
# Image nb 2906
# Time spent               = 3630.641 sec
# Estimated time remaining = 0.125 min
# Mean IoU                 = 0.521
#
# Image nb 2907
# Time spent               = 3631.208 sec
# Estimated time remaining = 0.104 min
# Mean IoU                 = 0.521
#
# Image nb 2908
# Time spent               = 3631.955 sec
# Estimated time remaining = 0.083 min
# Mean IoU                 = 0.521
#
# Image nb 2909
# Time spent               = 3632.751 sec
# Estimated time remaining = 0.062 min
# Mean IoU                 = 0.521
#
# Image nb 2910
# Time spent               = 3634.060 sec
# Estimated time remaining = 0.042 min
# Mean IoU                 = 0.521
#
# Image nb 2911
# Time spent               = 3634.860 sec
# Estimated time remaining = 0.021 min
# Mean IoU                 = 0.521
#
# Image nb 2912
# Time spent               = 3635.265 sec
# Estimated time remaining = 0.000 min
# Mean IoU                 = 0.521

# %%
print(f'Mean IoU = {np.mean(IoU)}')
# Out:
# Mean IoU = 0.5210917350877718

# %%
df = pd.read_csv(r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\voc-object-annotations-clean.csv')

# %%
df['mIoU'] = IoU

# %%
df.to_csv(output_path + 'IoU.csv', index = False)
