# %%
from torchvision import transforms
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import timeit
import pandas as pd
import gc

import sys
sys.path.append('../../')
import utils.image as im
import utils.cam as cam
import utils.grabcut as gc
import utils.voc as voc
import utils.json as json
from utils.VOCSegmentation import VOCSegmentation

# %%
root_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\\'

json_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\\'

output_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\sessions\session3\\'

# %%
camnet = cam.Cam()

# %%
data_tbl = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Class')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 0))

# %%
annotations = json.open_json(json_path + "voc-class-annotations")
N = len(annotations)
annotations = iter(annotations.items())

classes = json.open_json(json_path + "voc-classes")

# %%
IoU = np.array([])
time = np.array([])

for i in range(N):
    gc.collect()
    
    start = timeit.default_timer()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_pil = img
    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    for c in annots:
        
        img_cam = camnet.get_top(img_pil, c)
        img_cam = cam.cam_process(img_pil, img_cam)
        gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0)
        _, _, pred = gc.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
        
        true = voc.true_mask(sgm, classes.index(c) + 1, dilation = 0)
        
        IoU = np.append(IoU, voc.IoU_acc_undef(true, pred, sgm))
        
    stop = timeit.default_timer()
    time = np.append(time, stop - start)
    if i % 20 == 0:
        print(f'Image nb {i}')
        print(f'Time spent               = ' + voc.time_str(np.sum(time)))
        print(f'Estimated time remaining = ' + voc.time_str(np.mean(time) * (N - 1 - i)))
        print(f'Mean IoU                 =  {np.mean(IoU) :.3f}')
        print()
# Out:
# C:\Users\Nicol\Miniconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Image nb 0
# Time spent               =   0m02s
# Estimated time remaining = 134m14s
# Mean IoU                 =  0.037
#
# Image nb 1
# Time spent               =   0m03s
# Estimated time remaining =  89m25s
# Mean IoU                 =  0.139
#
# Image nb 2
# Time spent               =   0m07s
# Estimated time remaining = 126m34s
# Mean IoU                 =  0.185
#
# Image nb 3
# Time spent               =   0m09s
# Estimated time remaining = 112m08s
# Mean IoU                 =  0.316
#
# Image nb 4
# Time spent               =   0m09s
# Estimated time remaining =  95m29s
# Mean IoU                 =  0.283
#
# Image nb 5
# Time spent               =   0m12s
# Estimated time remaining = 103m10s
# Mean IoU                 =  0.255
#
# Image nb 6
# Time spent               =   0m13s
# Estimated time remaining =  94m18s
# Mean IoU                 =  0.251
#
# Image nb 7
# Time spent               =   0m15s
# Estimated time remaining =  92m48s
# Mean IoU                 =  0.233
#
# Image nb 8
# Time spent               =   0m16s
# Estimated time remaining =  90m10s
# Mean IoU                 =  0.212
#
# Image nb 9
# Time spent               =   0m19s
# Estimated time remaining =  96m40s
# Mean IoU                 =  0.239
#
# Image nb 10
# Time spent               =   0m25s
# Estimated time remaining = 111m02s
# Mean IoU                 =  0.245
#
# Image nb 11
# Time spent               =   0m26s
# Estimated time remaining = 104m46s
# Mean IoU                 =  0.287
#
# Image nb 12
# Time spent               =   0m27s
# Estimated time remaining = 101m24s
# Mean IoU                 =  0.292
#
# Image nb 13
# Time spent               =   0m28s
# Estimated time remaining =  97m56s
# Mean IoU                 =  0.280
#
# Image nb 14
# Time spent               =   0m29s
# Estimated time remaining =  95m24s
# Mean IoU                 =  0.318
#
# Image nb 15
# Time spent               =   0m32s
# Estimated time remaining =  98m11s
# Mean IoU                 =  0.307
#
# Image nb 16
# Time spent               =   0m33s
# Estimated time remaining =  94m15s
# Mean IoU                 =  0.313
#
# Image nb 17
# Time spent               =   0m35s
# Estimated time remaining =  94m52s
# Mean IoU                 =  0.299
#
# Image nb 18
# Time spent               =   0m41s
# Estimated time remaining = 104m22s
# Mean IoU                 =  0.287
#
# Image nb 19
# Time spent               =   0m42s
# Estimated time remaining = 102m47s
# Mean IoU                 =  0.288
#
# Image nb 20
# Time spent               =   0m44s
# Estimated time remaining = 101m11s
# Mean IoU                 =  0.288
#
# Image nb 21
# Time spent               =   0m45s
# Estimated time remaining =  99m05s
# Mean IoU                 =  0.302
#
# Image nb 22
# Time spent               =   0m46s
# Estimated time remaining =  98m19s
# Mean IoU                 =  0.304
#
# Image nb 23
# Time spent               =   0m49s
# Estimated time remaining = 100m18s
# Mean IoU                 =  0.292
#
# Image nb 24
# Time spent               =   0m51s
# Estimated time remaining =  99m22s
# Mean IoU                 =  0.279
#
# Image nb 25
# Time spent               =   0m51s
# Estimated time remaining =  96m12s
# Mean IoU                 =  0.289
#
# Image nb 26
# Time spent               =   0m53s
# Estimated time remaining =  94m52s
# Mean IoU                 =  0.290
#
# Image nb 27
# Time spent               =   0m53s
# Estimated time remaining =  92m43s
# Mean IoU                 =  0.290
#
# Image nb 28
# Time spent               =   1m00s
# Estimated time remaining = 100m11s
# Mean IoU                 =  0.295
#
# Image nb 29
# Time spent               =   1m08s
# Estimated time remaining = 110m16s
# Mean IoU                 =  0.276
#
# Image nb 30
# Time spent               =   1m09s
# Estimated time remaining = 108m12s
# Mean IoU                 =  0.284
#
# Image nb 31
# Time spent               =   1m12s
# Estimated time remaining = 109m24s
# Mean IoU                 =  0.275
#
# Image nb 32
# Time spent               =   1m16s
# Estimated time remaining = 111m01s
# Mean IoU                 =  0.284
#
# Image nb 33
# Time spent               =   1m18s
# Estimated time remaining = 111m01s
# Mean IoU                 =  0.279
#
# Image nb 34
# Time spent               =   1m19s
# Estimated time remaining = 109m09s
# Mean IoU                 =  0.274
#
# Image nb 35
# Time spent               =   1m21s
# Estimated time remaining = 108m28s
# Mean IoU                 =  0.273
#
# Image nb 36
# Time spent               =   1m23s
# Estimated time remaining = 108m33s
# Mean IoU                 =  0.274
#
# Image nb 37
# Time spent               =   1m25s
# Estimated time remaining = 108m03s
# Mean IoU                 =  0.277
#
# Image nb 38
# Time spent               =   1m27s
# Estimated time remaining = 106m55s
# Mean IoU                 =  0.285
#
# Image nb 39
# Time spent               =   1m31s
# Estimated time remaining = 109m19s
# Mean IoU                 =  0.276
#
# Image nb 40
# Time spent               =   1m36s
# Estimated time remaining = 112m59s
# Mean IoU                 =  0.265
#
# Image nb 41
# Time spent               =   1m40s
# Estimated time remaining = 114m28s
# Mean IoU                 =  0.264
#
# Image nb 42
# Time spent               =   1m41s
# Estimated time remaining = 113m06s
# Mean IoU                 =  0.271
#
# Image nb 43
# Time spent               =   1m42s
# Estimated time remaining = 111m21s
# Mean IoU                 =  0.277
#
# Image nb 44
# Time spent               =   1m43s
# Estimated time remaining = 110m00s
# Mean IoU                 =  0.281
#
# Image nb 45
# Time spent               =   1m45s
# Estimated time remaining = 109m36s
# Mean IoU                 =  0.272
#
# Image nb 46
# Time spent               =   1m47s
# Estimated time remaining = 108m49s
# Mean IoU                 =  0.277
#
# Image nb 47
# Time spent               =   1m47s
# Estimated time remaining = 106m53s
# Mean IoU                 =  0.283
#
# Image nb 48
# Time spent               =   1m51s
# Estimated time remaining = 108m43s
# Mean IoU                 =  0.288
#
# Image nb 49
# Time spent               =   1m52s
# Estimated time remaining = 107m32s
# Mean IoU                 =  0.292
#
# Image nb 50
# Time spent               =   1m57s
# Estimated time remaining = 109m57s
# Mean IoU                 =  0.285
#
# Image nb 51
# Time spent               =   2m03s
# Estimated time remaining = 113m35s
# Mean IoU                 =  0.276
#
# Image nb 52
# Time spent               =   2m06s
# Estimated time remaining = 113m58s
# Mean IoU                 =  0.280
#
# Image nb 53
# Time spent               =   2m10s
# Estimated time remaining = 114m58s
# Mean IoU                 =  0.276
#
# Image nb 54
# Time spent               =   2m11s
# Estimated time remaining = 113m37s
# Mean IoU                 =  0.275
#
# Image nb 55
# Time spent               =   2m13s
# Estimated time remaining = 113m51s
# Mean IoU                 =  0.270
#
# Image nb 56
# Time spent               =   2m15s
# Estimated time remaining = 113m30s
# Mean IoU                 =  0.270
#
# Image nb 57
# Time spent               =   2m16s
# Estimated time remaining = 111m52s
# Mean IoU                 =  0.267
#
# Image nb 58
# Time spent               =   2m17s
# Estimated time remaining = 111m13s
# Mean IoU                 =  0.270
#
# Image nb 59
# Time spent               =   2m20s
# Estimated time remaining = 111m22s
# Mean IoU                 =  0.270
#
# Image nb 60
# Time spent               =   2m23s
# Estimated time remaining = 111m50s
# Mean IoU                 =  0.267
#
# Image nb 61
# Time spent               =   2m25s
# Estimated time remaining = 111m31s
# Mean IoU                 =  0.263
#
# Image nb 62
# Time spent               =   2m26s
# Estimated time remaining = 110m11s
# Mean IoU                 =  0.266
#
# Image nb 63
# Time spent               =   2m28s
# Estimated time remaining = 110m00s
# Mean IoU                 =  0.271
#
# Image nb 64
# Time spent               =   2m33s
# Estimated time remaining = 112m06s
# Mean IoU                 =  0.262
#
# Image nb 65
# Time spent               =   2m34s
# Estimated time remaining = 110m48s
# Mean IoU                 =  0.266
#
# Image nb 66
# Time spent               =   2m40s
# Estimated time remaining = 113m29s
# Mean IoU                 =  0.263
#
# Image nb 67
# Time spent               =   2m42s
# Estimated time remaining = 113m08s
# Mean IoU                 =  0.260
#
# Image nb 68
# Time spent               =   2m44s
# Estimated time remaining = 112m49s
# Mean IoU                 =  0.256
#
# Image nb 69
# Time spent               =   2m47s
# Estimated time remaining = 113m12s
# Mean IoU                 =  0.256
#
# Image nb 70
# Time spent               =   2m47s
# Estimated time remaining = 112m04s
# Mean IoU                 =  0.261
# Image nb 71
# Time spent               =   2m48s
# Estimated time remaining = 110m45s
# Mean IoU                 =  0.267
#
# Image nb 72
# Time spent               =   2m49s
# Estimated time remaining = 110m12s
# Mean IoU                 =  0.269
#
# Image nb 73
# Time spent               =   2m52s
# Estimated time remaining = 110m07s
# Mean IoU                 =  0.269
#
# Image nb 74
# Time spent               =   2m53s
# Estimated time remaining = 109m09s
# Mean IoU                 =  0.275
#
# Image nb 75
# Time spent               =   2m55s
# Estimated time remaining = 109m05s
# Mean IoU                 =  0.276
#
# Image nb 76
# Time spent               =   2m57s
# Estimated time remaining = 109m09s
# Mean IoU                 =  0.275
#
# Image nb 77
# Time spent               =   2m58s
# Estimated time remaining = 108m20s
# Mean IoU                 =  0.278
#
# Image nb 78
# Time spent               =   3m01s
# Estimated time remaining = 108m33s
# Mean IoU                 =  0.275
#
# Image nb 79
# Time spent               =   3m04s
# Estimated time remaining = 108m42s
# Mean IoU                 =  0.273
#
# Image nb 80
# Time spent               =   3m04s
# Estimated time remaining = 107m33s
# Mean IoU                 =  0.277
#
# Image nb 81
# Time spent               =   3m09s
# Estimated time remaining = 108m48s
# Mean IoU                 =  0.271
#
# Image nb 82
# Time spent               =   3m10s
# Estimated time remaining = 108m10s
# Mean IoU                 =  0.275
#
# Image nb 83
# Time spent               =   3m13s
# Estimated time remaining = 108m50s
# Mean IoU                 =  0.276
#
# Image nb 84
# Time spent               =   3m14s
# Estimated time remaining = 107m58s
# Mean IoU                 =  0.277
#
# Image nb 85
# Time spent               =   3m17s
# Estimated time remaining = 108m22s
# Mean IoU                 =  0.278
#
# Image nb 86
# Time spent               =   3m23s
# Estimated time remaining = 110m01s
# Mean IoU                 =  0.277
#
# Image nb 87
# Time spent               =   3m26s
# Estimated time remaining = 110m26s
# Mean IoU                 =  0.275
#
# Image nb 88
# Time spent               =   3m28s
# Estimated time remaining = 110m02s
# Mean IoU                 =  0.277
#
# Image nb 89
# Time spent               =   3m29s
# Estimated time remaining = 109m43s
# Mean IoU                 =  0.275
#
# Image nb 90
# Time spent               =   3m30s
# Estimated time remaining = 108m53s
# Mean IoU                 =  0.278
#
# Image nb 91
# Time spent               =   3m31s
# Estimated time remaining = 108m13s
# Mean IoU                 =  0.280
#
# Image nb 92
# Time spent               =   3m37s
# Estimated time remaining = 110m07s
# Mean IoU                 =  0.277
#
# Image nb 93
# Time spent               =   3m40s
# Estimated time remaining = 110m10s
# Mean IoU                 =  0.275
#
# Image nb 94
# Time spent               =   3m41s
# Estimated time remaining = 109m33s
# Mean IoU                 =  0.273
#
# Image nb 95
# Time spent               =   3m47s
# Estimated time remaining = 111m13s
# Mean IoU                 =  0.271
#
# Image nb 96
# Time spent               =   3m48s
# Estimated time remaining = 110m29s
# Mean IoU                 =  0.272
#
# Image nb 97
# Time spent               =   3m48s
# Estimated time remaining = 109m36s
# Mean IoU                 =  0.273
#
# Image nb 98
# Time spent               =   3m50s
# Estimated time remaining = 109m25s
# Mean IoU                 =  0.271
#
# Image nb 99
# Time spent               =   3m53s
# Estimated time remaining = 109m37s
# Mean IoU                 =  0.272
#
# Image nb 100
# Time spent               =   3m56s
# Estimated time remaining = 109m40s
# Mean IoU                 =  0.269
#
# Image nb 101
# Time spent               =   3m58s
# Estimated time remaining = 109m37s
# Mean IoU                 =  0.268
#
# Image nb 102
# Time spent               =   3m59s
# Estimated time remaining = 108m43s
# Mean IoU                 =  0.271
#
# Image nb 103
# Time spent               =   4m00s
# Estimated time remaining = 108m05s
# Mean IoU                 =  0.271
#
# Image nb 104
# Time spent               =   4m04s
# Estimated time remaining = 109m11s
# Mean IoU                 =  0.271
#
# Image nb 105
# Time spent               =   4m08s
# Estimated time remaining = 109m35s
# Mean IoU                 =  0.270
#
# Image nb 106
# Time spent               =   4m08s
# Estimated time remaining = 108m43s
# Mean IoU                 =  0.271
#
# Image nb 107
# Time spent               =   4m09s
# Estimated time remaining = 108m08s
# Mean IoU                 =  0.270
#
# Image nb 108
# Time spent               =   4m10s
# Estimated time remaining = 107m16s
# Mean IoU                 =  0.273
#
# Image nb 109
# Time spent               =   4m15s
# Estimated time remaining = 108m38s
# Mean IoU                 =  0.273
#
# Image nb 110
# Time spent               =   4m16s
# Estimated time remaining = 108m05s
# Mean IoU                 =  0.274
#
# Image nb 111
# Time spent               =   4m18s
# Estimated time remaining = 107m34s
# Mean IoU                 =  0.276
#
# Image nb 112
# Time spent               =   4m19s
# Estimated time remaining = 107m09s
# Mean IoU                 =  0.277
#
# Image nb 113
# Time spent               =   4m20s
# Estimated time remaining = 106m27s
# Mean IoU                 =  0.280
#
# Image nb 114
# Time spent               =   4m21s
# Estimated time remaining = 105m54s
# Mean IoU                 =  0.280
#
# Image nb 115
# Time spent               =   4m22s
# Estimated time remaining = 105m37s
# Mean IoU                 =  0.281
#
# Image nb 116
# Time spent               =   4m25s
# Estimated time remaining = 105m41s
# Mean IoU                 =  0.279
#
# Image nb 117
# Time spent               =   4m29s
# Estimated time remaining = 106m24s
# Mean IoU                 =  0.277
#
# Image nb 118
# Time spent               =   4m31s
# Estimated time remaining = 106m22s
# Mean IoU                 =  0.276
#
# Image nb 119
# Time spent               =   4m33s
# Estimated time remaining = 106m11s
# Mean IoU                 =  0.274
#
# Image nb 120
# Time spent               =   4m36s
# Estimated time remaining = 106m15s
# Mean IoU                 =  0.275
#
# Image nb 121
# Time spent               =   4m37s
# Estimated time remaining = 105m44s
# Mean IoU                 =  0.277
#
# Image nb 122
# Time spent               =   4m39s
# Estimated time remaining = 105m40s
# Mean IoU                 =  0.276
#
# Image nb 123
# Time spent               =   4m44s
# Estimated time remaining = 106m40s
# Mean IoU                 =  0.274
#
# Image nb 124
# Time spent               =   4m45s
# Estimated time remaining = 106m03s
# Mean IoU                 =  0.277
#
# Image nb 125
# Time spent               =   4m46s
# Estimated time remaining = 105m28s
# Mean IoU                 =  0.281
#
# Image nb 126
# Time spent               =   4m47s
# Estimated time remaining = 104m56s
# Mean IoU                 =  0.281
#
# Image nb 127
# Time spent               =   4m48s
# Estimated time remaining = 104m33s
# Mean IoU                 =  0.280
#
# Image nb 128
# Time spent               =   4m50s
# Estimated time remaining = 104m26s
# Mean IoU                 =  0.279
#
# Image nb 129
# Time spent               =   4m52s
# Estimated time remaining = 104m23s
# Mean IoU                 =  0.278
#
# Image nb 130
# Time spent               =   4m54s
# Estimated time remaining = 104m04s
# Mean IoU                 =  0.278
#
# Image nb 131
# Time spent               =   4m57s
# Estimated time remaining = 104m23s
# Mean IoU                 =  0.277
#
# Image nb 132
# Time spent               =   5m00s
# Estimated time remaining = 104m31s
# Mean IoU                 =  0.280
#
# Image nb 133
# Time spent               =   5m03s
# Estimated time remaining = 104m56s
# Mean IoU                 =  0.281
#
# Image nb 134
# Time spent               =   5m04s
# Estimated time remaining = 104m23s
# Mean IoU                 =  0.284
#
# Image nb 135
# Time spent               =   5m04s
# Estimated time remaining = 103m45s
# Mean IoU                 =  0.286
#
# Image nb 136
# Time spent               =   5m08s
# Estimated time remaining = 104m03s
# Mean IoU                 =  0.286
#
# Image nb 137
# Time spent               =   5m11s
# Estimated time remaining = 104m14s
# Mean IoU                 =  0.286
#
# Image nb 138
# Time spent               =   5m11s
# Estimated time remaining = 103m41s
# Mean IoU                 =  0.287
#
# Image nb 139
# Time spent               =   5m13s
# Estimated time remaining = 103m25s
# Mean IoU                 =  0.288
#
# Image nb 140
# Time spent               =   5m18s
# Estimated time remaining = 104m23s
# Mean IoU                 =  0.284
# Image nb 141
# Time spent               =   5m19s
# Estimated time remaining = 104m04s
# Mean IoU                 =  0.282
#
# Image nb 142
# Time spent               =   5m22s
# Estimated time remaining = 104m00s
# Mean IoU                 =  0.283
#
# Image nb 143
# Time spent               =   5m23s
# Estimated time remaining = 103m33s
# Mean IoU                 =  0.285
#
# Image nb 144
# Time spent               =   5m23s
# Estimated time remaining = 102m57s
# Mean IoU                 =  0.287
#
# Image nb 145
# Time spent               =   5m26s
# Estimated time remaining = 103m11s
# Mean IoU                 =  0.286
#
# Image nb 146
# Time spent               =   5m30s
# Estimated time remaining = 103m47s
# Mean IoU                 =  0.284
#
# Image nb 147
# Time spent               =   5m32s
# Estimated time remaining = 103m40s
# Mean IoU                 =  0.282
#
# Image nb 148
# Time spent               =   5m33s
# Estimated time remaining = 103m07s
# Mean IoU                 =  0.283
#
# Image nb 149
# Time spent               =   5m36s
# Estimated time remaining = 103m17s
# Mean IoU                 =  0.282
#
# Image nb 150
# Time spent               =   5m39s
# Estimated time remaining = 103m29s
# Mean IoU                 =  0.280
#
# Image nb 151
# Time spent               =   5m41s
# Estimated time remaining = 103m17s
# Mean IoU                 =  0.282
#
# Image nb 152
# Time spent               =   5m43s
# Estimated time remaining = 103m13s
# Mean IoU                 =  0.279
#
# Image nb 153
# Time spent               =   5m45s
# Estimated time remaining = 103m08s
# Mean IoU                 =  0.278
#
# Image nb 154
# Time spent               =   5m49s
# Estimated time remaining = 103m45s
# Mean IoU                 =  0.277
#
# Image nb 155
# Time spent               =   5m51s
# Estimated time remaining = 103m24s
# Mean IoU                 =  0.277
#
# Image nb 156
# Time spent               =   5m52s
# Estimated time remaining = 103m00s
# Mean IoU                 =  0.280
#
# Image nb 157
# Time spent               =   5m54s
# Estimated time remaining = 103m02s
# Mean IoU                 =  0.280
#
# Image nb 158
# Time spent               =   5m55s
# Estimated time remaining = 102m34s
# Mean IoU                 =  0.282
#
# Image nb 159
# Time spent               =   6m01s
# Estimated time remaining = 103m40s
# Mean IoU                 =  0.283
#
# Image nb 160
# Time spent               =   6m03s
# Estimated time remaining = 103m26s
# Mean IoU                 =  0.283
#
# Image nb 161
# Time spent               =   6m06s
# Estimated time remaining = 103m38s
# Mean IoU                 =  0.283
#
# Image nb 162
# Time spent               =   6m08s
# Estimated time remaining = 103m37s
# Mean IoU                 =  0.284
#
# Image nb 163
# Time spent               =   6m10s
# Estimated time remaining = 103m22s
# Mean IoU                 =  0.284
#
# Image nb 164
# Time spent               =   6m14s
# Estimated time remaining = 104m00s
# Mean IoU                 =  0.284
#
# Image nb 165
# Time spent               =   6m16s
# Estimated time remaining = 103m43s
# Mean IoU                 =  0.285
#
# Image nb 166
# Time spent               =   6m17s
# Estimated time remaining = 103m32s
# Mean IoU                 =  0.284
#
# Image nb 167
# Time spent               =   6m20s
# Estimated time remaining = 103m31s
# Mean IoU                 =  0.284
#
# Image nb 168
# Time spent               =   6m23s
# Estimated time remaining = 103m48s
# Mean IoU                 =  0.284
#
# Image nb 169
# Time spent               =   6m31s
# Estimated time remaining = 105m11s
# Mean IoU                 =  0.282
#
# Image nb 170
# Time spent               =   6m32s
# Estimated time remaining = 104m48s
# Mean IoU                 =  0.284
#
# Image nb 171
# Time spent               =   6m38s
# Estimated time remaining = 105m48s
# Mean IoU                 =  0.283
#
# Image nb 172
# Time spent               =   6m40s
# Estimated time remaining = 105m44s
# Mean IoU                 =  0.283
#
# Image nb 173
# Time spent               =   6m41s
# Estimated time remaining = 105m19s
# Mean IoU                 =  0.284
#
# Image nb 174
# Time spent               =   6m42s
# Estimated time remaining = 104m57s
# Mean IoU                 =  0.286
#
# Image nb 175
# Time spent               =   6m43s
# Estimated time remaining = 104m36s
# Mean IoU                 =  0.287
#
# Image nb 176
# Time spent               =   6m46s
# Estimated time remaining = 104m37s
# Mean IoU                 =  0.285
#
# Image nb 177
# Time spent               =   6m47s
# Estimated time remaining = 104m25s
# Mean IoU                 =  0.285
#
# Image nb 178
# Time spent               =   6m48s
# Estimated time remaining = 104m02s
# Mean IoU                 =  0.285
#
# Image nb 179
# Time spent               =   6m50s
# Estimated time remaining = 103m45s
# Mean IoU                 =  0.284
#
# Image nb 180
# Time spent               =   6m50s
# Estimated time remaining = 103m23s
# Mean IoU                 =  0.286
#
# Image nb 181
# Time spent               =   6m51s
# Estimated time remaining = 103m01s
# Mean IoU                 =  0.285
#
# Image nb 182
# Time spent               =   6m54s
# Estimated time remaining = 103m03s
# Mean IoU                 =  0.284
#
# Image nb 183
# Time spent               =   6m55s
# Estimated time remaining = 102m49s
# Mean IoU                 =  0.285
#
# Image nb 184
# Time spent               =   6m58s
# Estimated time remaining = 102m47s
# Mean IoU                 =  0.288
#
# Image nb 185
# Time spent               =   7m00s
# Estimated time remaining = 102m42s
# Mean IoU                 =  0.288
#
# Image nb 186
# Time spent               =   7m01s
# Estimated time remaining = 102m28s
# Mean IoU                 =  0.288
#
# Image nb 187
# Time spent               =   7m04s
# Estimated time remaining = 102m27s
# Mean IoU                 =  0.288
#
# Image nb 188
# Time spent               =   7m05s
# Estimated time remaining = 102m07s
# Mean IoU                 =  0.290
#
# Image nb 189
# Time spent               =   7m10s
# Estimated time remaining = 102m53s
# Mean IoU                 =  0.287
#
# Image nb 190
# Time spent               =   7m13s
# Estimated time remaining = 103m02s
# Mean IoU                 =  0.287
#
# Image nb 191
# Time spent               =   7m14s
# Estimated time remaining = 102m42s
# Mean IoU                 =  0.288
#
# Image nb 192
# Time spent               =   7m15s
# Estimated time remaining = 102m13s
# Mean IoU                 =  0.289
#
# Image nb 193
# Time spent               =   7m25s
# Estimated time remaining = 104m05s
# Mean IoU                 =  0.289
#
# Image nb 194
# Time spent               =   7m29s
# Estimated time remaining = 104m18s
# Mean IoU                 =  0.289
#
# Image nb 195
# Time spent               =   7m30s
# Estimated time remaining = 104m04s
# Mean IoU                 =  0.288
#
# Image nb 196
# Time spent               =   7m32s
# Estimated time remaining = 103m55s
# Mean IoU                 =  0.289
#
# Image nb 197
# Time spent               =   7m34s
# Estimated time remaining = 103m45s
# Mean IoU                 =  0.290
#
# Image nb 198
# Time spent               =   7m34s
# Estimated time remaining = 103m20s
# Mean IoU                 =  0.290
#
# Image nb 199
# Time spent               =   7m36s
# Estimated time remaining = 103m08s
# Mean IoU                 =  0.290
#
# Image nb 200
# Time spent               =   7m37s
# Estimated time remaining = 102m46s
# Mean IoU                 =  0.291
#
# Image nb 201
# Time spent               =   7m38s
# Estimated time remaining = 102m27s
# Mean IoU                 =  0.292
#
# Image nb 202
# Time spent               =   7m40s
# Estimated time remaining = 102m21s
# Mean IoU                 =  0.294
#
# Image nb 203
# Time spent               =   7m41s
# Estimated time remaining = 102m02s
# Mean IoU                 =  0.294
#
# Image nb 204
# Time spent               =   7m45s
# Estimated time remaining = 102m35s
# Mean IoU                 =  0.293
#
# Image nb 205
# Time spent               =   7m51s
# Estimated time remaining = 103m14s
# Mean IoU                 =  0.290
#
# Image nb 206
# Time spent               =   7m52s
# Estimated time remaining = 102m56s
# Mean IoU                 =  0.292
#
# Image nb 207
# Time spent               =   7m53s
# Estimated time remaining = 102m32s
# Mean IoU                 =  0.294
#
# Image nb 208
# Time spent               =   7m55s
# Estimated time remaining = 102m28s
# Mean IoU                 =  0.295
#
# Image nb 209
# Time spent               =   7m57s
# Estimated time remaining = 102m30s
# Mean IoU                 =  0.294
#
# Image nb 210
# Time spent               =   8m00s
# Estimated time remaining = 102m38s
# Mean IoU                 =  0.293
# Image nb 211
# Time spent               =   8m02s
# Estimated time remaining = 102m24s
# Mean IoU                 =  0.294
#
# Image nb 212
# Time spent               =   8m04s
# Estimated time remaining = 102m15s
# Mean IoU                 =  0.293
#
# Image nb 213
# Time spent               =   8m05s
# Estimated time remaining = 102m07s
# Mean IoU                 =  0.292
#
# Image nb 214
# Time spent               =   8m06s
# Estimated time remaining = 101m43s
# Mean IoU                 =  0.292
#
# Image nb 215
# Time spent               =   8m07s
# Estimated time remaining = 101m25s
# Mean IoU                 =  0.293
#
# Image nb 216
# Time spent               =   8m09s
# Estimated time remaining = 101m15s
# Mean IoU                 =  0.292
#
# Image nb 217
# Time spent               =   8m11s
# Estimated time remaining = 101m18s
# Mean IoU                 =  0.294
#
# Image nb 218
# Time spent               =   8m15s
# Estimated time remaining = 101m37s
# Mean IoU                 =  0.292
#
# Image nb 219
# Time spent               =   8m17s
# Estimated time remaining = 101m32s
# Mean IoU                 =  0.293
#
# Image nb 220
# Time spent               =   8m19s
# Estimated time remaining = 101m18s
# Mean IoU                 =  0.293
#
# Image nb 221
# Time spent               =   8m24s
# Estimated time remaining = 101m53s
# Mean IoU                 =  0.290
#
# Image nb 222
# Time spent               =   8m25s
# Estimated time remaining = 101m39s
# Mean IoU                 =  0.291
#
# Image nb 223
# Time spent               =   8m32s
# Estimated time remaining = 102m27s
# Mean IoU                 =  0.290
#
# Image nb 224
# Time spent               =   8m32s
# Estimated time remaining = 102m03s
# Mean IoU                 =  0.289
#
# Image nb 225
# Time spent               =   8m33s
# Estimated time remaining = 101m41s
# Mean IoU                 =  0.290
#
# Image nb 226
# Time spent               =   8m37s
# Estimated time remaining = 101m59s
# Mean IoU                 =  0.290
#
# Image nb 227
# Time spent               =   8m39s
# Estimated time remaining = 101m58s
# Mean IoU                 =  0.289
#
# Image nb 228
# Time spent               =   8m43s
# Estimated time remaining = 102m11s
# Mean IoU                 =  0.289
#
# Image nb 229
# Time spent               =   8m46s
# Estimated time remaining = 102m23s
# Mean IoU                 =  0.288
#
# Image nb 230
# Time spent               =   8m48s
# Estimated time remaining = 102m13s
# Mean IoU                 =  0.288
#
# Image nb 231
# Time spent               =   8m50s
# Estimated time remaining = 102m11s
# Mean IoU                 =  0.289
#
# Image nb 232
# Time spent               =   8m53s
# Estimated time remaining = 102m17s
# Mean IoU                 =  0.288
#
# Image nb 233
# Time spent               =   8m54s
# Estimated time remaining = 101m55s
# Mean IoU                 =  0.290
#
# Image nb 234
# Time spent               =   8m56s
# Estimated time remaining = 101m48s
# Mean IoU                 =  0.292
#
# Image nb 235
# Time spent               =   8m58s
# Estimated time remaining = 101m44s
# Mean IoU                 =  0.290
#
# Image nb 236
# Time spent               =   9m02s
# Estimated time remaining = 102m04s
# Mean IoU                 =  0.289
#
# Image nb 237
# Time spent               =   9m03s
# Estimated time remaining = 101m47s
# Mean IoU                 =  0.289
#
# Image nb 238
# Time spent               =   9m05s
# Estimated time remaining = 101m42s
# Mean IoU                 =  0.288
#
# Image nb 239
# Time spent               =   9m10s
# Estimated time remaining = 102m13s
# Mean IoU                 =  0.288
#
# Image nb 240
# Time spent               =   9m11s
# Estimated time remaining = 101m57s
# Mean IoU                 =  0.289
#
# Image nb 241
# Time spent               =   9m12s
# Estimated time remaining = 101m35s
# Mean IoU                 =  0.290
#
# Image nb 242
# Time spent               =   9m12s
# Estimated time remaining = 101m14s
# Mean IoU                 =  0.291
#
# Image nb 243
# Time spent               =   9m20s
# Estimated time remaining = 102m12s
# Mean IoU                 =  0.291
#
# Image nb 244
# Time spent               =   9m21s
# Estimated time remaining = 101m58s
# Mean IoU                 =  0.291
#
# Image nb 245
# Time spent               =   9m23s
# Estimated time remaining = 101m51s
# Mean IoU                 =  0.291
#
# Image nb 246
# Time spent               =   9m25s
# Estimated time remaining = 101m41s
# Mean IoU                 =  0.292
#
# Image nb 247
# Time spent               =   9m26s
# Estimated time remaining = 101m31s
# Mean IoU                 =  0.292
#
# Image nb 248
# Time spent               =   9m27s
# Estimated time remaining = 101m07s
# Mean IoU                 =  0.293
#
# Image nb 249
# Time spent               =   9m28s
# Estimated time remaining = 100m58s
# Mean IoU                 =  0.293
#
# Image nb 250
# Time spent               =   9m29s
# Estimated time remaining = 100m39s
# Mean IoU                 =  0.293
#
# Image nb 251
# Time spent               =   9m33s
# Estimated time remaining = 100m54s
# Mean IoU                 =  0.294
#
# Image nb 252
# Time spent               =   9m37s
# Estimated time remaining = 101m07s
# Mean IoU                 =  0.292
#
# Image nb 253
# Time spent               =   9m41s
# Estimated time remaining = 101m22s
# Mean IoU                 =  0.292
#
# Image nb 254
# Time spent               =   9m41s
# Estimated time remaining = 101m04s
# Mean IoU                 =  0.293
#
# Image nb 255
# Time spent               =   9m42s
# Estimated time remaining = 100m48s
# Mean IoU                 =  0.294
#
# Image nb 256
# Time spent               =   9m43s
# Estimated time remaining = 100m29s
# Mean IoU                 =  0.295
#
# Image nb 257
# Time spent               =   9m45s
# Estimated time remaining = 100m26s
# Mean IoU                 =  0.295
#
# Image nb 258
# Time spent               =   9m46s
# Estimated time remaining = 100m13s
# Mean IoU                 =  0.296
#
# Image nb 259
# Time spent               =   9m48s
# Estimated time remaining = 100m08s
# Mean IoU                 =  0.297
#
# Image nb 260
# Time spent               =   9m49s
# Estimated time remaining =  99m48s
# Mean IoU                 =  0.298
#
# Image nb 261
# Time spent               =   9m50s
# Estimated time remaining =  99m34s
# Mean IoU                 =  0.298
#
# Image nb 262
# Time spent               =   9m53s
# Estimated time remaining =  99m35s
# Mean IoU                 =  0.297
#
# Image nb 263
# Time spent               =   9m59s
# Estimated time remaining = 100m19s
# Mean IoU                 =  0.298
#
# Image nb 264
# Time spent               =  10m01s
# Estimated time remaining = 100m11s
# Mean IoU                 =  0.298
#
# Image nb 265
# Time spent               =  10m01s
# Estimated time remaining =  99m50s
# Mean IoU                 =  0.299
#
# Image nb 266
# Time spent               =  10m12s
# Estimated time remaining = 101m06s
# Mean IoU                 =  0.296
#
# Image nb 267
# Time spent               =  10m12s
# Estimated time remaining = 100m49s
# Mean IoU                 =  0.295
#
# Image nb 268
# Time spent               =  10m13s
# Estimated time remaining = 100m33s
# Mean IoU                 =  0.295
#
# Image nb 269
# Time spent               =  10m17s
# Estimated time remaining = 100m47s
# Mean IoU                 =  0.294
#
# Image nb 270
# Time spent               =  10m19s
# Estimated time remaining = 100m35s
# Mean IoU                 =  0.294
#
# Image nb 271
# Time spent               =  10m25s
# Estimated time remaining = 101m17s
# Mean IoU                 =  0.293
#
# Image nb 272
# Time spent               =  10m28s
# Estimated time remaining = 101m22s
# Mean IoU                 =  0.293
#
# Image nb 273
# Time spent               =  10m32s
# Estimated time remaining = 101m29s
# Mean IoU                 =  0.293
#
# Image nb 274
# Time spent               =  10m35s
# Estimated time remaining = 101m38s
# Mean IoU                 =  0.293
#
# Image nb 275
# Time spent               =  10m37s
# Estimated time remaining = 101m27s
# Mean IoU                 =  0.292
#
# Image nb 276
# Time spent               =  10m40s
# Estimated time remaining = 101m37s
# Mean IoU                 =  0.293
#
# Image nb 277
# Time spent               =  10m43s
# Estimated time remaining = 101m35s
# Mean IoU                 =  0.292
#
# Image nb 278
# Time spent               =  10m44s
# Estimated time remaining = 101m25s
# Mean IoU                 =  0.292
#
# Image nb 279
# Time spent               =  10m45s
# Estimated time remaining = 101m08s
# Mean IoU                 =  0.292
#
# Image nb 280
# Time spent               =  10m48s
# Estimated time remaining = 101m11s
# Mean IoU                 =  0.292
# Image nb 281
# Time spent               =  10m49s
# Estimated time remaining = 100m56s
# Mean IoU                 =  0.293
#
# Image nb 282
# Time spent               =  10m53s
# Estimated time remaining = 101m11s
# Mean IoU                 =  0.293
#
# Image nb 283
# Time spent               =  10m56s
# Estimated time remaining = 101m15s
# Mean IoU                 =  0.294
#
# Image nb 284
# Time spent               =  10m57s
# Estimated time remaining = 100m59s
# Mean IoU                 =  0.294
#
# Image nb 285
# Time spent               =  10m58s
# Estimated time remaining = 100m45s
# Mean IoU                 =  0.295
#
# Image nb 286
# Time spent               =  11m01s
# Estimated time remaining = 100m54s
# Mean IoU                 =  0.294
#
# Image nb 287
# Time spent               =  11m09s
# Estimated time remaining = 101m37s
# Mean IoU                 =  0.293
#
# Image nb 288
# Time spent               =  11m11s
# Estimated time remaining = 101m35s
# Mean IoU                 =  0.293
#
# Image nb 289
# Time spent               =  11m12s
# Estimated time remaining = 101m22s
# Mean IoU                 =  0.293
#
# Image nb 290
# Time spent               =  11m14s
# Estimated time remaining = 101m15s
# Mean IoU                 =  0.293
#
# Image nb 291
# Time spent               =  11m14s
# Estimated time remaining = 100m58s
# Mean IoU                 =  0.292
#
# Image nb 292
# Time spent               =  11m15s
# Estimated time remaining = 100m40s
# Mean IoU                 =  0.292
#
# Image nb 293
# Time spent               =  11m18s
# Estimated time remaining = 100m43s
# Mean IoU                 =  0.292
#
# Image nb 294
# Time spent               =  11m19s
# Estimated time remaining = 100m29s
# Mean IoU                 =  0.291
#
# Image nb 295
# Time spent               =  11m23s
# Estimated time remaining = 100m44s
# Mean IoU                 =  0.290
#
# Image nb 296
# Time spent               =  11m33s
# Estimated time remaining = 101m51s
# Mean IoU                 =  0.288
#
# Image nb 297
# Time spent               =  11m36s
# Estimated time remaining = 101m50s
# Mean IoU                 =  0.287
#
# Image nb 298
# Time spent               =  11m37s
# Estimated time remaining = 101m34s
# Mean IoU                 =  0.288
#
# Image nb 299
# Time spent               =  11m38s
# Estimated time remaining = 101m28s
# Mean IoU                 =  0.288
#
# Image nb 300
# Time spent               =  11m43s
# Estimated time remaining = 101m43s
# Mean IoU                 =  0.287
#
# Image nb 301
# Time spent               =  11m44s
# Estimated time remaining = 101m30s
# Mean IoU                 =  0.287
#
# Image nb 302
# Time spent               =  11m51s
# Estimated time remaining = 102m12s
# Mean IoU                 =  0.286
#
# Image nb 303
# Time spent               =  11m52s
# Estimated time remaining = 101m57s
# Mean IoU                 =  0.288
#
# Image nb 304
# Time spent               =  11m54s
# Estimated time remaining = 101m46s
# Mean IoU                 =  0.288
#
# Image nb 305
# Time spent               =  11m55s
# Estimated time remaining = 101m32s
# Mean IoU                 =  0.289
#
# Image nb 306
# Time spent               =  11m55s
# Estimated time remaining = 101m16s
# Mean IoU                 =  0.289
#
# Image nb 307
# Time spent               =  11m56s
# Estimated time remaining = 100m58s
# Mean IoU                 =  0.289
#
# Image nb 308
# Time spent               =  11m57s
# Estimated time remaining = 100m49s
# Mean IoU                 =  0.291
#
# Image nb 309
# Time spent               =  11m58s
# Estimated time remaining = 100m32s
# Mean IoU                 =  0.291
#
# Image nb 310
# Time spent               =  11m59s
# Estimated time remaining = 100m23s
# Mean IoU                 =  0.291
#
# Image nb 311
# Time spent               =  12m01s
# Estimated time remaining = 100m14s
# Mean IoU                 =  0.290
#
# Image nb 312
# Time spent               =  12m02s
# Estimated time remaining = 100m04s
# Mean IoU                 =  0.290
#
# Image nb 313
# Time spent               =  12m05s
# Estimated time remaining = 100m01s
# Mean IoU                 =  0.289
#
# Image nb 314
# Time spent               =  12m10s
# Estimated time remaining = 100m25s
# Mean IoU                 =  0.288
#
# Image nb 315
# Time spent               =  12m14s
# Estimated time remaining = 100m38s
# Mean IoU                 =  0.287
#
# Image nb 316
# Time spent               =  12m18s
# Estimated time remaining = 100m46s
# Mean IoU                 =  0.287
#
# Image nb 317
# Time spent               =  12m19s
# Estimated time remaining = 100m38s
# Mean IoU                 =  0.286
#
# Image nb 318
# Time spent               =  12m21s
# Estimated time remaining = 100m33s
# Mean IoU                 =  0.287
#
# Image nb 319
# Time spent               =  12m23s
# Estimated time remaining = 100m20s
# Mean IoU                 =  0.287
#
# Image nb 320
# Time spent               =  12m23s
# Estimated time remaining = 100m03s
# Mean IoU                 =  0.287
#
# Image nb 321
# Time spent               =  12m24s
# Estimated time remaining =  99m54s
# Mean IoU                 =  0.288
#
# Image nb 322
# Time spent               =  12m26s
# Estimated time remaining =  99m46s
# Mean IoU                 =  0.288
#
# Image nb 323
# Time spent               =  12m28s
# Estimated time remaining =  99m37s
# Mean IoU                 =  0.288
#
# Image nb 324
# Time spent               =  12m32s
# Estimated time remaining =  99m50s
# Mean IoU                 =  0.286
#
# Image nb 325
# Time spent               =  12m33s
# Estimated time remaining =  99m39s
# Mean IoU                 =  0.286
#
# Image nb 326
# Time spent               =  12m37s
# Estimated time remaining =  99m52s
# Mean IoU                 =  0.286
#
# Image nb 327
# Time spent               =  12m39s
# Estimated time remaining =  99m47s
# Mean IoU                 =  0.286
#
# Image nb 328
# Time spent               =  12m42s
# Estimated time remaining =  99m51s
# Mean IoU                 =  0.287
#
# Image nb 329
# Time spent               =  12m48s
# Estimated time remaining = 100m13s
# Mean IoU                 =  0.286
#
# Image nb 330
# Time spent               =  12m51s
# Estimated time remaining = 100m15s
# Mean IoU                 =  0.285
#
# Image nb 331
# Time spent               =  12m52s
# Estimated time remaining = 100m03s
# Mean IoU                 =  0.285
#
# Image nb 332
# Time spent               =  12m53s
# Estimated time remaining =  99m56s
# Mean IoU                 =  0.285
#
# Image nb 333
# Time spent               =  12m56s
# Estimated time remaining =  99m57s
# Mean IoU                 =  0.284
#
# Image nb 334
# Time spent               =  12m59s
# Estimated time remaining = 100m00s
# Mean IoU                 =  0.284
#
# Image nb 335
# Time spent               =  13m00s
# Estimated time remaining =  99m46s
# Mean IoU                 =  0.285
#
# Image nb 336
# Time spent               =  13m02s
# Estimated time remaining =  99m42s
# Mean IoU                 =  0.284
#
# Image nb 337
# Time spent               =  13m04s
# Estimated time remaining =  99m34s
# Mean IoU                 =  0.284
#
# Image nb 338
# Time spent               =  13m06s
# Estimated time remaining =  99m34s
# Mean IoU                 =  0.283
#
# Image nb 339
# Time spent               =  13m07s
# Estimated time remaining =  99m20s
# Mean IoU                 =  0.284
#
# Image nb 340
# Time spent               =  13m10s
# Estimated time remaining =  99m22s
# Mean IoU                 =  0.283
#
# Image nb 341
# Time spent               =  13m11s
# Estimated time remaining =  99m09s
# Mean IoU                 =  0.284
#
# Image nb 342
# Time spent               =  13m16s
# Estimated time remaining =  99m31s
# Mean IoU                 =  0.282
#
# Image nb 343
# Time spent               =  13m18s
# Estimated time remaining =  99m21s
# Mean IoU                 =  0.283
#
# Image nb 344
# Time spent               =  13m19s
# Estimated time remaining =  99m11s
# Mean IoU                 =  0.283
#
# Image nb 345
# Time spent               =  13m23s
# Estimated time remaining =  99m20s
# Mean IoU                 =  0.282
#
# Image nb 346
# Time spent               =  13m27s
# Estimated time remaining =  99m30s
# Mean IoU                 =  0.282
#
# Image nb 347
# Time spent               =  13m28s
# Estimated time remaining =  99m21s
# Mean IoU                 =  0.281
#
# Image nb 348
# Time spent               =  13m33s
# Estimated time remaining =  99m33s
# Mean IoU                 =  0.281
#
# Image nb 349
# Time spent               =  13m33s
# Estimated time remaining =  99m17s
# Mean IoU                 =  0.282
#
# Image nb 350
# Time spent               =  13m38s
# Estimated time remaining =  99m32s
# Mean IoU                 =  0.281
# Image nb 351
# Time spent               =  13m41s
# Estimated time remaining =  99m39s
# Mean IoU                 =  0.281
#
# Image nb 352
# Time spent               =  13m42s
# Estimated time remaining =  99m26s
# Mean IoU                 =  0.282
#
# Image nb 353
# Time spent               =  13m43s
# Estimated time remaining =  99m14s
# Mean IoU                 =  0.282
#
# Image nb 354
# Time spent               =  13m44s
# Estimated time remaining =  99m03s
# Mean IoU                 =  0.283
#
# Image nb 355
# Time spent               =  13m46s
# Estimated time remaining =  98m57s
# Mean IoU                 =  0.282
#
# Image nb 356
# Time spent               =  13m47s
# Estimated time remaining =  98m45s
# Mean IoU                 =  0.282
#
# Image nb 357
# Time spent               =  13m50s
# Estimated time remaining =  98m48s
# Mean IoU                 =  0.282
#
# Image nb 358
# Time spent               =  13m55s
# Estimated time remaining =  99m04s
# Mean IoU                 =  0.283
#
# Image nb 359
# Time spent               =  13m57s
# Estimated time remaining =  98m58s
# Mean IoU                 =  0.282
#
# Image nb 360
# Time spent               =  13m58s
# Estimated time remaining =  98m44s
# Mean IoU                 =  0.282
#
# Image nb 361
# Time spent               =  13m58s
# Estimated time remaining =  98m29s
# Mean IoU                 =  0.282
#
# Image nb 362
# Time spent               =  14m01s
# Estimated time remaining =  98m28s
# Mean IoU                 =  0.282
#
# Image nb 363
# Time spent               =  14m02s
# Estimated time remaining =  98m21s
# Mean IoU                 =  0.283
#
# Image nb 364
# Time spent               =  14m03s
# Estimated time remaining =  98m06s
# Mean IoU                 =  0.283
#
# Image nb 365
# Time spent               =  14m04s
# Estimated time remaining =  97m57s
# Mean IoU                 =  0.284
#
# Image nb 366
# Time spent               =  14m05s
# Estimated time remaining =  97m44s
# Mean IoU                 =  0.285
#
# Image nb 367
# Time spent               =  14m07s
# Estimated time remaining =  97m40s
# Mean IoU                 =  0.285
#
# Image nb 368
# Time spent               =  14m08s
# Estimated time remaining =  97m26s
# Mean IoU                 =  0.286
#
# Image nb 369
# Time spent               =  14m08s
# Estimated time remaining =  97m11s
# Mean IoU                 =  0.287
#
# Image nb 370
# Time spent               =  14m09s
# Estimated time remaining =  97m00s
# Mean IoU                 =  0.287
#
# Image nb 371
# Time spent               =  14m10s
# Estimated time remaining =  96m51s
# Mean IoU                 =  0.288
#
# Image nb 372
# Time spent               =  14m18s
# Estimated time remaining =  97m24s
# Mean IoU                 =  0.287
#
# Image nb 373
# Time spent               =  14m19s
# Estimated time remaining =  97m13s
# Mean IoU                 =  0.287
#
# Image nb 374
# Time spent               =  14m21s
# Estimated time remaining =  97m09s
# Mean IoU                 =  0.286
#
# Image nb 375
# Time spent               =  14m24s
# Estimated time remaining =  97m11s
# Mean IoU                 =  0.285
#
# Image nb 376
# Time spent               =  14m25s
# Estimated time remaining =  97m00s
# Mean IoU                 =  0.285
#
# Image nb 377
# Time spent               =  14m26s
# Estimated time remaining =  96m49s
# Mean IoU                 =  0.285
#
# Image nb 378
# Time spent               =  14m30s
# Estimated time remaining =  97m02s
# Mean IoU                 =  0.285
#
# Image nb 379
# Time spent               =  14m33s
# Estimated time remaining =  97m03s
# Mean IoU                 =  0.285
#
# Image nb 380
# Time spent               =  14m39s
# Estimated time remaining =  97m25s
# Mean IoU                 =  0.284
#
# Image nb 381
# Time spent               =  14m40s
# Estimated time remaining =  97m16s
# Mean IoU                 =  0.284
#
# Image nb 382
# Time spent               =  14m41s
# Estimated time remaining =  97m04s
# Mean IoU                 =  0.284
#
# Image nb 383
# Time spent               =  14m42s
# Estimated time remaining =  96m52s
# Mean IoU                 =  0.284
#
# Image nb 384
# Time spent               =  14m45s
# Estimated time remaining =  96m52s
# Mean IoU                 =  0.284
#
# Image nb 385
# Time spent               =  14m51s
# Estimated time remaining =  97m17s
# Mean IoU                 =  0.284
#
# Image nb 386
# Time spent               =  14m52s
# Estimated time remaining =  97m05s
# Mean IoU                 =  0.284
#
# Image nb 387
# Time spent               =  14m53s
# Estimated time remaining =  96m52s
# Mean IoU                 =  0.285
#
# Image nb 388
# Time spent               =  14m56s
# Estimated time remaining =  96m58s
# Mean IoU                 =  0.285
#
# Image nb 389
# Time spent               =  15m01s
# Estimated time remaining =  97m11s
# Mean IoU                 =  0.284
#
# Image nb 390
# Time spent               =  15m04s
# Estimated time remaining =  97m12s
# Mean IoU                 =  0.284
#
# Image nb 391
# Time spent               =  15m04s
# Estimated time remaining =  96m58s
# Mean IoU                 =  0.285
#
# Image nb 392
# Time spent               =  15m06s
# Estimated time remaining =  96m49s
# Mean IoU                 =  0.285
#
# Image nb 393
# Time spent               =  15m07s
# Estimated time remaining =  96m41s
# Mean IoU                 =  0.285
#
# Image nb 394
# Time spent               =  15m12s
# Estimated time remaining =  96m55s
# Mean IoU                 =  0.286
#
# Image nb 395
# Time spent               =  15m14s
# Estimated time remaining =  96m53s
# Mean IoU                 =  0.285
#
# Image nb 396
# Time spent               =  15m15s
# Estimated time remaining =  96m43s
# Mean IoU                 =  0.286
#
# Image nb 397
# Time spent               =  15m17s
# Estimated time remaining =  96m39s
# Mean IoU                 =  0.285
#
# Image nb 398
# Time spent               =  15m18s
# Estimated time remaining =  96m26s
# Mean IoU                 =  0.285
#
# Image nb 399
# Time spent               =  15m24s
# Estimated time remaining =  96m48s
# Mean IoU                 =  0.285
#
# Image nb 400
# Time spent               =  15m27s
# Estimated time remaining =  96m51s
# Mean IoU                 =  0.285
#
# Image nb 401
# Time spent               =  15m29s
# Estimated time remaining =  96m43s
# Mean IoU                 =  0.285
#
# Image nb 402
# Time spent               =  15m31s
# Estimated time remaining =  96m42s
# Mean IoU                 =  0.285
#
# Image nb 403
# Time spent               =  15m35s
# Estimated time remaining =  96m50s
# Mean IoU                 =  0.285
#
# Image nb 404
# ...
# Mean IoU                 =  0.338
#
# Image nb 1720
# Time spent               =  58m14s
# Estimated time remaining =  40m20s
# Mean IoU                 =  0.338
#
# Image nb 1721
# Time spent               =  58m14s
# Estimated time remaining =  40m17s
# Mean IoU                 =  0.338
#
# Image nb 1722
# Time spent               =  58m19s
# Estimated time remaining =  40m16s
# Mean IoU                 =  0.338
#
# Image nb 1723
# Time spent               =  58m21s
# Estimated time remaining =  40m14s
# Mean IoU                 =  0.338
#
# Image nb 1724
# Time spent               =  58m22s
# Estimated time remaining =  40m12s
# Mean IoU                 =  0.338
#
# Image nb 1725
# Time spent               =  58m23s
# Estimated time remaining =  40m09s
# Mean IoU                 =  0.338
#
# Image nb 1726
# Time spent               =  58m26s
# Estimated time remaining =  40m08s
# Mean IoU                 =  0.338
#
# Image nb 1727
# Time spent               =  58m30s
# Estimated time remaining =  40m07s
# Mean IoU                 =  0.338
#
# Image nb 1728
# Time spent               =  58m31s
# Estimated time remaining =  40m04s
# Mean IoU                 =  0.338
#
# Image nb 1729
# Time spent               =  58m32s
# Estimated time remaining =  40m02s
# Mean IoU                 =  0.338
#
# Image nb 1730
# Time spent               =  58m34s
# Estimated time remaining =  39m59s
# Mean IoU                 =  0.338
#
# Image nb 1731
# Time spent               =  58m41s
# Estimated time remaining =  40m01s
# Mean IoU                 =  0.338
#
# Image nb 1732
# Time spent               =  58m42s
# Estimated time remaining =  39m58s
# Mean IoU                 =  0.338
#
# Image nb 1733
# Time spent               =  58m43s
# Estimated time remaining =  39m55s
# Mean IoU                 =  0.338
#
# Image nb 1734
# Time spent               =  58m45s
# Estimated time remaining =  39m53s
# Mean IoU                 =  0.338
#
# Image nb 1735
# Time spent               =  58m48s
# Estimated time remaining =  39m51s
# Mean IoU                 =  0.338
#
# Image nb 1736
# Time spent               =  58m48s
# Estimated time remaining =  39m49s
# Mean IoU                 =  0.338
#
# Image nb 1737
# Time spent               =  58m50s
# Estimated time remaining =  39m46s
# Mean IoU                 =  0.338
#
# Image nb 1738
# Time spent               =  58m53s
# Estimated time remaining =  39m45s
# Mean IoU                 =  0.338
#
# Image nb 1739
# Time spent               =  58m59s
# Estimated time remaining =  39m45s
# Mean IoU                 =  0.337
#
# Image nb 1740
# Time spent               =  59m05s
# Estimated time remaining =  39m46s
# Mean IoU                 =  0.337
# Image nb 1741
# Time spent               =  59m06s
# Estimated time remaining =  39m44s
# Mean IoU                 =  0.337
#
# Image nb 1742
# Time spent               =  59m12s
# Estimated time remaining =  39m44s
# Mean IoU                 =  0.337
#
# Image nb 1743
# Time spent               =  59m12s
# Estimated time remaining =  39m41s
# Mean IoU                 =  0.337
#
# Image nb 1744
# Time spent               =  59m13s
# Estimated time remaining =  39m38s
# Mean IoU                 =  0.337
#
# Image nb 1745
# Time spent               =  59m14s
# Estimated time remaining =  39m35s
# Mean IoU                 =  0.337
#
# Image nb 1746
# Time spent               =  59m14s
# Estimated time remaining =  39m32s
# Mean IoU                 =  0.337
#
# Image nb 1747
# Time spent               =  59m17s
# Estimated time remaining =  39m30s
# Mean IoU                 =  0.337
#
# Image nb 1748
# Time spent               =  59m18s
# Estimated time remaining =  39m28s
# Mean IoU                 =  0.338
#
# Image nb 1749
# Time spent               =  59m20s
# Estimated time remaining =  39m26s
# Mean IoU                 =  0.337
#
# Image nb 1750
# Time spent               =  59m21s
# Estimated time remaining =  39m23s
# Mean IoU                 =  0.337
#
# Image nb 1751
# Time spent               =  59m23s
# Estimated time remaining =  39m21s
# Mean IoU                 =  0.337
#
# Image nb 1752
# Time spent               =  59m23s
# Estimated time remaining =  39m18s
# Mean IoU                 =  0.337
#
# Image nb 1753
# Time spent               =  59m25s
# Estimated time remaining =  39m15s
# Mean IoU                 =  0.337
#
# Image nb 1754
# Time spent               =  59m33s
# Estimated time remaining =  39m17s
# Mean IoU                 =  0.337
#
# Image nb 1755
# Time spent               =  59m39s
# Estimated time remaining =  39m18s
# Mean IoU                 =  0.337
#
# Image nb 1756
# Time spent               =  59m42s
# Estimated time remaining =  39m17s
# Mean IoU                 =  0.337
#
# Image nb 1757
# Time spent               =  59m43s
# Estimated time remaining =  39m14s
# Mean IoU                 =  0.337
#
# Image nb 1758
# Time spent               =  59m45s
# Estimated time remaining =  39m11s
# Mean IoU                 =  0.336
#
# Image nb 1759
# Time spent               =  59m45s
# Estimated time remaining =  39m09s
# Mean IoU                 =  0.337
#
# Image nb 1760
# Time spent               =  59m47s
# Estimated time remaining =  39m06s
# Mean IoU                 =  0.337
#
# Image nb 1761
# Time spent               =  59m50s
# Estimated time remaining =  39m05s
# Mean IoU                 =  0.337
#
# Image nb 1762
# Time spent               =  59m52s
# Estimated time remaining =  39m03s
# Mean IoU                 =  0.336
#
# Image nb 1763
# Time spent               =  59m52s
# Estimated time remaining =  39m00s
# Mean IoU                 =  0.336
#
# Image nb 1764
# Time spent               =  59m54s
# Estimated time remaining =  38m57s
# Mean IoU                 =  0.336
#
# Image nb 1765
# Time spent               =  60m02s
# Estimated time remaining =  38m59s
# Mean IoU                 =  0.336
#
# Image nb 1766
# Time spent               =  60m03s
# Estimated time remaining =  38m57s
# Mean IoU                 =  0.336
#
# Image nb 1767
# Time spent               =  60m04s
# Estimated time remaining =  38m54s
# Mean IoU                 =  0.336
#
# Image nb 1768
# Time spent               =  60m06s
# Estimated time remaining =  38m52s
# Mean IoU                 =  0.336
#
# Image nb 1769
# Time spent               =  60m07s
# Estimated time remaining =  38m49s
# Mean IoU                 =  0.336
#
# Image nb 1770
# Time spent               =  60m11s
# Estimated time remaining =  38m48s
# Mean IoU                 =  0.336
#
# Image nb 1771
# Time spent               =  60m11s
# Estimated time remaining =  38m45s
# Mean IoU                 =  0.336
#
# Image nb 1772
# Time spent               =  60m14s
# Estimated time remaining =  38m43s
# Mean IoU                 =  0.336
#
# Image nb 1773
# Time spent               =  60m17s
# Estimated time remaining =  38m42s
# Mean IoU                 =  0.336
#
# Image nb 1774
# Time spent               =  60m19s
# Estimated time remaining =  38m40s
# Mean IoU                 =  0.336
#
# Image nb 1775
# Time spent               =  60m20s
# Estimated time remaining =  38m37s
# Mean IoU                 =  0.336
#
# Image nb 1776
# Time spent               =  60m21s
# Estimated time remaining =  38m34s
# Mean IoU                 =  0.336
#
# Image nb 1777
# Time spent               =  60m22s
# Estimated time remaining =  38m32s
# Mean IoU                 =  0.336
#
# Image nb 1778
# Time spent               =  60m22s
# Estimated time remaining =  38m29s
# Mean IoU                 =  0.336
#
# Image nb 1779
# Time spent               =  60m24s
# Estimated time remaining =  38m27s
# Mean IoU                 =  0.336
#
# Image nb 1780
# Time spent               =  60m25s
# Estimated time remaining =  38m24s
# Mean IoU                 =  0.336
#
# Image nb 1781
# Time spent               =  60m26s
# Estimated time remaining =  38m21s
# Mean IoU                 =  0.336
#
# Image nb 1782
# Time spent               =  60m26s
# Estimated time remaining =  38m18s
# Mean IoU                 =  0.337
#
# Image nb 1783
# Time spent               =  60m27s
# Estimated time remaining =  38m15s
# Mean IoU                 =  0.337
#
# Image nb 1784
# Time spent               =  60m28s
# Estimated time remaining =  38m13s
# Mean IoU                 =  0.337
#
# Image nb 1785
# Time spent               =  60m30s
# Estimated time remaining =  38m11s
# Mean IoU                 =  0.337
#
# Image nb 1786
# Time spent               =  60m40s
# Estimated time remaining =  38m13s
# Mean IoU                 =  0.337
#
# Image nb 1787
# Time spent               =  60m41s
# Estimated time remaining =  38m11s
# Mean IoU                 =  0.337
#
# Image nb 1788
# Time spent               =  60m42s
# Estimated time remaining =  38m08s
# Mean IoU                 =  0.337
#
# Image nb 1789
# Time spent               =  60m45s
# Estimated time remaining =  38m07s
# Mean IoU                 =  0.337
#
# Image nb 1790
# Time spent               =  60m46s
# Estimated time remaining =  38m04s
# Mean IoU                 =  0.337
#
# Image nb 1791
# Time spent               =  60m52s
# Estimated time remaining =  38m04s
# Mean IoU                 =  0.337
#
# Image nb 1792
# Time spent               =  60m52s
# Estimated time remaining =  38m01s
# Mean IoU                 =  0.337
#
# Image nb 1793
# Time spent               =  60m54s
# Estimated time remaining =  37m59s
# Mean IoU                 =  0.337
#
# Image nb 1794
# Time spent               =  60m56s
# Estimated time remaining =  37m57s
# Mean IoU                 =  0.337
#
# Image nb 1795
# Time spent               =  60m59s
# Estimated time remaining =  37m55s
# Mean IoU                 =  0.337
#
# Image nb 1796
# Time spent               =  61m01s
# Estimated time remaining =  37m54s
# Mean IoU                 =  0.337
#
# Image nb 1797
# Time spent               =  61m02s
# Estimated time remaining =  37m51s
# Mean IoU                 =  0.337
#
# Image nb 1798
# Time spent               =  61m04s
# Estimated time remaining =  37m49s
# Mean IoU                 =  0.337
#
# Image nb 1799
# Time spent               =  61m04s
# Estimated time remaining =  37m46s
# Mean IoU                 =  0.337
#
# Image nb 1800
# Time spent               =  61m07s
# Estimated time remaining =  37m44s
# Mean IoU                 =  0.337
#
# Image nb 1801
# Time spent               =  61m08s
# Estimated time remaining =  37m41s
# Mean IoU                 =  0.337
#
# Image nb 1802
# Time spent               =  61m09s
# Estimated time remaining =  37m38s
# Mean IoU                 =  0.337
#
# Image nb 1803
# Time spent               =  61m10s
# Estimated time remaining =  37m36s
# Mean IoU                 =  0.337
#
# Image nb 1804
# Time spent               =  61m12s
# Estimated time remaining =  37m34s
# Mean IoU                 =  0.337
#
# Image nb 1805
# Time spent               =  61m13s
# Estimated time remaining =  37m31s
# Mean IoU                 =  0.337
#
# Image nb 1806
# Time spent               =  61m14s
# Estimated time remaining =  37m28s
# Mean IoU                 =  0.337
#
# Image nb 1807
# Time spent               =  61m14s
# Estimated time remaining =  37m25s
# Mean IoU                 =  0.337
#
# Image nb 1808
# Time spent               =  61m15s
# Estimated time remaining =  37m22s
# Mean IoU                 =  0.337
#
# Image nb 1809
# Time spent               =  61m16s
# Estimated time remaining =  37m20s
# Mean IoU                 =  0.337
# Image nb 1810
# Time spent               =  61m19s
# Estimated time remaining =  37m18s
# Mean IoU                 =  0.337
#
# Image nb 1811
# Time spent               =  61m19s
# Estimated time remaining =  37m15s
# Mean IoU                 =  0.337
#
# Image nb 1812
# Time spent               =  61m20s
# Estimated time remaining =  37m13s
# Mean IoU                 =  0.337
#
# Image nb 1813
# Time spent               =  61m21s
# Estimated time remaining =  37m10s
# Mean IoU                 =  0.337
#
# Image nb 1814
# Time spent               =  61m25s
# Estimated time remaining =  37m09s
# Mean IoU                 =  0.337
#
# Image nb 1815
# Time spent               =  61m31s
# Estimated time remaining =  37m10s
# Mean IoU                 =  0.337
#
# Image nb 1816
# Time spent               =  61m33s
# Estimated time remaining =  37m08s
# Mean IoU                 =  0.337
#
# Image nb 1817
# Time spent               =  61m35s
# Estimated time remaining =  37m05s
# Mean IoU                 =  0.337
#
# Image nb 1818
# Time spent               =  61m37s
# Estimated time remaining =  37m03s
# Mean IoU                 =  0.337
#
# Image nb 1819
# Time spent               =  61m38s
# Estimated time remaining =  37m00s
# Mean IoU                 =  0.337
#
# Image nb 1820
# Time spent               =  61m39s
# Estimated time remaining =  36m58s
# Mean IoU                 =  0.337
#
# Image nb 1821
# Time spent               =  61m40s
# Estimated time remaining =  36m55s
# Mean IoU                 =  0.337
#
# Image nb 1822
# Time spent               =  61m41s
# Estimated time remaining =  36m53s
# Mean IoU                 =  0.337
#
# Image nb 1823
# Time spent               =  61m44s
# Estimated time remaining =  36m51s
# Mean IoU                 =  0.338
#
# Image nb 1824
# Time spent               =  61m45s
# Estimated time remaining =  36m49s
# Mean IoU                 =  0.338
#
# Image nb 1825
# Time spent               =  61m47s
# Estimated time remaining =  36m47s
# Mean IoU                 =  0.337
#
# Image nb 1826
# Time spent               =  61m48s
# Estimated time remaining =  36m44s
# Mean IoU                 =  0.338
#
# Image nb 1827
# Time spent               =  61m49s
# Estimated time remaining =  36m41s
# Mean IoU                 =  0.338
#
# Image nb 1828
# Time spent               =  61m52s
# Estimated time remaining =  36m40s
# Mean IoU                 =  0.337
#
# Image nb 1829
# Time spent               =  61m56s
# Estimated time remaining =  36m39s
# Mean IoU                 =  0.337
#
# Image nb 1830
# Time spent               =  61m57s
# Estimated time remaining =  36m36s
# Mean IoU                 =  0.338
#
# Image nb 1831
# Time spent               =  61m57s
# Estimated time remaining =  36m33s
# Mean IoU                 =  0.337
#
# Image nb 1832
# Time spent               =  61m59s
# Estimated time remaining =  36m31s
# Mean IoU                 =  0.338
#
# Image nb 1833
# Time spent               =  61m59s
# Estimated time remaining =  36m28s
# Mean IoU                 =  0.338
#
# Image nb 1834
# Time spent               =  62m05s
# Estimated time remaining =  36m28s
# Mean IoU                 =  0.337
#
# Image nb 1835
# Time spent               =  62m09s
# Estimated time remaining =  36m27s
# Mean IoU                 =  0.337
#
# Image nb 1836
# Time spent               =  62m10s
# Estimated time remaining =  36m25s
# Mean IoU                 =  0.337
#
# Image nb 1837
# Time spent               =  62m18s
# Estimated time remaining =  36m26s
# Mean IoU                 =  0.337
#
# Image nb 1838
# Time spent               =  62m19s
# Estimated time remaining =  36m23s
# Mean IoU                 =  0.337
#
# Image nb 1839
# Time spent               =  62m24s
# Estimated time remaining =  36m23s
# Mean IoU                 =  0.337
#
# Image nb 1840
# Time spent               =  62m27s
# Estimated time remaining =  36m22s
# Mean IoU                 =  0.337
#
# Image nb 1841
# Time spent               =  62m33s
# Estimated time remaining =  36m22s
# Mean IoU                 =  0.337
#
# Image nb 1842
# Time spent               =  62m36s
# Estimated time remaining =  36m21s
# Mean IoU                 =  0.337
#
# Image nb 1843
# Time spent               =  62m38s
# Estimated time remaining =  36m18s
# Mean IoU                 =  0.337
#
# Image nb 1844
# Time spent               =  62m39s
# Estimated time remaining =  36m16s
# Mean IoU                 =  0.337
#
# Image nb 1845
# Time spent               =  62m41s
# Estimated time remaining =  36m13s
# Mean IoU                 =  0.337
#
# Image nb 1846
# Time spent               =  62m44s
# Estimated time remaining =  36m12s
# Mean IoU                 =  0.337
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-be783479ed88> in <module>
#      19         img_cam = cam.cam_process(img_pil, img_cam)
#      20         gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0)
# ---> 21         _, _, pred = gc.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
#      22
#      23         true = voc.true_mask(sgm, classes.index(c) + 1, dilation = 0)
#
# ~\Documents\EPFL\BA7\Project\Code\voc\utils\grabcut.py in grabcut(img, mask, iterCount, mode)
#      23         np.zeros((1, 65), dtype="float"),
#      24         iterCount = iterCount,
# ---> 25         mode = cv2.GC_INIT_WITH_MASK)
#      26
#      27     quaternary_mask3 = mask                                 # [0, 1, 2, 3]
#
# error: bad allocation

# %%
print(f'Mean IoU = {np.mean(IoU)}')

# %%
df = pd.read_csv(r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\voc-class-annotations.csv')

# %%
df['mIoU'] = IoU

# %%
df.to_csv(output_path + 'IoU.csv', index = False)
