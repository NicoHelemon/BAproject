# %%
from torchvision import transforms
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import timeit
import pandas as pd

import sys
sys.path.append('../../')
import utils.image as im
import utils.cam as cam
import utils.grabcut as gc
import utils.voc as voc
import utils.json as json
from utils.VOCSegmentation import VOCSegmentation

# %%
root_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\\'

json_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\\'

output_path = r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\sessions\session3\\'

# %%
camnet = cam.Cam()

# %%
data_tbl = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Class')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 0))

# %%
annotations = json.open_json(json_path + "voc-class-annotations")
N = len(annotations)
annotations = iter(annotations.items())

classes = json.open_json(json_path + "voc-classes")

# %%
IoU = np.array([])
time = np.array([])

for i in range(N):
    start = timeit.default_timer()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_pil = img
    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    for c in annots:
        
        img_cam = camnet.get_top(img_pil, c)
        img_cam = cam.cam_process(img_pil, img_cam)
        pred = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0) % 2
        
        true = voc.true_mask(sgm, classes.index(c) + 1, dilation = 0)
        
        IoU = np.append(IoU, voc.IoU_acc_undef(true, pred, sgm))
        
    stop = timeit.default_timer()
    time = np.append(time, stop - start)
    if i % 10 == 0:
        print(f'Image nb {i}')
        print(f'Time spent               = ' + voc.time_str(np.sum(time), shift = 2))
        print(f'Estimated time remaining = ' + voc.time_str(np.mean(time) * (N - 1 - i), shift = 2))
        print(f'Mean IoU                 =  {np.mean(IoU) :.3f}')
        print()
# Out:
# C:\Users\Nicol\Miniconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Image nb 0
# Time spent               =   0m  0s
# Estimated time remaining =  13m  8s
# Mean IoU                 =  0.034
#
# Image nb 10
# Time spent               =   0m  2s
# Estimated time remaining =  10m 14s
# Mean IoU                 =  0.326
#
# Image nb 20
# Time spent               =   0m  4s
# Estimated time remaining =   9m 11s
# Mean IoU                 =  0.311
#
# Image nb 30
# Time spent               =   0m  6s
# Estimated time remaining =   9m 52s
# Mean IoU                 =  0.284
#
# Image nb 40
# Time spent               =   0m  8s
# Estimated time remaining =  10m 21s
# Mean IoU                 =  0.252
#
# Image nb 50
# Time spent               =   0m 11s
# Estimated time remaining =  10m 35s
# Mean IoU                 =  0.264
#
# Image nb 60
# Time spent               =   0m 13s
# Estimated time remaining =  10m 42s
# Mean IoU                 =  0.245
#
# Image nb 70
# Time spent               =   0m 16s
# Estimated time remaining =  11m 17s
# Mean IoU                 =  0.231
#
# Image nb 80
# Time spent               =   0m 18s
# Estimated time remaining =  10m 57s
# Mean IoU                 =  0.235
#
# Image nb 90
# Time spent               =   0m 21s
# Estimated time remaining =  10m 58s
# Mean IoU                 =  0.236
#
# Image nb 100
# Time spent               =   0m 23s
# Estimated time remaining =  11m  1s
# Mean IoU                 =  0.226
#
# Image nb 110
# Time spent               =   0m 26s
# Estimated time remaining =  10m 57s
# Mean IoU                 =  0.231
#
# Image nb 120
# Time spent               =   0m 27s
# Estimated time remaining =  10m 45s
# Mean IoU                 =  0.229
#
# Image nb 130
# Time spent               =   0m 30s
# Estimated time remaining =  10m 41s
# Mean IoU                 =  0.229
#
# Image nb 140
# Time spent               =   0m 31s
# Estimated time remaining =  10m 29s
# Mean IoU                 =  0.234
#
# Image nb 150
# Time spent               =   0m 34s
# Estimated time remaining =  10m 26s
# Mean IoU                 =  0.231
#
# Image nb 160
# Time spent               =   0m 36s
# Estimated time remaining =  10m 25s
# Mean IoU                 =  0.232
#
# Image nb 170
# Time spent               =   0m 38s
# Estimated time remaining =  10m 24s
# Mean IoU                 =  0.234
#
# Image nb 180
# Time spent               =   0m 41s
# Estimated time remaining =  10m 25s
# Mean IoU                 =  0.235
#
# Image nb 190
# Time spent               =   0m 43s
# Estimated time remaining =  10m 20s
# Mean IoU                 =  0.234
#
# Image nb 200
# Time spent               =   0m 45s
# Estimated time remaining =  10m 14s
# Mean IoU                 =  0.236
#
# Image nb 210
# Time spent               =   0m 47s
# Estimated time remaining =  10m 10s
# Mean IoU                 =  0.238
#
# Image nb 220
# Time spent               =   0m 49s
# Estimated time remaining =  10m  9s
# Mean IoU                 =  0.239
#
# Image nb 230
# Time spent               =   0m 52s
# Estimated time remaining =  10m  7s
# Mean IoU                 =  0.235
#
# Image nb 240
# Time spent               =   0m 54s
# Estimated time remaining =  10m  5s
# Mean IoU                 =  0.235
#
# Image nb 250
# Time spent               =   0m 56s
# Estimated time remaining =   9m 58s
# Mean IoU                 =  0.239
#
# Image nb 260
# Time spent               =   0m 58s
# Estimated time remaining =   9m 54s
# Mean IoU                 =  0.240
#
# Image nb 270
# Time spent               =   1m  1s
# Estimated time remaining =   9m 59s
# Mean IoU                 =  0.238
#
# Image nb 280
# Time spent               =   1m  4s
# Estimated time remaining =  10m  2s
# Mean IoU                 =  0.237
#
# Image nb 290
# Time spent               =   1m  6s
# Estimated time remaining =   9m 59s
# Mean IoU                 =  0.238
#
# Image nb 300
# Time spent               =   1m  9s
# Estimated time remaining =   9m 59s
# Mean IoU                 =  0.235
#
# Image nb 310
# Time spent               =   1m 10s
# Estimated time remaining =   9m 52s
# Mean IoU                 =  0.237
#
# Image nb 320
# Time spent               =   1m 13s
# Estimated time remaining =   9m 54s
# Mean IoU                 =  0.235
#
# Image nb 330
# Time spent               =   1m 15s
# Estimated time remaining =   9m 52s
# Mean IoU                 =  0.233
#
# Image nb 340
# Time spent               =   1m 18s
# Estimated time remaining =   9m 53s
# Mean IoU                 =  0.233
#
# Image nb 350
# Time spent               =   1m 22s
# Estimated time remaining =  10m  2s
# Mean IoU                 =  0.233
#
# Image nb 360
# Time spent               =   1m 25s
# Estimated time remaining =  10m  3s
# Mean IoU                 =  0.234
#
# Image nb 370
# Time spent               =   1m 28s
# Estimated time remaining =  10m  4s
# Mean IoU                 =  0.236
#
# Image nb 380
# Time spent               =   1m 32s
# Estimated time remaining =  10m 14s
# Mean IoU                 =  0.233
#
# Image nb 390
# Time spent               =   1m 34s
# Estimated time remaining =  10m 11s
# Mean IoU                 =  0.235
#
# Image nb 400
# Time spent               =   1m 37s
# Estimated time remaining =  10m  9s
# Mean IoU                 =  0.235
#
# Image nb 410
# Time spent               =   1m 39s
# Estimated time remaining =  10m  6s
# Mean IoU                 =  0.233
#
# Image nb 420
# Time spent               =   1m 41s
# Estimated time remaining =  10m  2s
# Mean IoU                 =  0.234
#
# Image nb 430
# Time spent               =   1m 43s
# Estimated time remaining =   9m 56s
# Mean IoU                 =  0.236
#
# Image nb 440
# Time spent               =   1m 46s
# Estimated time remaining =   9m 55s
# Mean IoU                 =  0.237
#
# Image nb 450
# Time spent               =   1m 48s
# Estimated time remaining =   9m 51s
# Mean IoU                 =  0.238
#
# Image nb 460
# Time spent               =   1m 50s
# Estimated time remaining =   9m 48s
# Mean IoU                 =  0.239
#
# Image nb 470
# Time spent               =   1m 53s
# Estimated time remaining =   9m 46s
# Mean IoU                 =  0.238
#
# Image nb 480
# Time spent               =   1m 55s
# Estimated time remaining =   9m 42s
# Mean IoU                 =  0.241
#
# Image nb 490
# Time spent               =   1m 57s
# Estimated time remaining =   9m 41s
# Mean IoU                 =  0.239
#
# Image nb 500
# Time spent               =   1m 59s
# Estimated time remaining =   9m 36s
# Mean IoU                 =  0.240
#
# Image nb 510
# Time spent               =   2m  2s
# Estimated time remaining =   9m 35s
# Mean IoU                 =  0.238
#
# Image nb 520
# Time spent               =   2m  5s
# Estimated time remaining =   9m 34s
# Mean IoU                 =  0.239
#
# Image nb 530
# Time spent               =   2m  7s
# Estimated time remaining =   9m 30s
# Mean IoU                 =  0.238
#
# Image nb 540
# Time spent               =   2m  9s
# Estimated time remaining =   9m 25s
# Mean IoU                 =  0.239
#
# Image nb 550
# Time spent               =   2m 11s
# Estimated time remaining =   9m 23s
# Mean IoU                 =  0.238
#
# Image nb 560
# Time spent               =   2m 14s
# Estimated time remaining =   9m 22s
# Mean IoU                 =  0.238
#
# Image nb 570
# Time spent               =   2m 16s
# Estimated time remaining =   9m 18s
# Mean IoU                 =  0.239
#
# Image nb 580
# Time spent               =   2m 19s
# Estimated time remaining =   9m 18s
# Mean IoU                 =  0.238
#
# Image nb 590
# Time spent               =   2m 21s
# Estimated time remaining =   9m 15s
# Mean IoU                 =  0.238
#
# Image nb 600
# Time spent               =   2m 23s
# Estimated time remaining =   9m 11s
# Mean IoU                 =  0.238
#
# Image nb 610
# Time spent               =   2m 25s
# Estimated time remaining =   9m  9s
# Mean IoU                 =  0.237
#
# Image nb 620
# Time spent               =   2m 27s
# Estimated time remaining =   9m  5s
# Mean IoU                 =  0.239
#
# Image nb 630
# Time spent               =   2m 30s
# Estimated time remaining =   9m  2s
# Mean IoU                 =  0.239
#
# Image nb 640
# Time spent               =   2m 31s
# Estimated time remaining =   8m 58s
# Mean IoU                 =  0.241
#
# Image nb 650
# Time spent               =   2m 33s
# Estimated time remaining =   8m 53s
# Mean IoU                 =  0.241
#
# Image nb 660
# Time spent               =   2m 35s
# Estimated time remaining =   8m 48s
# Mean IoU                 =  0.242
#
# Image nb 670
# Time spent               =   2m 36s
# Estimated time remaining =   8m 44s
# Mean IoU                 =  0.242
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-18c5c9e5151f> in <module>
#      18         img_cam = camnet.get_top(img_pil, c)
#      19         img_cam = cam.cam_process(img_pil, img_cam)
# ---> 20         pred = cam.cam_to_gcmask(img_cam, a = 0.0, b = 0.2, c = 1.0) % 2
#      21
#      22         true = voc.true_mask(sgm, classes.index(c) + 1, dilation = 0)
#
# ~\Documents\EPFL\BA7\Project\Code\voc\utils\cam.py in cam_to_gcmask(cam, a, b, c)
#     135     max_coord = np.unravel_index(cam.argmax(), cam.shape)
#     136
# --> 137     mask = np.vectorize(img1c_to_4bins)(cam, a, b, c).astype('uint8')
#     138     return anchoring_fgd(mask, max_coord)
#
# ~\Miniconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~\Miniconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2165                       for a in args]
#    2166
# -> 2167             outputs = ufunc(*inputs)
#    2168
#    2169             if ufunc.nout == 1:
#
# ~\Documents\EPFL\BA7\Project\Code\voc\utils\cam.py in img1c_to_4bins(x, a, b, c)
#     114
#     115     if   x <= a:              return 0
# --> 116     elif (a < x) & (x <= b): return 2
#     117     elif (b < x) & (x <= c): return 3
#     118     elif c <= x:             return 1
#
# KeyboardInterrupt:

# %%
print(f'Mean IoU = {np.mean(IoU)}')

# %%
df = pd.read_csv(r'C:\Users\Nicol\Documents\EPFL\BA7\Project\Code\voc\json\voc-object-annotations-clean.csv')

# %%
df['mIoU'] = IoU

# %%
df.to_csv(output_dir + 'IoU.csv', index = False)
