# %%
from torchvision import transforms
import torch
import numpy as np
import timeit
import gc
import pandas as pd
from pathlib import Path

import sys
sys.path.append('../')
import utils.image as im
import utils.cam as cam
import utils.grabcut as gcut
import utils.metrics as m
import utils.json as json
import utils.path as path
from utils.VOCSegmentation import VOCSegmentation

# %%
root_path   = path.goback_from_current_dir(1)
json_path   = root_path + 'json\\'
output_path = root_path + 'visualization\\'
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
camnet = cam.Cam()

data_object = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Object')

data_class  = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Class')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 0))

# %%
annotations_save = json.open_json(json_path + "voc-class-annotations")
N = len(annotations_save)
annotations = iter(annotations_save.items())

classes = json.open_json(json_path + "voc-classes")

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 0))

annotations = iter(annotations_save.items())

for i in range(N):
    gc.collect()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_pil = img
    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    im.show(img_cv2)
    
    for c in annots:
        
        print(len(annots))
        
        print(c)
        
        img_cam = camnet.get_top(img_pil, c)
        img_cam = cam.cam_process(img_pil, img_cam)
        gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = FB_threshold, c = 1.0)
        
        im.show(cam.heat_map(img_cv2, img_cam))
        im.show(im.f1_to_f255(gcmask_cam % 2), mode = 'gray')
        
        _, _, pred = gcut.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
        
        im.show(im.f1_to_f255(pred), mode = 'gray')
        
        true = voc.true_mask(sgm, classes.index(c) + 1)
        
        im.show(im.f1_to_f255(true), mode = 'gray')
        
        print("_______________________")
        
    print("=======================================================")
# Out:
# 2
# aeroplane
# _______________________
# 2
# person
# _______________________
# ...
# 1
# aeroplane
# _______________________
# ...
# 1
# tvmonitor
# _______________________
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-652f5bd91c8a> in <module>
#      18     name, annots = next(annotations)
#      19
# ---> 20     im.show(img_cv2)
#      21
#      22     for c in annots:
#
# ~\Documents\EPFL\BA7\Project\Code\utils\image.py in show(img, mode)
#      49 def show(img, mode = 'color'):
#      50     if mode == 'color':
# ---> 51         plt.imshow(img.astype('uint8'))
#      52         plt.show()
#      53     if mode == 'gray' or mode == 'grey':
#
# ~\Miniconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
# ...
