# %%
from torchvision import transforms
import torch
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
import timeit
import pandas as pd
import gc
from pathlib import Path

import utils.image as im
import utils.cam as cam
import utils.grabcut as gcut
import utils.voc as voc
import utils.json as json
import utils.path as path
from utils.VOCSegmentation import VOCSegmentation

# %%
FB_threshold = 0.1

# %%
root_path = path.goback_from_current_dir(0)

json_path = root_path + 'json\\'

output_path  = root_path + 'sessions\2 Object grabcut-cam\threshold_0' + str(int(FB_threshold * 10)) + '\\'

# %%
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
camnet = cam.Cam()

# %%
data_tbl = VOCSegmentation(root = root_path,
                           year = '2012',
                           image_set = 'trainval',
                           download = False,
                           transform = transforms.ToTensor(),
                           target_transform = transforms.ToTensor(),
                           transforms = None,
                           target = 'Object')

# %%
data = iter(torch.utils.data.DataLoader(data_tbl,
                                        batch_size = 1,
                                        shuffle = False,
                                        num_workers = 2))

# %%
annotations = json.open_json(json_path + "voc-object-annotations-clean")
N = len(annotations)
annotations = iter(annotations.items())

# %%
IoU  = []
Acc  = []
time = []

for i in range(N):
    start = timeit.default_timer()
    gc.collect()
    
    img, sgm = next(data)
    img, sgm = torch.squeeze(img), torch.squeeze(sgm)

    img_pil = img
    img_cv2 = im.pil_to_cv2(img.numpy())
    sgm     = im.f1_to_f255(sgm.numpy())
    
    name, annots = next(annotations)
    
    for j, annot in enumerate(annots):
        c, d, cbbox = annot
        
        img_cam = camnet.get_top(img_pil, c)
        img_cam = cam.cam_process(img_pil, img_cam)
        img_cam = im.bitwise_and(img_cam, im.cbbox_mask(img_cv2, cbbox))
        gcmask_cam = cam.cam_to_gcmask(img_cam, a = 0.0, b = FB_threshold, c = 1.0)
        _, _, pred = gcut.grabcut(img_cv2, gcmask_cam, mode = 'MASK')
        pred    = im.bitwise_and(pred, im.cbbox_mask(img_cv2, cbbox)).astype(bool)
        
        true = voc.true_mask(sgm, j+1).astype(bool)
        
        IoU.append(voc.IoU(true, pred, sgm))
        Acc.append(voc.accuracy(true, pred, sgm))
        
    stop = timeit.default_timer()
    time.append(stop - start)
    if i % 20 == 0:
        print(f'Image nb {i}')
        print(f'Time spent               = ' + voc.time_str(np.sum(time)))
        print(f'Estimated time remaining = ' + voc.time_str(np.mean(time) * (N - 1 - i)))
        print(f'Mean IoU                 =  {np.mean(IoU) :.3f}')
        print(f'Mean Acc                 =  {np.mean(Acc) :.3f}')
        print()
# Out:
# C:\Users\Nicol\Miniconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Image nb 0
# Time spent               =   0m01s
# Estimated time remaining =  54m55s
# Mean IoU                 =  0.448
#
# Image nb 20
# Time spent               =   0m23s
# Estimated time remaining =  53m38s
# Mean IoU                 =  0.440
#
# Image nb 40
# Time spent               =   0m45s
# Estimated time remaining =  52m38s
# Mean IoU                 =  0.432
#
# Image nb 60
# Time spent               =   1m25s
# Estimated time remaining =  66m24s
# Mean IoU                 =  0.418
#
# Image nb 80
# Time spent               =   1m55s
# Estimated time remaining =  67m25s
# Mean IoU                 =  0.453
#
# Image nb 100
# Time spent               =   2m28s
# Estimated time remaining =  68m40s
# Mean IoU                 =  0.441
#
# Image nb 120
# Time spent               =   3m01s
# Estimated time remaining =  69m52s
# Mean IoU                 =  0.460
#
# Image nb 140
# Time spent               =   3m23s
# Estimated time remaining =  66m46s
# Mean IoU                 =  0.466
#
# Image nb 160
# Time spent               =   3m49s
# Estimated time remaining =  65m17s
# Mean IoU                 =  0.454
#
# Image nb 180
# Time spent               =   4m19s
# Estimated time remaining =  65m10s
# Mean IoU                 =  0.450
#
# Image nb 200
# Time spent               =   4m42s
# Estimated time remaining =  63m31s
# Mean IoU                 =  0.455
#
# Image nb 220
# Time spent               =   5m12s
# Estimated time remaining =  63m25s
# Mean IoU                 =  0.447
#
# Image nb 240
# Time spent               =   5m35s
# Estimated time remaining =  61m59s
# Mean IoU                 =  0.443
#
# Image nb 260
# Time spent               =   5m54s
# Estimated time remaining =  60m01s
# Mean IoU                 =  0.448
#
# Image nb 280
# Time spent               =   6m26s
# Estimated time remaining =  60m20s
# Mean IoU                 =  0.441
#
# Image nb 300
# Time spent               =   6m55s
# Estimated time remaining =  60m08s
# Mean IoU                 =  0.432
#
# Image nb 320
# Time spent               =   7m16s
# Estimated time remaining =  58m48s
# Mean IoU                 =  0.434
#
# Image nb 340
# Time spent               =   7m48s
# Estimated time remaining =  58m53s
# Mean IoU                 =  0.430
#
# Image nb 360
# Time spent               =   8m19s
# Estimated time remaining =  58m50s
# Mean IoU                 =  0.426
#
# Image nb 380
# Time spent               =   8m43s
# Estimated time remaining =  58m00s
# Mean IoU                 =  0.428
#
# Image nb 400
# Time spent               =   9m09s
# Estimated time remaining =  57m22s
# Mean IoU                 =  0.430
#
# Image nb 420
# Time spent               =   9m43s
# Estimated time remaining =  57m36s
# Mean IoU                 =  0.432
#
# Image nb 440
# Time spent               =  10m23s
# Estimated time remaining =  58m16s
# Mean IoU                 =  0.432
#
# Image nb 460
# Time spent               =  10m45s
# Estimated time remaining =  57m15s
# Mean IoU                 =  0.434
#
# Image nb 480
# Time spent               =  11m16s
# Estimated time remaining =  57m01s
# Mean IoU                 =  0.433
#
# Image nb 500
# Time spent               =  11m49s
# Estimated time remaining =  56m55s
# Mean IoU                 =  0.430
#
# Image nb 520
# Time spent               =  12m15s
# Estimated time remaining =  56m16s
# Mean IoU                 =  0.431
#
# Image nb 540
# Time spent               =  12m37s
# Estimated time remaining =  55m21s
# Mean IoU                 =  0.431
#
# Image nb 560
# Time spent               =  13m14s
# Estimated time remaining =  55m30s
# Mean IoU                 =  0.432
#
# Image nb 580
# Time spent               =  13m46s
# Estimated time remaining =  55m17s
# Mean IoU                 =  0.430
#
# Image nb 600
# Time spent               =  14m08s
# Estimated time remaining =  54m24s
# Mean IoU                 =  0.431
#
# Image nb 620
# Time spent               =  14m39s
# Estimated time remaining =  54m04s
# Mean IoU                 =  0.432
#
# Image nb 640
# Time spent               =  14m55s
# Estimated time remaining =  52m53s
# Mean IoU                 =  0.435
#
# Image nb 660
# Time spent               =  15m09s
# Estimated time remaining =  51m38s
# Mean IoU                 =  0.438
#
# Image nb 680
# Time spent               =  15m32s
# Estimated time remaining =  50m57s
# Mean IoU                 =  0.440
#
# Image nb 700
# Time spent               =  15m50s
# Estimated time remaining =  50m00s
# Mean IoU                 =  0.442
#
# Image nb 720
# Time spent               =  16m09s
# Estimated time remaining =  49m08s
# Mean IoU                 =  0.445
#
# Image nb 740
# Time spent               =  16m32s
# Estimated time remaining =  48m29s
# Mean IoU                 =  0.447
#
# Image nb 760
# Time spent               =  16m47s
# Estimated time remaining =  47m27s
# Mean IoU                 =  0.450
#
# Image nb 780
# Time spent               =  17m03s
# Estimated time remaining =  46m33s
# Mean IoU                 =  0.451
#
# Image nb 800
# Time spent               =  17m22s
# Estimated time remaining =  45m47s
# Mean IoU                 =  0.454
#
# Image nb 820
# Time spent               =  17m38s
# Estimated time remaining =  44m56s
# Mean IoU                 =  0.455
#
# Image nb 840
# Time spent               =  18m01s
# Estimated time remaining =  44m25s
# Mean IoU                 =  0.457
#
# Image nb 860
# Time spent               =  18m31s
# Estimated time remaining =  44m08s
# Mean IoU                 =  0.456
#
# Image nb 880
# Time spent               =  18m49s
# Estimated time remaining =  43m24s
# Mean IoU                 =  0.458
#
# Image nb 900
# Time spent               =  19m04s
# Estimated time remaining =  42m35s
# Mean IoU                 =  0.460
#
# Image nb 920
# Time spent               =  19m28s
# Estimated time remaining =  42m07s
# Mean IoU                 =  0.461
#
# Image nb 940
# Time spent               =  19m49s
# Estimated time remaining =  41m33s
# Mean IoU                 =  0.462
#
# Image nb 960
# Time spent               =  20m11s
# Estimated time remaining =  41m00s
# Mean IoU                 =  0.463
#
# Image nb 980
# Time spent               =  20m35s
# Estimated time remaining =  40m33s
# Mean IoU                 =  0.464
#
# Image nb 1000
# Time spent               =  20m51s
# Estimated time remaining =  39m49s
# Mean IoU                 =  0.466
#
# Image nb 1020
# Time spent               =  21m10s
# Estimated time remaining =  39m15s
# Mean IoU                 =  0.468
#
# Image nb 1040
# Time spent               =  21m26s
# Estimated time remaining =  38m34s
# Mean IoU                 =  0.471
#
# Image nb 1060
# Time spent               =  21m45s
# Estimated time remaining =  37m58s
# Mean IoU                 =  0.471
#
# Image nb 1080
# Time spent               =  22m16s
# Estimated time remaining =  37m45s
# Mean IoU                 =  0.470
#
# Image nb 1100
# Time spent               =  22m47s
# Estimated time remaining =  37m31s
# Mean IoU                 =  0.469
#
# Image nb 1120
# Time spent               =  23m10s
# Estimated time remaining =  37m02s
# Mean IoU                 =  0.469
#
# Image nb 1140
# Time spent               =  23m39s
# Estimated time remaining =  36m44s
# Mean IoU                 =  0.468
#
# Image nb 1160
# Time spent               =  24m22s
# Estimated time remaining =  36m46s
# Mean IoU                 =  0.469
#
# Image nb 1180
# Time spent               =  24m52s
# Estimated time remaining =  36m28s
# Mean IoU                 =  0.469
#
# Image nb 1200
# Time spent               =  25m17s
# Estimated time remaining =  36m03s
# Mean IoU                 =  0.469
#
# Image nb 1220
# Time spent               =  25m40s
# Estimated time remaining =  35m34s
# Mean IoU                 =  0.470
#
# Image nb 1240
# Time spent               =  26m11s
# Estimated time remaining =  35m17s
# Mean IoU                 =  0.470
#
# Image nb 1260
# Time spent               =  26m47s
# Estimated time remaining =  35m05s
# Mean IoU                 =  0.469
#
# Image nb 1280
# Time spent               =  27m19s
# Estimated time remaining =  34m49s
# Mean IoU                 =  0.469
#
# Image nb 1300
# Time spent               =  27m43s
# Estimated time remaining =  34m20s
# Mean IoU                 =  0.471
#
# Image nb 1320
# Time spent               =  28m21s
# Estimated time remaining =  34m10s
# Mean IoU                 =  0.472
#
# Image nb 1340
# Time spent               =  28m50s
# Estimated time remaining =  33m48s
# Mean IoU                 =  0.473
#
# Image nb 1360
# Time spent               =  29m12s
# Estimated time remaining =  33m18s
# Mean IoU                 =  0.474
#
# Image nb 1380
# Time spent               =  29m30s
# Estimated time remaining =  32m43s
# Mean IoU                 =  0.475
# Image nb 1400
# Time spent               =  29m54s
# Estimated time remaining =  32m17s
# Mean IoU                 =  0.476
#
# Image nb 1420
# Time spent               =  30m16s
# Estimated time remaining =  31m46s
# Mean IoU                 =  0.476
#
# Image nb 1440
# Time spent               =  30m38s
# Estimated time remaining =  31m17s
# Mean IoU                 =  0.477
#
# Image nb 1460
# Time spent               =  30m58s
# Estimated time remaining =  30m47s
# Mean IoU                 =  0.478
#
# Image nb 1480
# Time spent               =  31m16s
# Estimated time remaining =  30m14s
# Mean IoU                 =  0.480
#
# Image nb 1500
# Time spent               =  31m40s
# Estimated time remaining =  29m47s
# Mean IoU                 =  0.480
#
# Image nb 1520
# Time spent               =  32m00s
# Estimated time remaining =  29m17s
# Mean IoU                 =  0.481
#
# Image nb 1540
# Time spent               =  32m24s
# Estimated time remaining =  28m51s
# Mean IoU                 =  0.481
#
# Image nb 1560
# Time spent               =  32m49s
# Estimated time remaining =  28m25s
# Mean IoU                 =  0.481
#
# Image nb 1580
# Time spent               =  33m16s
# Estimated time remaining =  28m02s
# Mean IoU                 =  0.480
#
# Image nb 1600
# Time spent               =  33m40s
# Estimated time remaining =  27m35s
# Mean IoU                 =  0.481
#
# Image nb 1620
# Time spent               =  34m02s
# Estimated time remaining =  27m07s
# Mean IoU                 =  0.483
#
# Image nb 1640
# Time spent               =  34m55s
# Estimated time remaining =  27m04s
# Mean IoU                 =  0.482
#
# Image nb 1660
# Time spent               =  35m13s
# Estimated time remaining =  26m33s
# Mean IoU                 =  0.483
#
# Image nb 1680
# Time spent               =  35m37s
# Estimated time remaining =  26m06s
# Mean IoU                 =  0.483
#
# Image nb 1700
# Time spent               =  35m58s
# Estimated time remaining =  25m38s
# Mean IoU                 =  0.483
#
# Image nb 1720
# Time spent               =  36m24s
# Estimated time remaining =  25m13s
# Mean IoU                 =  0.483
#
# Image nb 1740
# Time spent               =  36m45s
# Estimated time remaining =  24m44s
# Mean IoU                 =  0.483
#
# Image nb 1760
# Time spent               =  37m05s
# Estimated time remaining =  24m16s
# Mean IoU                 =  0.484
#
# Image nb 1780
# Time spent               =  37m23s
# Estimated time remaining =  23m45s
# Mean IoU                 =  0.484
#
# Image nb 1800
# Time spent               =  37m45s
# Estimated time remaining =  23m18s
# Mean IoU                 =  0.484
#
# Image nb 1820
# Time spent               =  38m07s
# Estimated time remaining =  22m51s
# Mean IoU                 =  0.484
#
# Image nb 1840
# Time spent               =  38m28s
# Estimated time remaining =  22m23s
# Mean IoU                 =  0.484
#
# Image nb 1860
# Time spent               =  38m46s
# Estimated time remaining =  21m55s
# Mean IoU                 =  0.485
#
# Image nb 1880
# Time spent               =  39m03s
# Estimated time remaining =  21m26s
# Mean IoU                 =  0.486
#
# Image nb 1900
# Time spent               =  39m28s
# Estimated time remaining =  21m00s
# Mean IoU                 =  0.486
#
# Image nb 1920
# Time spent               =  39m53s
# Estimated time remaining =  20m36s
# Mean IoU                 =  0.487
#
# Image nb 1940
# Time spent               =  40m19s
# Estimated time remaining =  20m11s
# Mean IoU                 =  0.487
#
# Image nb 1960
# Time spent               =  40m40s
# Estimated time remaining =  19m44s
# Mean IoU                 =  0.488
#
# Image nb 1980
# Time spent               =  41m03s
# Estimated time remaining =  19m19s
# Mean IoU                 =  0.488
#
# Image nb 2000
# Time spent               =  41m26s
# Estimated time remaining =  18m53s
# Mean IoU                 =  0.488
#
# Image nb 2020
# Time spent               =  41m53s
# Estimated time remaining =  18m29s
# Mean IoU                 =  0.487
#
# Image nb 2040
# Time spent               =  42m15s
# Estimated time remaining =  18m03s
# Mean IoU                 =  0.487
#
# Image nb 2060
# Time spent               =  42m43s
# Estimated time remaining =  17m39s
# Mean IoU                 =  0.488
#
# Image nb 2080
# Time spent               =  43m15s
# Estimated time remaining =  17m17s
# Mean IoU                 =  0.486
#
# Image nb 2100
# Time spent               =  43m46s
# Estimated time remaining =  16m55s
# Mean IoU                 =  0.485
#
# Image nb 2120
# Time spent               =  44m14s
# Estimated time remaining =  16m31s
# Mean IoU                 =  0.485
#
# Image nb 2140
# Time spent               =  44m43s
# Estimated time remaining =  16m07s
# Mean IoU                 =  0.486
#
# Image nb 2160
# Time spent               =  45m12s
# Estimated time remaining =  15m44s
# Mean IoU                 =  0.486
#
# Image nb 2180
# Time spent               =  45m38s
# Estimated time remaining =  15m19s
# Mean IoU                 =  0.485
#
# Image nb 2200
# Time spent               =  46m09s
# Estimated time remaining =  14m55s
# Mean IoU                 =  0.484
#
# Image nb 2220
# Time spent               =  46m33s
# Estimated time remaining =  14m30s
# Mean IoU                 =  0.484
#
# Image nb 2240
# Time spent               =  47m06s
# Estimated time remaining =  14m07s
# Mean IoU                 =  0.483
#
# Image nb 2260
# Time spent               =  47m38s
# Estimated time remaining =  13m44s
# Mean IoU                 =  0.483
#
# Image nb 2280
# Time spent               =  48m01s
# Estimated time remaining =  13m18s
# Mean IoU                 =  0.483
#
# Image nb 2300
# Time spent               =  48m22s
# Estimated time remaining =  12m52s
# Mean IoU                 =  0.484
#
# Image nb 2320
# Time spent               =  48m47s
# Estimated time remaining =  12m26s
# Mean IoU                 =  0.484
#
# Image nb 2340
# Time spent               =  49m16s
# Estimated time remaining =  12m02s
# Mean IoU                 =  0.484
#
# Image nb 2360
# Time spent               =  49m41s
# Estimated time remaining =  11m36s
# Mean IoU                 =  0.484
#
# Image nb 2380
# Time spent               =  50m05s
# Estimated time remaining =  11m11s
# Mean IoU                 =  0.484
#
# Image nb 2400
# Time spent               =  50m29s
# Estimated time remaining =  10m46s
# Mean IoU                 =  0.483
#
# Image nb 2420
# Time spent               =  50m53s
# Estimated time remaining =  10m20s
# Mean IoU                 =  0.483
#
# Image nb 2440
# Time spent               =  51m17s
# Estimated time remaining =   9m55s
# Mean IoU                 =  0.482
#
# Image nb 2460
# Time spent               =  51m36s
# Estimated time remaining =   9m28s
# Mean IoU                 =  0.482
#
# Image nb 2480
# Time spent               =  52m01s
# Estimated time remaining =   9m03s
# Mean IoU                 =  0.483
#
# Image nb 2500
# Time spent               =  52m31s
# Estimated time remaining =   8m39s
# Mean IoU                 =  0.482
#
# Image nb 2520
# Time spent               =  53m01s
# Estimated time remaining =   8m14s
# Mean IoU                 =  0.482
#
# Image nb 2540
# Time spent               =  53m25s
# Estimated time remaining =   7m49s
# Mean IoU                 =  0.482
#
# Image nb 2560
# Time spent               =  53m57s
# Estimated time remaining =   7m24s
# Mean IoU                 =  0.481
#
# Image nb 2580
# Time spent               =  54m25s
# Estimated time remaining =   7m00s
# Mean IoU                 =  0.481
#
# Image nb 2600
# Time spent               =  54m53s
# Estimated time remaining =   6m35s
# Mean IoU                 =  0.480
#
# Image nb 2620
# Time spent               =  55m23s
# Estimated time remaining =   6m10s
# Mean IoU                 =  0.479
#
# Image nb 2640
# Time spent               =  55m55s
# Estimated time remaining =   5m45s
# Mean IoU                 =  0.479
#
# Image nb 2660
# Time spent               =  56m22s
# Estimated time remaining =   5m20s
# Mean IoU                 =  0.479
#
# Image nb 2680
# Time spent               =  56m50s
# Estimated time remaining =   4m55s
# Mean IoU                 =  0.478
#
# Image nb 2700
# Time spent               =  57m15s
# Estimated time remaining =   4m29s
# Mean IoU                 =  0.477
#
# Image nb 2720
# Time spent               =  57m42s
# Estimated time remaining =   4m04s
# Mean IoU                 =  0.477
#
# Image nb 2740
# Time spent               =  58m18s
# Estimated time remaining =   3m39s
# Mean IoU                 =  0.477
#
# Image nb 2760
# Time spent               =  58m43s
# Estimated time remaining =   3m13s
# Mean IoU                 =  0.477
# Image nb 2780
# Time spent               =  59m03s
# Estimated time remaining =   2m48s
# Mean IoU                 =  0.477
#
# Image nb 2800
# Time spent               =  59m37s
# Estimated time remaining =   2m23s
# Mean IoU                 =  0.476
#
# Image nb 2820
# Time spent               =  60m11s
# Estimated time remaining =   1m57s
# Mean IoU                 =  0.476
#
# Image nb 2840
# Time spent               =  60m41s
# Estimated time remaining =   1m32s
# Mean IoU                 =  0.475
#
# Image nb 2860
# Time spent               =  61m19s
# Estimated time remaining =   1m06s
# Mean IoU                 =  0.474
#
# Image nb 2880
# Time spent               =  61m56s
# Estimated time remaining =   0m41s
# Mean IoU                 =  0.472
#
# Image nb 2900
# Time spent               =  62m35s
# Estimated time remaining =   0m15s
# Mean IoU                 =  0.470

# %%
print(f'Mean IoU = {np.mean(IoU):.3f}')
print(f'Mean Acc = {np.mean(Acc):.3f}')
# Out:
# Mean IoU = 0.470

# %%
df = pd.read_csv(json_path + 'voc-object-annotations-clean.csv')

# %%
df['IoU'] = IoU
df['Accuracy'] = Acc

# %%
df.to_csv(output_path + 'IoU.csv', index = False)
